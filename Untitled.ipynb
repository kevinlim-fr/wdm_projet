# %%
import pandas as pd
import re
import numpy as np
import math
import sklearn
import json
np.seterr(all="ignore")
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)
# -*- coding: utf-8 -*-

# %% [markdown]
# ### Hopitaux de Paris

# %%
hopitaux_file = open("originalJSON/les_etablissements_hospitaliers_franciliens.json","r")
hopitaux_file_json = json.load(hopitaux_file)

# %%
paris_transports = pd.DataFrame()
for i in range(len(paris_traports_array)):
    
    stop_name = paris_traports_array[i]["fields"]["stop_name"]
    latitude = paris_traports_array[i]["fields"]["stop_coordinates"][0]
    longitude = paris_traports_array[i]["fields"]["stop_coordinates"][1]
    
    list_to_append = [stop_name,latitude,longitude]
    line_labels = ['stop_name'] + ['latitude'] + ['longitude']
    dic = {line_labels[i]: list_to_append[i] for i in range(len(list_to_append))}   
    paris_transports = paris_transports.append(dic,ignore_index=True)

# %%
#hopitaux_file_json

# %%
#hopitaux_file_json

# %% [markdown]
# ### Lyon Transports

# %%
lyon_transports_file = open("originalJSON/lyon_transports.json","r")
lyon_transports_json = json.load(lyon_transports_file)

# %%
or element in lyon_transports:
    del element['escalator']
    del element['pmr']
    del element['desserte']
     del element['last_update']
    del element['ascenseur']
    del element['ascenseur']

# %%
lyon_transports_json["features"][0]["properties"]
# Out:
# {'id': '3070',
#  'nom': 'Vaulx Pasteur',
#  'desserte': '37A:R,57A:R',
#  'pmr': 'true',
#  'ascenseur': 'false',
#  'escalator': 'false',
#  'gid': '10894',
#  'last_update': '2021-03-25 01:31:17',
#  'last_update_fme': '2021-03-25 06:00:11'}

# %%
json_array = []
for i in range(len(lyon_transports_json["features"])):
    for element in  lyon_transports_json["features"][i]["properties"]:
        del element['id']
        del element['desserte']
        del element['pmr']
        del element['ascenseur']
        del element['escalator']
        del element['gid']
        del element['last_update']
        del element['last_update_fme']
    #json["lat"] = lyon_transports_json["geometry"]["coordinates"][0]
    #json["lon"] = lyon_transports_json["geometry"]["coordinates"][0]
    #json_array.append(json)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-831a81185f89> in <module>
#       2 for i in range(len(lyon_transports_json["features"])):
#       3     for element in  lyon_transports_json["features"][i]["properties"]:
# ----> 4         del element['id']
#       5         del element['desserte']
#       6         del element['pmr']
#
# TypeError: 'str' object does not support item deletion

# %%
lyon_transports_json
# Out:
# {'type': 'FeatureCollection',
#  'name': 'tcl_sytral.tclarret',
#  'features': [{'type': 'Feature',
#    'properties': {'id': '3070',
#     'nom': 'Vaulx Pasteur',
#     'desserte': '37A:R,57A:R',
#     'pmr': 'true',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '10894',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:11'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.930446205373434, 45.7854487493262]}},
#   {'type': 'Feature',
#    'properties': {'id': '50',
#     'nom': 'Charmettes',
#     'desserte': 'C16A:A',
#     'pmr': 'true',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '824',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:10'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.868704265465049, 45.763319060017736]}},
#   {'type': 'Feature',
#    'properties': {'id': '55',
#     'nom': 'Ampere',
#     'desserte': 'S16A:A,S3B:A',
#     'pmr': 'false',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '10529',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:10'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.838614838251458, 45.81706998116871]}},
#   {'type': 'Feature',
#    'properties': {'id': '58',
#     'nom': 'Anatole France',
#     'desserte': '39A:R',
#     'pmr': 'true',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '9567',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:10'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.894235412815058, 45.722029387153285]}},
#   {'type': 'Feature',
#    'properties': {'id': '64',
#     'nom': 'Andre Boulloche',
#     'desserte': '93A:A',
#     'pmr': 'true',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '9543',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:10'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.930375386827087, 45.71898634117752]}},
#   {'type': 'Feature',
#    'properties': {'id': '73',
#     'nom': 'Aqueducs de Beaunant',
#     'desserte': '11B:R,12B:R,14B:R',
#     'pmr': 'false',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '10656',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:10'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.779963362674723, 45.72432459823616]}},
#   {'type': 'Feature',
#    'properties': {'id': '140',
#     'nom': 'Batterie',
#     'desserte': '24A:R',
#     'pmr': 'true',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '10702',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:10'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.915743877214211, 45.74447560539888]}},
#   {'type': 'Feature',
#    'properties': {'id': '197',
#     'nom': 'Berthaudiere',
#     'desserte': '67A:R',
#     'pmr': 'false',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '10769',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:10'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.969655190500498, 45.775524836226936]}},
#   {'type': 'Feature',
#    'properties': {'id': '227',
#     'nom': 'Bon Coin - Medipole',
#     'desserte': 'C11A:A,C17A:R,C3A:A',
#     'pmr': 'true',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '9522',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:10'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.906205292007596, 45.76068195636625]}},
#   {'type': 'Feature',
#    'properties': {'id': '10884',
#     'nom': 'Minimes Théatres Romains',
#     'desserte': '346A:R',
#     'pmr': 'false',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '10893',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:12'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.821171309692938, 45.758426230134916]}},
#   {'type': 'Feature',
#    'properties': {'id': '30362',
#     'nom': 'Hénon',
#     'desserte': 'C13A:R',
#     'pmr': 'false',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '10897',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:12'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.827554198940718, 45.779070071515086]}},
#   {'type': 'Feature',
#    'properties': {'id': '43217',
#     'nom': 'Vaulx - Marcel Cachin',
#     'desserte': '37A:A,37A:R,57A:A,57A:R',
#     'pmr': 'false',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '10895',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:13'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.932885300675281, 45.78433525965211]}},
#   {'type': 'Feature',
#    'properties': {'id': '43937',
#     'nom': 'Vaulx - Marcel Cachin',
#     'desserte': '57A:R',
#     'pmr': 'false',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '10896',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:13'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.933258006781948, 45.78432664466685]}},
#   {'type': 'Feature',
#    'properties': {'id': '47563',
#     'nom': 'J. B. Simon',
#     'desserte': '40A:R',
#     'pmr': 'true',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '10887',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:13'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.857657652441985, 45.82580260491257]}},
#   {'type': 'Feature',
#    'properties': {'id': '47677',
#     'nom': 'Grd Parc Miribel Jonage',
#     'desserte': '83A:A,83A:R',
#     'pmr': 'false',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '10885',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:13'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.942095183774559, 45.79793361474266]}},
#   {'type': 'Feature',
#    'properties': {'id': '47748',
#     'nom': 'Pressense - Marrane',
#     'desserte': '35A:R',
#     'pmr': 'false',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '10728',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:13'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.864877404316286, 45.72384840629712]}},
#   {'type': 'Feature',
#    'properties': {'id': '47783',
#     'nom': 'Egalite - Farrere',
#     'desserte': 'C25B:A',
#     'pmr': 'false',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '10795',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:13'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.94903016455394, 45.68841945954886]}},
#   {'type': 'Feature',
#    'properties': {'id': '47784',
#     'nom': 'Les Halles 102 - 104',
#     'desserte': '5A:A,86A:A',
#     'pmr': 'false',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '10753',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:13'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.751738018531494, 45.7771513286027]}},
#   {'type': 'Feature',
#    'properties': {'id': '47785',
#     'nom': 'Les Halles 102 - 104',
#     'desserte': '5A:R,86A:R',
#     'pmr': 'false',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '10754',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:13'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.751634017929973, 45.77700631049046]}},
#   {'type': 'Feature',
#    'properties': {'id': '47791',
#     'nom': 'Place Morel',
#     'desserte': 'S12A:R',
#     'pmr': 'false',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '10850',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:13'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.825748178701537, 45.771651127343084]}},
#   {'type': 'Feature',
#    'properties': {'id': '47796',
#     'nom': "Rochette Cercle d'Aviron",
#     'desserte': 'S5A:A',
#     'pmr': 'false',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '10881',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:13'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.823617023076824, 45.79111591478002]}},
#   {'type': 'Feature',
#    'properties': {'id': '352',
#     'nom': 'Carrefour Liberation',
#     'desserte': '5A:A,5A:R,73D:R,C21A:A,C21A:R',
#     'pmr': 'false',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '10755',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:10'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.775593098231488, 45.7588803382298]}},
#   {'type': 'Feature',
#    'properties': {'id': '443',
#     'nom': 'Gare de Villeurbanne',
#     'desserte': 'C26A:R',
#     'pmr': 'true',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '553',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:10'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.891167814643029, 45.75622631216981]}},
#   {'type': 'Feature',
#    'properties': {'id': '753',
#     'nom': 'Diderot',
#     'desserte': 'C7B:R',
#     'pmr': 'true',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '9018',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:10'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.809094227754559, 45.71330245057979]}},
#   {'type': 'Feature',
#    'properties': {'id': '802',
#     'nom': 'Dumas - Salengro',
#     'desserte': '52A:R',
#     'pmr': 'false',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '10842',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:10'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.928450323771209, 45.75357147538473]}},
#   {'type': 'Feature',
#    'properties': {'id': '808',
#     'nom': 'Duquesne - Foch',
#     'desserte': 'C6C:A',
#     'pmr': 'true',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '10463',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:10'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.842685177776138, 45.7725131438024]}},
#   {'type': 'Feature',
#    'properties': {'id': '988',
#     'nom': 'Gabriel Rosset',
#     'desserte': '34A:R,64A:R',
#     'pmr': 'true',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '10091',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:11'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.839444456026275, 45.72993138192083]}},
#   {'type': 'Feature',
#    'properties': {'id': '1070',
#     'nom': 'Grand Vire',
#     'desserte': '83A:A',
#     'pmr': 'true',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '10861',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:11'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.916839205795164, 45.77885473899531]}},
#   {'type': 'Feature',
#    'properties': {'id': '47797',
#     'nom': 'Caluire - Bords de Saone',
#     'desserte': '40A:R',
#     'pmr': 'false',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '10888',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:13'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.825987996410432, 45.79322691636009]}},
#   {'type': 'Feature',
#    'properties': {'id': '47799',
#     'nom': 'Caluire - Bords de Saone',
#     'desserte': '40A:A',
#     'pmr': 'false',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '10889',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:13'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.826712082301316, 45.793579915554886]}},
#   {'type': 'Feature',
#    'properties': {'id': '1718',
#     'nom': 'Les Meurieres',
#     'desserte': '62A:R',
#     'pmr': 'true',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '10772',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:11'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.949208447874335, 45.67946656562846]}},
#   {'type': 'Feature',
#    'properties': {'id': '1794',
#     'nom': 'Limonest Centre',
#     'desserte': '21A:A,942A:A',
#     'pmr': 'true',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '2073',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:11'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.771644326091469, 45.837503925162565]}},
#   {'type': 'Feature',
#    'properties': {'id': '1804',
#     'nom': 'Longefer',
#     'desserte': '24A:A,34A:R',
#     'pmr': 'true',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '2081',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:11'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.880151152518684, 45.7393379781948]}},
#   {'type': 'Feature',
#    'properties': {'id': '1805',
#     'nom': 'Longefer',
#     'desserte': '24A:R,34A:A',
#     'pmr': 'true',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '2080',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:11'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.881798373734903, 45.74007924523859]}},
#   {'type': 'Feature',
#    'properties': {'id': '2560',
#     'nom': 'Quatre Chemins',
#     'desserte': '147:R',
#     'pmr': 'true',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '10617',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:11'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.690500937227512, 45.73994285620513]}},
#   {'type': 'Feature',
#    'properties': {'id': '47801',
#     'nom': 'Place des Buers',
#     'desserte': 'C17A:A',
#     'pmr': 'false',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '10892',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:13'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.89197417250469, 45.77846277626935]}},
#   {'type': 'Feature',
#    'properties': {'id': '47804',
#     'nom': 'St Nizier',
#     'desserte': 'S1A:R',
#     'pmr': 'false',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '10890',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:13'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.833073202327023, 45.76508408604173]}},
#   {'type': 'Feature',
#    'properties': {'id': '47805',
#     'nom': 'Esplanade Mitterrand',
#     'desserte': 'S1A:R',
#     'pmr': 'false',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '10891',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:13'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.820524423063508, 45.74057136638855]}},
#   {'type': 'Feature',
#    'properties': {'id': '2496',
#     'nom': 'Pont De Lattre RD',
#     'desserte': 'C6C:A',
#     'pmr': 'true',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '10472',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:11'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.83770913230017, 45.772791061399715]}},
#   {'type': 'Feature',
#    'properties': {'id': '51',
#     'nom': 'Charmettes',
#     'desserte': 'C16A:R',
#     'pmr': 'true',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '821',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:10'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.868900270827173, 45.76397299357612]}},
#   {'type': 'Feature',
#    'properties': {'id': '66',
#     'nom': 'Andre Brun',
#     'desserte': '16A:R',
#     'pmr': 'false',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '837',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:10'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.96656794565722, 45.7671056243793]}},
#   {'type': 'Feature',
#    'properties': {'id': '75',
#     'nom': 'Arago',
#     'desserte': 'C11A:A',
#     'pmr': 'true',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '844',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:10'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.884751233661722, 45.75799805819997]}},
#   {'type': 'Feature',
#    'properties': {'id': '98',
#     'nom': 'Ayasse - Yves Farge',
#     'desserte': '34A:A,C7B:A',
#     'pmr': 'true',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '9387',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:10'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.827341942461014, 45.73547622762371]}},
#   {'type': 'Feature',
#    'properties': {'id': '204',
#     'nom': 'Bir Hakeim',
#     'desserte': 'C11A:A',
#     'pmr': 'true',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '9413',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:10'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.855110015531393, 45.75311652018818]}},
#   {'type': 'Feature',
#    'properties': {'id': '46635',
#     'nom': 'Fontaines Centre',
#     'desserte': '77A:A,77A:R',
#     'pmr': 'false',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '10802',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:13'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.845944504104499, 45.8352615436654]}},
#   {'type': 'Feature',
#    'properties': {'id': '46639',
#     'nom': 'Fontaines Petit Moulin',
#     'desserte': '40A:A,70A:A',
#     'pmr': 'false',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '5724',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:13'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.842696489510696, 45.83417859630333]}},
#   {'type': 'Feature',
#    'properties': {'id': '46878',
#     'nom': 'Meyzieu Bascule',
#     'desserte': '85A:A',
#     'pmr': 'false',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '6603',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:13'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.996115081911822, 45.76613191233633]}},
#   {'type': 'Feature',
#    'properties': {'id': '444',
#     'nom': 'Charton',
#     'desserte': 'C7B:A',
#     'pmr': 'true',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '5858',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:10'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.810666671101981, 45.71179575412843]}},
#   {'type': 'Feature',
#    'properties': {'id': '47291',
#     'nom': 'Moulin à Vent',
#     'desserte': 'T6:A',
#     'pmr': 'true',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '10055',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:13'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.853170465739497, 45.72954040009761]}},
#   {'type': 'Feature',
#    'properties': {'id': '452',
#     'nom': 'Chassieu Mairie',
#     'desserte': '68B:R,76A:R',
#     'pmr': 'true',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '10249',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:10'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.971799125111602, 45.742867496966454]}},
#   {'type': 'Feature',
#    'properties': {'id': '463',
#     'nom': 'Chazay',
#     'desserte': 'C20D:A,C20E:A',
#     'pmr': 'true',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '1125',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:10'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.786263164088715, 45.74550404001804]}},
#   {'type': 'Feature',
#    'properties': {'id': '466',
#     'nom': 'Chemin Bressan',
#     'desserte': '43A:R',
#     'pmr': 'true',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '1126',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:10'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.834331720806412, 45.88198429550201]}},
#   {'type': 'Feature',
#    'properties': {'id': '467',
#     'nom': 'Chemin de Grange Blanche',
#     'desserte': '54A:A',
#     'pmr': 'true',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '1129',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:10'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.901834345134705, 45.66370100464933]}},
#   {'type': 'Feature',
#    'properties': {'id': '47622',
#     'nom': "Rond-Point d'Italie",
#     'desserte': '48B:R,ZI5B:R',
#     'pmr': 'false',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '10234',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:13'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.994823010518814, 45.714425310467]}},
#   {'type': 'Feature',
#    'properties': {'id': '47623',
#     'nom': 'Calmette - Muriers',
#     'desserte': 'ZI5B:R',
#     'pmr': 'false',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '10235',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:13'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.9874500474915, 45.716940310523874]}},
#   {'type': 'Feature',
#    'properties': {'id': '47680',
#     'nom': 'Cyrano',
#     'desserte': 'C9A:A',
#     'pmr': 'true',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '10757',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:13'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.880265247146904, 45.75469810488319]}},
#   {'type': 'Feature',
#    'properties': {'id': '47730',
#     'nom': 'Gymnase Frison Roche',
#     'desserte': '93A:A',
#     'pmr': 'false',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '10873',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:13'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.858826533226259, 45.68997659305562]}},
#   {'type': 'Feature',
#    'properties': {'id': '47732',
#     'nom': 'Joannes Carret',
#     'desserte': '31A:A,31A:R,43A:A,S10A:A',
#     'pmr': 'false',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '10687',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:13'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.82054601397684, 45.792880947193076]}},
#   {'type': 'Feature',
#    'properties': {'id': '47733',
#     'nom': "St-Rambert - l'Ile Barbe",
#     'desserte': '31A:A,43A:A',
#     'pmr': 'false',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '10701',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:13'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.830182021368815, 45.797808842443004]}},
#   {'type': 'Feature',
#    'properties': {'id': '484',
#     'nom': 'Caluire Chemin Petit',
#     'desserte': '70A:R,S5A:A',
#     'pmr': 'true',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '1138',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:10'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.860388830869239, 45.804008210322664]}},
#   {'type': 'Feature',
#    'properties': {'id': '490',
#     'nom': 'Valpre',
#     'desserte': '19A:R',
#     'pmr': 'true',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '1144',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:10'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.787133057704978, 45.77852019114668]}},
#   {'type': 'Feature',
#    'properties': {'id': '502',
#     'nom': "Cimetiere d'Oullins",
#     'desserte': 'C7B:R',
#     'pmr': 'true',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '9017',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:10'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.811007493824214, 45.70937578210631]}},
#   {'type': 'Feature',
#    'properties': {'id': '542',
#     'nom': 'Claudius Collonge',
#     'desserte': '63A:A,63A:R,S1A:A,S1A:R',
#     'pmr': 'false',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '10801',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:10'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.821463302991127, 45.74798432448097]}},
#   {'type': 'Feature',
#    'properties': {'id': '585',
#     'nom': 'Collonges St Martin',
#     'desserte': 'S16A:R,S3B:R',
#     'pmr': 'false',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '10531',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:10'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.843958764532682, 45.81765171137535]}},
#   {'type': 'Feature',
#    'properties': {'id': '682',
#     'nom': 'Dauphine',
#     'desserte': '62A:A,87A:A',
#     'pmr': 'true',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '9377',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:10'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.952238046502822, 45.66299046423904]}},
#   {'type': 'Feature',
#    'properties': {'id': '693',
#     'nom': 'Debrousse',
#     'desserte': 'C19A:A',
#     'pmr': 'true',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '1290',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:10'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.812658687050715, 45.7483992423646]}},
#   {'type': 'Feature',
#    'properties': {'id': '47738',
#     'nom': 'Les Lavandes',
#     'desserte': '15F:R,18B:R',
#     'pmr': 'false',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '10803',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:13'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.803945453397975, 45.64579766195123]}},
#   {'type': 'Feature',
#    'properties': {'id': '47739',
#     'nom': 'Le Meridien',
#     'desserte': '5A:R,86A:R',
#     'pmr': 'false',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '10750',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:13'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.752449001212891, 45.774094360442916]}},
#   {'type': 'Feature',
#    'properties': {'id': '47740',
#     'nom': 'Ancienne Gare',
#     'desserte': '11B:A,73D:A,73E:A',
#     'pmr': 'false',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '10786',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:13'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.696516063471774, 45.71818095149072]}},
#   {'type': 'Feature',
#    'properties': {'id': '47741',
#     'nom': 'Piscine de Vaise',
#     'desserte': '19A:R,3A:R,66B:R',
#     'pmr': 'false',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '10726',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:13'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.796787123455652, 45.77078017533241]}},
#   {'type': 'Feature',
#    'properties': {'id': '47742',
#     'nom': "Irigny - Gare d'Yvours",
#     'desserte': '15F:R',
#     'pmr': 'false',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '10804',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:13'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.830905615712292, 45.69002165816063]}},
#   {'type': 'Feature',
#    'properties': {'id': '47743',
#     'nom': 'Val Rosay',
#     'desserte': '20A:A,2A:A,71A:A',
#     'pmr': 'false',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '10841',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:13'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.812107089108228, 45.793412975124454]}},
#   {'type': 'Feature',
#    'properties': {'id': '47744',
#     'nom': 'Champagne Centre',
#     'desserte': '21A:R,61B:R',
#     'pmr': 'false',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '10787',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:13'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.793102953483603, 45.79452001850936]}},
#   {'type': 'Feature',
#    'properties': {'id': '47745',
#     'nom': 'Bifurcation du Rosay',
#     'desserte': '20A:R,22A:R',
#     'pmr': 'true',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '10844',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:13'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.808492061574311, 45.791190998320786]}},
#   {'type': 'Feature',
#    'properties': {'id': '697',
#     'nom': 'Decines Champ Fleuri',
#     'desserte': '67A:A',
#     'pmr': 'true',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '10770',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:10'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.972319161755388, 45.77369585489877]}},
#   {'type': 'Feature',
#    'properties': {'id': '1817',
#     'nom': 'Louise Michel',
#     'desserte': '69A:R,C17A:A',
#     'pmr': 'true',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '10716',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:11'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.893728436693432, 45.77452182127272]}},
#   {'type': 'Feature',
#    'properties': {'id': '1822',
#     'nom': 'Luther King',
#     'desserte': '24A:A,C17A:A',
#     'pmr': 'true',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '2095',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:11'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.901216409120526, 45.73189321564186]}},
#   {'type': 'Feature',
#    'properties': {'id': '1866',
#     'nom': 'Mairie du 5eme',
#     'desserte': '46A:A,90B:R',
#     'pmr': 'true',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '2114',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:11'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.801065253275925, 45.75806624208645]}},
#   {'type': 'Feature',
#    'properties': {'id': '47746',
#     'nom': 'General Frere',
#     'desserte': '26A:R,79A:R',
#     'pmr': 'false',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '10751',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:13'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.886860372675921, 45.72722530939464]}},
#   {'type': 'Feature',
#    'properties': {'id': '2653',
#     'nom': 'Fryd - Gerland',
#     'desserte': '34A:R,64A:R',
#     'pmr': 'true',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '10092',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:11'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.83746242157684, 45.73019142130332]}},
#   {'type': 'Feature',
#    'properties': {'id': '2954',
#     'nom': 'Tassin Genetieres',
#     'desserte': '5A:A,5A:R,72C:R',
#     'pmr': 'true',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '9991',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:11'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.772141109574016, 45.75871639840283]}},
#   {'type': 'Feature',
#    'properties': {'id': '10017',
#     'nom': 'Francheville Bourg',
#     'desserte': 'C20D:A,C20E:A',
#     'pmr': 'true',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '3273',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:11'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.76448429360339, 45.73703938417742]}},
#   {'type': 'Feature',
#    'properties': {'id': '10033',
#     'nom': 'Z.I. Rocade Est',
#     'desserte': 'ZI5B:R',
#     'pmr': 'false',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '5405',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:11'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.977771163290933, 45.72341826936045]}},
#   {'type': 'Feature',
#    'properties': {'id': '43120',
#     'nom': 'Montchat Place Ronde',
#     'desserte': 'C26A:R',
#     'pmr': 'true',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '687',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:13'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.891899310585315, 45.75324308594694]}},
#   {'type': 'Feature',
#    'properties': {'id': '46498',
#     'nom': 'Sathonay Village Eglise',
#     'desserte': '77A:R',
#     'pmr': 'true',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '5502',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:13'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.878043557656289, 45.83152141484879]}},
#   {'type': 'Feature',
#    'properties': {'id': '46500',
#     'nom': 'La Rama',
#     'desserte': 'R3A:A,R3A:R',
#     'pmr': 'false',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '5506',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:13'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.749392154170081, 45.57803569417921]}},
#   {'type': 'Feature',
#    'properties': {'id': '46513',
#     'nom': 'Chemin de Crepieux',
#     'desserte': 'S5A:A',
#     'pmr': 'false',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '5503',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:13'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.879249018147972, 45.80175863817186]}},
#   {'type': 'Feature',
#    'properties': {'id': '46514',
#     'nom': 'Chemin de Crepieux',
#     'desserte': 'S5A:R',
#     'pmr': 'false',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '5504',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:13'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.879148127937394, 45.801928617442435]}},
#   {'type': 'Feature',
#    'properties': {'id': '47761',
#     'nom': 'Berliet - Lyonnais',
#     'desserte': '54A:A,87A:A,ZI1A:A',
#     'pmr': 'false',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '10731',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:13'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.896057565984181, 45.70275453781425]}},
#   {'type': 'Feature',
#    'properties': {'id': '43835',
#     'nom': 'Hôtel Région Montrochet',
#     'desserte': 'S1A:R',
#     'pmr': 'true',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '10886',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:13'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.818791708053788, 45.739568726230225]}},
#   {'type': 'Feature',
#    'properties': {'id': '45842',
#     'nom': 'Vaulx Place Boissier',
#     'desserte': '7A:A,83A:A',
#     'pmr': 'false',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '10883',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:13'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.925997190298202, 45.786598720078]}},
#   {'type': 'Feature',
#    'properties': {'id': '45864',
#     'nom': 'Archives Departementales',
#     'desserte': 'T4A:A,T4A:R',
#     'pmr': 'true',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '765',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:13'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.861789761225316, 45.75434634549679]}},
#   {'type': 'Feature',
#    'properties': {'id': '45885',
#     'nom': 'Fonderie',
#     'desserte': '83A:A',
#     'pmr': 'false',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '10868',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:13'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.918140124191135, 45.78233074646598]}},
#   {'type': 'Feature',
#    'properties': {'id': '46432',
#     'nom': 'Liauthaud',
#     'desserte': '81A:A',
#     'pmr': 'false',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '5418',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:13'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.760752155188618, 45.58957174448534]}},
#   {'type': 'Feature',
#    'properties': {'id': '46480',
#     'nom': 'Montee de Bianne',
#     'desserte': '32A:A',
#     'pmr': 'false',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '9202',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:13'},
#    'geometry': {'type': 'Point',
#     'coordinates': [5.087367754704125, 45.80374621047484]}},
#   {'type': 'Feature',
#    'properties': {'id': '46489',
#     'nom': 'Route de Bianne',
#     'desserte': '32A:R',
#     'pmr': 'false',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '9203',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:13'},
#    'geometry': {'type': 'Point',
#     'coordinates': [5.0872748311458, 45.80313417266991]}},
#   {'type': 'Feature',
#    'properties': {'id': '46495',
#     'nom': 'Centre Village',
#     'desserte': '77A:A,77A:R',
#     'pmr': 'false',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '5499',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:13'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.877447559764261, 45.833759409074894]}},
#   {'type': 'Feature',
#    'properties': {'id': '47762',
#     'nom': 'Les Pepinieres',
#     'desserte': '55B:A',
#     'pmr': 'false',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '10758',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:13'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.809171297467273, 45.7591652542319]}},
#   {'type': 'Feature',
#    'properties': {'id': '47763',
#     'nom': 'Route de Mions',
#     'desserte': '62A:R,C25B:R',
#     'pmr': 'false',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '10789',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:13'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.947689254414536, 45.684585507022526]}},
#   {'type': 'Feature',
#    'properties': {'id': '47765',
#     'nom': 'Mions Les Tilleuls',
#     'desserte': '62A:R,87A:R',
#     'pmr': 'false',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '10791',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:13'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.955581103123013, 45.669315482756225]}},
#   {'type': 'Feature',
#    'properties': {'id': '47775',
#     'nom': 'Langevin',
#     'desserte': '93A:R',
#     'pmr': 'false',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '10874',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:13'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.88084148705645, 45.701748574160256]}},
#   {'type': 'Feature',
#    'properties': {'id': '47780',
#     'nom': 'Orsel',
#     'desserte': 'C7B:R',
#     'pmr': 'false',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '10800',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:13'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.809862513433015, 45.71546358268933]}},
#   {'type': 'Feature',
#    'properties': {'id': '47781',
#     'nom': 'Les Sources',
#     'desserte': 'C14A:A,C14A:R,S15A:A,S15A:R',
#     'pmr': 'false',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '10829',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:13'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.78286197584006, 45.7923360881349]}},
#   {'type': 'Feature',
#    'properties': {'id': '47782',
#     'nom': 'Mont Louis',
#     'desserte': 'C14A:A,S15A:A',
#     'pmr': 'false',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '10830',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:13'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.787124994671088, 45.789299106277134]}},
#   {'type': 'Feature',
#    'properties': {'id': '235',
#     'nom': 'Bourdarias',
#     'desserte': 'C25B:R',
#     'pmr': 'true',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '9303',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:10'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.882435434504391, 45.7248743857795]}},
#   {'type': 'Feature',
#    'properties': {'id': '256',
#     'nom': 'Boutasse - C. Rousset',
#     'desserte': 'C17A:A',
#     'pmr': 'true',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '406',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:10'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.904198486012517, 45.73455073098701]}},
#   {'type': 'Feature',
#    'properties': {'id': '269',
#     'nom': 'Brossolette-Genas',
#     'desserte': '24A:A,25A:A,52A:R',
#     'pmr': 'true',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '9260',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:10'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.918121264869042, 45.74841003480584]}},
#   {'type': 'Feature',
#    'properties': {'id': '325',
#     'nom': 'Mermoz - Californie',
#     'desserte': 'C15A:A,PL2A:A',
#     'pmr': 'true',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '9757',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:10'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.878260676894259, 45.73347596444967]}},
#   {'type': 'Feature',
#    'properties': {'id': '328',
#     'nom': 'Caluire Centre',
#     'desserte': '33A:R,38A:R,38B:R,S5A:R',
#     'pmr': 'true',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '9758',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:10'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.848166040817118, 45.79903581271503]}},
#   {'type': 'Feature',
#    'properties': {'id': '360',
#     'nom': 'Centre Psychotherapique',
#     'desserte': 'S16A:A,S3B:A',
#     'pmr': 'false',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '10530',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:10'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.835984900443225, 45.81811864373236]}},
#   {'type': 'Feature',
#    'properties': {'id': '420',
#     'nom': 'Charles Richard',
#     'desserte': '25A:R,C26A:A',
#     'pmr': 'true',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '1102',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:10'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.887411268701787, 45.75047409505281]}},
#   {'type': 'Feature',
#    'properties': {'id': '428',
#     'nom': 'Charmet',
#     'desserte': '17B:R,C7B:R',
#     'pmr': 'true',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '1108',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:10'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.816483549957566, 45.697748721199076]}},
#   {'type': 'Feature',
#    'properties': {'id': '834',
#     'nom': 'Ecully Centre',
#     'desserte': '19A:R,3A:R',
#     'pmr': 'true',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '10712',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:10'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.779102743712339, 45.77448122904023]}},
#   {'type': 'Feature',
#    'properties': {'id': '853',
#     'nom': 'Entree de Decines',
#     'desserte': '67A:A',
#     'pmr': 'true',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '1395',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:10'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.934557157331896, 45.767436702568794]}},
#   {'type': 'Feature',
#    'properties': {'id': '873',
#     'nom': 'Etats-Unis Viviani',
#     'desserte': '26A:A',
#     'pmr': 'true',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '9759',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:10'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.870515479549677, 45.725406337595565]}},
#   {'type': 'Feature',
#    'properties': {'id': '901',
#     'nom': 'Felix Faure Vivier Merle',
#     'desserte': 'C11A:A',
#     'pmr': 'true',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '9414',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:10'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.858989502981674, 45.7535964906293]}},
#   {'type': 'Feature',
#    'properties': {'id': '912',
#     'nom': 'Feuillat - Lacassagne',
#     'desserte': '25A:R,C13A:A,C13B:A,C16A:R',
#     'pmr': 'false',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '1409',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:10'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.875108669638037, 45.75013667902249]}},
#   {'type': 'Feature',
#    'properties': {'id': '2579',
#     'nom': 'Republique - Reaux',
#     'desserte': '28A:R',
#     'pmr': 'false',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '9768',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:11'},
#    'geometry': {'type': 'Point',
#     'coordinates': [5.006860918881103, 45.730192471758066]}},
#   {'type': 'Feature',
#    'properties': {'id': '2580',
#     'nom': 'Republique - Reaux',
#     'desserte': '28A:A',
#     'pmr': 'false',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '9769',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:11'},
#    'geometry': {'type': 'Point',
#     'coordinates': [5.007551160471777, 45.73011303344651]}},
#   {'type': 'Feature',
#    'properties': {'id': '2619',
#     'nom': 'Rochetaillee',
#     'desserte': '40A:A,70A:A',
#     'pmr': 'true',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '9909',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:11'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.835017370271311, 45.84265456097211]}},
#   {'type': 'Feature',
#    'properties': {'id': '954',
#     'nom': 'Foucaud - Picasso',
#     'desserte': '57A:A',
#     'pmr': 'true',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '1435',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:10'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.921477293826322, 45.77402158815064]}},
#   {'type': 'Feature',
#    'properties': {'id': '10081',
#     'nom': 'St-Irenee - Cx Blanche',
#     'desserte': '46A:A,49A:A,C20D:A,C20E:A',
#     'pmr': 'true',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '3073',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:11'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.807754377057382, 45.75514110809671]}},
#   {'type': 'Feature',
#    'properties': {'id': '45886',
#     'nom': 'Fonderie',
#     'desserte': '83A:R',
#     'pmr': 'false',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '10869',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:13'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.918106201770807, 45.78229876065277]}},
#   {'type': 'Feature',
#    'properties': {'id': '45887',
#     'nom': 'Vaulx Jean Moulin',
#     'desserte': '83A:A',
#     'pmr': 'false',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '10870',
#     'last_update': '2021-03-25 01:31:17',
# ...
#     'last_update_fme': '2021-03-25 06:00:11'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.814894266416478, 45.76720720651439]}},
#   {'type': 'Feature',
#    'properties': {'id': '1182',
#     'nom': 'Hopital Lyon Sud',
#     'desserte': '17B:A,17B:R',
#     'pmr': 'true',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '1568',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:11'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.80630856966259, 45.69996572972026]}},
#   {'type': 'Feature',
#    'properties': {'id': '1221',
#     'nom': 'Irigny Mairie',
#     'desserte': '15C:R,15F:R',
#     'pmr': 'true',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '1585',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:11'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.822699457546256, 45.672824660974534]}},
#   {'type': 'Feature',
#    'properties': {'id': '1510',
#     'nom': 'Laurent Bonnevay',
#     'desserte': '57A:A,57A:R',
#     'pmr': 'true',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '229',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:11'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.908262194730447, 45.765125497074884]}},
#   {'type': 'Feature',
#    'properties': {'id': '1512',
#     'nom': 'Laurent Bonnevay',
#     'desserte': '67A:A,67A:R',
#     'pmr': 'true',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '5164',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:11'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.909093734082594, 45.76475539409875]}},
#   {'type': 'Feature',
#    'properties': {'id': '1673',
#     'nom': 'Les Esses',
#     'desserte': 'C13A:R,C13B:R,C18A:R',
#     'pmr': 'true',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '1967',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:11'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.817236362020267, 45.771800064841436]}},
#   {'type': 'Feature',
#    'properties': {'id': '1696',
#     'nom': 'Les Grillons',
#     'desserte': '68B:A',
#     'pmr': 'false',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '1989',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:11'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.958945211220945, 45.74642713144586]}},
#   {'type': 'Feature',
#    'properties': {'id': '1709',
#     'nom': 'Les Lauriers',
#     'desserte': '97A:A,97A:R',
#     'pmr': 'false',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '1996',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:11'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.86608223194194, 45.88077000296736]}},
#   {'type': 'Feature',
#    'properties': {'id': '1741',
#     'nom': 'Les Pepinieres',
#     'desserte': '55B:R',
#     'pmr': 'true',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '6059',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:11'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.808964669611873, 45.75918294646694]}},
#   {'type': 'Feature',
#    'properties': {'id': '1951',
#     'nom': 'Menival Centre',
#     'desserte': '65B:R,C21A:A',
#     'pmr': 'true',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '2170',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:11'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.785730252887004, 45.756928925959556]}},
#   {'type': 'Feature',
#    'properties': {'id': '2319',
#     'nom': 'Pierre-Benite Centre',
#     'desserte': '15C:R,18B:R,C7B:R',
#     'pmr': 'true',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '2420',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:11'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.820932264164171, 45.70360762189578]}},
#   {'type': 'Feature',
#    'properties': {'id': '2613',
#     'nom': 'Centre Culturel',
#     'desserte': 'S15A:A',
#     'pmr': 'false',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '2590',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:11'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.778867280322095, 45.77815875708593]}},
#   {'type': 'Feature',
#    'properties': {'id': '2698',
#     'nom': 'Saxe - Bonnel',
#     'desserte': 'C9A:A',
#     'pmr': 'true',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '2641',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:11'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.845930516564737, 45.76160320392736]}},
#   {'type': 'Feature',
#    'properties': {'id': '2702',
#     'nom': 'Saxe - Gambetta',
#     'desserte': 'C12A:R',
#     'pmr': 'true',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '199',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:11'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.846288303299103, 45.754223219321936]}},
#   {'type': 'Feature',
#    'properties': {'id': '2759',
#     'nom': 'St-Alexandre',
#     'desserte': '55B:A,C20D:A,C21A:A',
#     'pmr': 'true',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '2690',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:11'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.815079064724896, 45.75646480976425]}},
#   {'type': 'Feature',
#    'properties': {'id': '2897',
#     'nom': 'Stade de Parilly',
#     'desserte': 'C25B:R',
#     'pmr': 'true',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '2778',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:11'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.891879738343539, 45.7172883349801]}},
#   {'type': 'Feature',
#    'properties': {'id': '3124',
#     'nom': 'Victor Hugo',
#     'desserte': '62A:A,87A:A',
#     'pmr': 'true',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '2954',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:11'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.949342111311572, 45.662792559569205]}},
#   {'type': 'Feature',
#    'properties': {'id': '3125',
#     'nom': 'Victor Hugo',
#     'desserte': '62A:R,87A:R',
#     'pmr': 'true',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '2953',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:11'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.949454079704033, 45.66298798324237]}},
#   {'type': 'Feature',
#    'properties': {'id': '10018',
#     'nom': 'Francheville Bourg',
#     'desserte': 'C20D:R,C20E:R',
#     'pmr': 'true',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '3272',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:11'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.764071523204976, 45.736715280829635]}},
#   {'type': 'Feature',
#    'properties': {'id': '43945',
#     'nom': 'Cimetiere de St-Priest',
#     'desserte': '30B:R',
#     'pmr': 'true',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '3091',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:13'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.946375301915402, 45.69203573797305]}},
#   {'type': 'Feature',
#    'properties': {'id': '45852',
#     'nom': 'Parc Lyder',
#     'desserte': '62A:A',
#     'pmr': 'true',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '3604',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:13'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.909095478025558, 45.708621457996934]}},
#   {'type': 'Feature',
#    'properties': {'id': '45856',
#     'nom': 'Charlie Chaplin',
#     'desserte': '62A:A',
#     'pmr': 'true',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '5036',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:13'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.912566426161668, 45.71106641723426]}},
#   {'type': 'Feature',
#    'properties': {'id': '45870',
#     'nom': 'Lycee Colbert',
#     'desserte': 'T4A:R',
#     'pmr': 'true',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '753',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:13'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.859026122258117, 45.7455881661212]}},
#   {'type': 'Feature',
#    'properties': {'id': '46151',
#     'nom': 'Part-Dieu Servient',
#     'desserte': '38A:A,38B:A,C13A:A,C13B:A,C25B:R',
#     'pmr': 'true',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '429',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:13'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.852179222357435, 45.7609630758551]}},
#   {'type': 'Feature',
#    'properties': {'id': '46154',
#     'nom': 'Musée des Confluences',
#     'desserte': 'T1A:R',
#     'pmr': 'true',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '773',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:13'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.818881717108439, 45.73359802567545]}},
#   {'type': 'Feature',
#    'properties': {'id': '46155',
#     'nom': 'Halle Tony Garnier',
#     'desserte': 'T1A:A',
#     'pmr': 'true',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '784',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:13'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.822883249456253, 45.73171930117249]}},
#   {'type': 'Feature',
#    'properties': {'id': '46156',
#     'nom': 'Halle Tony Garnier',
#     'desserte': 'T1A:R',
#     'pmr': 'true',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '781',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:13'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.822873868542968, 45.731690885548794]}},
#   {'type': 'Feature',
#    'properties': {'id': '46157',
#     'nom': 'ENS Lyon',
#     'desserte': 'T1A:A',
#     'pmr': 'true',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '788',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:13'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.82885055096414, 45.73145785005577]}},
#   {'type': 'Feature',
#    'properties': {'id': '47408',
#     'nom': 'J.Jaures - Malherbe',
#     'desserte': '95A:A',
#     'pmr': 'true',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '9970',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:13'},
#    'geometry': {'type': 'Point',
#     'coordinates': [5.015805053998155, 45.77168894278703]}},
#   {'type': 'Feature',
#    'properties': {'id': '47409',
#     'nom': 'Fenelon',
#     'desserte': '95A:A,ZI2A:A',
#     'pmr': 'false',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '9971',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:13'},
#    'geometry': {'type': 'Point',
#     'coordinates': [5.018967021534516, 45.775027894216926]}},
#   {'type': 'Feature',
#    'properties': {'id': '47410',
#     'nom': 'Jonage Le Vivier',
#     'desserte': '95A:A',
#     'pmr': 'false',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '9972',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:13'},
#    'geometry': {'type': 'Point',
#     'coordinates': [5.053652940553616, 45.79868102596905]}},
#   {'type': 'Feature',
#    'properties': {'id': '529',
#     'nom': 'Hopital St Jean de Dieu',
#     'desserte': 'C12A:A',
#     'pmr': 'true',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '1172',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:10'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.853985459814939, 45.72426245118035]}},
#   {'type': 'Feature',
#    'properties': {'id': '658',
#     'nom': 'Curis la Planche',
#     'desserte': '84A:A,R2A:A',
#     'pmr': 'true',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '1267',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:10'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.823242795819041, 45.87224672377827]}},
#   {'type': 'Feature',
#    'properties': {'id': '897',
#     'nom': 'Collège Plan du Loup',
#     'desserte': 'C19A:A',
#     'pmr': 'true',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '725',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:10'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.788379208705846, 45.73528672012571]}},
#   {'type': 'Feature',
#    'properties': {'id': '931',
#     'nom': 'Foch',
#     'desserte': '27A:R,C4A:R',
#     'pmr': 'true',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '306',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:10'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.843950265327451, 45.76827008454548]}},
#   {'type': 'Feature',
#    'properties': {'id': '1157',
#     'nom': 'Henriette',
#     'desserte': '45B:R,65B:A',
#     'pmr': 'true',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '1548',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:11'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.786306240466579, 45.74883139482326]}},
#   {'type': 'Feature',
#    'properties': {'id': '1190',
#     'nom': 'Hôtel de Ville L. Pradel',
#     'desserte': 'C13B:A,C14A:A,C3A:R,PL2A:A',
#     'pmr': 'false',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '113',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:11'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.836089388765163, 45.767196435783355]}},
#   {'type': 'Feature',
#    'properties': {'id': '1476',
#     'nom': 'La Vosne',
#     'desserte': '97A:A',
#     'pmr': 'false',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '1797',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:11'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.848982893768294, 45.87661648688708]}},
#   {'type': 'Feature',
#    'properties': {'id': '47420',
#     'nom': 'Rd Pt Charles de Gaulle',
#     'desserte': '26A:R',
#     'pmr': 'true',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '9853',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:13'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.929696361393763, 45.726606294185316]}},
#   {'type': 'Feature',
#    'properties': {'id': '47422',
#     'nom': 'Galline',
#     'desserte': '69A:A',
#     'pmr': 'false',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '9855',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:13'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.868190164743088, 45.77632690300168]}},
#   {'type': 'Feature',
#    'properties': {'id': '47423',
#     'nom': 'Dumas',
#     'desserte': '69A:A',
#     'pmr': 'false',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '9856',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:13'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.887262216228566, 45.776515875620625]}},
#   {'type': 'Feature',
#    'properties': {'id': '47424',
#     'nom': 'Joliot-Curie - M. Sembat',
#     'desserte': '79A:A',
#     'pmr': 'true',
#     'ascenseur': 'false',
#     'escalator': 'false',
#     'gid': '9677',
#     'last_update': '2021-03-25 01:31:17',
#     'last_update_fme': '2021-03-25 06:00:13'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.878414483234351, 45.71384646727943]}},
#   ...]}

# %%
#lyon_transports_json

# %%
# Out:
# [{'nom': 'Vaulx Pasteur',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '37A:R,57A:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 10894,
#   'last_update_fme': '2021-03-25 06:00:11',
#   'id': 3070},
#  {'nom': 'Charmettes',
#   'escalator': False,
#   'pmr': True,
#   'desserte': 'C16A:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 824,
#   'last_update_fme': '2021-03-25 06:00:10',
#   'id': 50},
#  {'nom': 'Ampere',
#   'escalator': False,
#   'pmr': False,
#   'desserte': 'S16A:A,S3B:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 10529,
#   'last_update_fme': '2021-03-25 06:00:10',
#   'id': 55},
#  {'nom': 'Anatole France',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '39A:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 9567,
#   'last_update_fme': '2021-03-25 06:00:10',
#   'id': 58},
#  {'nom': 'Andre Boulloche',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '93A:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 9543,
#   'last_update_fme': '2021-03-25 06:00:10',
#   'id': 64},
#  {'nom': 'Aqueducs de Beaunant',
#   'escalator': False,
#   'pmr': False,
#   'desserte': '11B:R,12B:R,14B:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 10656,
#   'last_update_fme': '2021-03-25 06:00:10',
#   'id': 73},
#  {'nom': 'Batterie',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '24A:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 10702,
#   'last_update_fme': '2021-03-25 06:00:10',
#   'id': 140},
#  {'nom': 'Berthaudiere',
#   'escalator': False,
#   'pmr': False,
#   'desserte': '67A:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 10769,
#   'last_update_fme': '2021-03-25 06:00:10',
#   'id': 197},
#  {'nom': 'Bon Coin - Medipole',
#   'escalator': False,
#   'pmr': True,
#   'desserte': 'C11A:A,C17A:R,C3A:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 9522,
#   'last_update_fme': '2021-03-25 06:00:10',
#   'id': 227},
#  {'nom': 'Minimes Théatres Romains',
#   'escalator': False,
#   'pmr': False,
#   'desserte': '346A:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 10893,
#   'last_update_fme': '2021-03-25 06:00:12',
#   'id': 10884},
#  {'nom': 'Hénon',
#   'escalator': False,
#   'pmr': False,
#   'desserte': 'C13A:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 10897,
#   'last_update_fme': '2021-03-25 06:00:12',
#   'id': 30362},
#  {'nom': 'Vaulx - Marcel Cachin',
#   'escalator': False,
#   'pmr': False,
#   'desserte': '37A:A,37A:R,57A:A,57A:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 10895,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 43217},
#  {'nom': 'Vaulx - Marcel Cachin',
#   'escalator': False,
#   'pmr': False,
#   'desserte': '57A:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 10896,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 43937},
#  {'nom': 'J. B. Simon',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '40A:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 10887,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 47563},
#  {'nom': 'Grd Parc Miribel Jonage',
#   'escalator': False,
#   'pmr': False,
#   'desserte': '83A:A,83A:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 10885,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 47677},
#  {'nom': 'Pressense - Marrane',
#   'escalator': False,
#   'pmr': False,
#   'desserte': '35A:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 10728,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 47748},
#  {'nom': 'Egalite - Farrere',
#   'escalator': False,
#   'pmr': False,
#   'desserte': 'C25B:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 10795,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 47783},
#  {'nom': 'Les Halles 102 - 104',
#   'escalator': False,
#   'pmr': False,
#   'desserte': '5A:A,86A:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 10753,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 47784},
#  {'nom': 'Les Halles 102 - 104',
#   'escalator': False,
#   'pmr': False,
#   'desserte': '5A:R,86A:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 10754,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 47785},
#  {'nom': 'Place Morel',
#   'escalator': False,
#   'pmr': False,
#   'desserte': 'S12A:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 10850,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 47791},
#  {'nom': "Rochette Cercle d'Aviron",
#   'escalator': False,
#   'pmr': False,
#   'desserte': 'S5A:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 10881,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 47796},
#  {'nom': 'Carrefour Liberation',
#   'escalator': False,
#   'pmr': False,
#   'desserte': '5A:A,5A:R,73D:R,C21A:A,C21A:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 10755,
#   'last_update_fme': '2021-03-25 06:00:10',
#   'id': 352},
#  {'nom': 'Gare de Villeurbanne',
#   'escalator': False,
#   'pmr': True,
#   'desserte': 'C26A:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 553,
#   'last_update_fme': '2021-03-25 06:00:10',
#   'id': 443},
#  {'nom': 'Diderot',
#   'escalator': False,
#   'pmr': True,
#   'desserte': 'C7B:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 9018,
#   'last_update_fme': '2021-03-25 06:00:10',
#   'id': 753},
#  {'nom': 'Dumas - Salengro',
#   'escalator': False,
#   'pmr': False,
#   'desserte': '52A:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 10842,
#   'last_update_fme': '2021-03-25 06:00:10',
#   'id': 802},
#  {'nom': 'Duquesne - Foch',
#   'escalator': False,
#   'pmr': True,
#   'desserte': 'C6C:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 10463,
#   'last_update_fme': '2021-03-25 06:00:10',
#   'id': 808},
#  {'nom': 'Gabriel Rosset',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '34A:R,64A:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 10091,
#   'last_update_fme': '2021-03-25 06:00:11',
#   'id': 988},
#  {'nom': 'Grand Vire',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '83A:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 10861,
#   'last_update_fme': '2021-03-25 06:00:11',
#   'id': 1070},
#  {'nom': 'Caluire - Bords de Saone',
#   'escalator': False,
#   'pmr': False,
#   'desserte': '40A:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 10888,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 47797},
#  {'nom': 'Caluire - Bords de Saone',
#   'escalator': False,
#   'pmr': False,
#   'desserte': '40A:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 10889,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 47799},
#  {'nom': 'Les Meurieres',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '62A:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 10772,
#   'last_update_fme': '2021-03-25 06:00:11',
#   'id': 1718},
#  {'nom': 'Limonest Centre',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '21A:A,942A:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 2073,
#   'last_update_fme': '2021-03-25 06:00:11',
#   'id': 1794},
#  {'nom': 'Longefer',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '24A:A,34A:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 2081,
#   'last_update_fme': '2021-03-25 06:00:11',
#   'id': 1804},
#  {'nom': 'Longefer',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '24A:R,34A:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 2080,
#   'last_update_fme': '2021-03-25 06:00:11',
#   'id': 1805},
#  {'nom': 'Quatre Chemins',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '147:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 10617,
#   'last_update_fme': '2021-03-25 06:00:11',
#   'id': 2560},
#  {'nom': 'Place des Buers',
#   'escalator': False,
#   'pmr': False,
#   'desserte': 'C17A:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 10892,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 47801},
#  {'nom': 'St Nizier',
#   'escalator': False,
#   'pmr': False,
#   'desserte': 'S1A:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 10890,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 47804},
#  {'nom': 'Esplanade Mitterrand',
#   'escalator': False,
#   'pmr': False,
#   'desserte': 'S1A:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 10891,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 47805},
#  {'nom': 'Pont De Lattre RD',
#   'escalator': False,
#   'pmr': True,
#   'desserte': 'C6C:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 10472,
#   'last_update_fme': '2021-03-25 06:00:11',
#   'id': 2496},
#  {'nom': 'Charmettes',
#   'escalator': False,
#   'pmr': True,
#   'desserte': 'C16A:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 821,
#   'last_update_fme': '2021-03-25 06:00:10',
#   'id': 51},
#  {'nom': 'Andre Brun',
#   'escalator': False,
#   'pmr': False,
#   'desserte': '16A:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 837,
#   'last_update_fme': '2021-03-25 06:00:10',
#   'id': 66},
#  {'nom': 'Arago',
#   'escalator': False,
#   'pmr': True,
#   'desserte': 'C11A:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 844,
#   'last_update_fme': '2021-03-25 06:00:10',
#   'id': 75},
#  {'nom': 'Ayasse - Yves Farge',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '34A:A,C7B:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 9387,
#   'last_update_fme': '2021-03-25 06:00:10',
#   'id': 98},
#  {'nom': 'Bir Hakeim',
#   'escalator': False,
#   'pmr': True,
#   'desserte': 'C11A:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 9413,
#   'last_update_fme': '2021-03-25 06:00:10',
#   'id': 204},
#  {'nom': 'Fontaines Centre',
#   'escalator': False,
#   'pmr': False,
#   'desserte': '77A:A,77A:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 10802,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 46635},
#  {'nom': 'Fontaines Petit Moulin',
#   'escalator': False,
#   'pmr': False,
#   'desserte': '40A:A,70A:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 5724,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 46639},
#  {'nom': 'Meyzieu Bascule',
#   'escalator': False,
#   'pmr': False,
#   'desserte': '85A:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 6603,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 46878},
#  {'nom': 'Charton',
#   'escalator': False,
#   'pmr': True,
#   'desserte': 'C7B:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 5858,
#   'last_update_fme': '2021-03-25 06:00:10',
#   'id': 444},
#  {'nom': 'Moulin à Vent',
#   'escalator': False,
#   'pmr': True,
#   'desserte': 'T6:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 10055,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 47291},
#  {'nom': 'Chassieu Mairie',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '68B:R,76A:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 10249,
#   'last_update_fme': '2021-03-25 06:00:10',
#   'id': 452},
#  {'nom': 'Chazay',
#   'escalator': False,
#   'pmr': True,
#   'desserte': 'C20D:A,C20E:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 1125,
#   'last_update_fme': '2021-03-25 06:00:10',
#   'id': 463},
#  {'nom': 'Chemin Bressan',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '43A:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 1126,
#   'last_update_fme': '2021-03-25 06:00:10',
#   'id': 466},
#  {'nom': 'Chemin de Grange Blanche',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '54A:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 1129,
#   'last_update_fme': '2021-03-25 06:00:10',
#   'id': 467},
#  {'nom': "Rond-Point d'Italie",
#   'escalator': False,
#   'pmr': False,
#   'desserte': '48B:R,ZI5B:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 10234,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 47622},
#  {'nom': 'Calmette - Muriers',
#   'escalator': False,
#   'pmr': False,
#   'desserte': 'ZI5B:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 10235,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 47623},
#  {'nom': 'Cyrano',
#   'escalator': False,
#   'pmr': True,
#   'desserte': 'C9A:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 10757,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 47680},
#  {'nom': 'Gymnase Frison Roche',
#   'escalator': False,
#   'pmr': False,
#   'desserte': '93A:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 10873,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 47730},
#  {'nom': 'Joannes Carret',
#   'escalator': False,
#   'pmr': False,
#   'desserte': '31A:A,31A:R,43A:A,S10A:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 10687,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 47732},
#  {'nom': "St-Rambert - l'Ile Barbe",
#   'escalator': False,
#   'pmr': False,
#   'desserte': '31A:A,43A:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 10701,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 47733},
#  {'nom': 'Caluire Chemin Petit',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '70A:R,S5A:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 1138,
#   'last_update_fme': '2021-03-25 06:00:10',
#   'id': 484},
#  {'nom': 'Valpre',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '19A:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 1144,
#   'last_update_fme': '2021-03-25 06:00:10',
#   'id': 490},
#  {'nom': "Cimetiere d'Oullins",
#   'escalator': False,
#   'pmr': True,
#   'desserte': 'C7B:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 9017,
#   'last_update_fme': '2021-03-25 06:00:10',
#   'id': 502},
#  {'nom': 'Claudius Collonge',
#   'escalator': False,
#   'pmr': False,
#   'desserte': '63A:A,63A:R,S1A:A,S1A:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 10801,
#   'last_update_fme': '2021-03-25 06:00:10',
#   'id': 542},
#  {'nom': 'Collonges St Martin',
#   'escalator': False,
#   'pmr': False,
#   'desserte': 'S16A:R,S3B:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 10531,
#   'last_update_fme': '2021-03-25 06:00:10',
#   'id': 585},
#  {'nom': 'Dauphine',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '62A:A,87A:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 9377,
#   'last_update_fme': '2021-03-25 06:00:10',
#   'id': 682},
#  {'nom': 'Debrousse',
#   'escalator': False,
#   'pmr': True,
#   'desserte': 'C19A:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 1290,
#   'last_update_fme': '2021-03-25 06:00:10',
#   'id': 693},
#  {'nom': 'Les Lavandes',
#   'escalator': False,
#   'pmr': False,
#   'desserte': '15F:R,18B:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 10803,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 47738},
#  {'nom': 'Le Meridien',
#   'escalator': False,
#   'pmr': False,
#   'desserte': '5A:R,86A:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 10750,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 47739},
#  {'nom': 'Ancienne Gare',
#   'escalator': False,
#   'pmr': False,
#   'desserte': '11B:A,73D:A,73E:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 10786,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 47740},
#  {'nom': 'Piscine de Vaise',
#   'escalator': False,
#   'pmr': False,
#   'desserte': '19A:R,3A:R,66B:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 10726,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 47741},
#  {'nom': "Irigny - Gare d'Yvours",
#   'escalator': False,
#   'pmr': False,
#   'desserte': '15F:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 10804,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 47742},
#  {'nom': 'Val Rosay',
#   'escalator': False,
#   'pmr': False,
#   'desserte': '20A:A,2A:A,71A:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 10841,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 47743},
#  {'nom': 'Champagne Centre',
#   'escalator': False,
#   'pmr': False,
#   'desserte': '21A:R,61B:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 10787,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 47744},
#  {'nom': 'Bifurcation du Rosay',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '20A:R,22A:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 10844,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 47745},
#  {'nom': 'Decines Champ Fleuri',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '67A:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 10770,
#   'last_update_fme': '2021-03-25 06:00:10',
#   'id': 697},
#  {'nom': 'Louise Michel',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '69A:R,C17A:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 10716,
#   'last_update_fme': '2021-03-25 06:00:11',
#   'id': 1817},
#  {'nom': 'Luther King',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '24A:A,C17A:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 2095,
#   'last_update_fme': '2021-03-25 06:00:11',
#   'id': 1822},
#  {'nom': 'Mairie du 5eme',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '46A:A,90B:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 2114,
#   'last_update_fme': '2021-03-25 06:00:11',
#   'id': 1866},
#  {'nom': 'General Frere',
#   'escalator': False,
#   'pmr': False,
#   'desserte': '26A:R,79A:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 10751,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 47746},
#  {'nom': 'Fryd - Gerland',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '34A:R,64A:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 10092,
#   'last_update_fme': '2021-03-25 06:00:11',
#   'id': 2653},
#  {'nom': 'Tassin Genetieres',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '5A:A,5A:R,72C:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 9991,
#   'last_update_fme': '2021-03-25 06:00:11',
#   'id': 2954},
#  {'nom': 'Francheville Bourg',
#   'escalator': False,
#   'pmr': True,
#   'desserte': 'C20D:A,C20E:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 3273,
#   'last_update_fme': '2021-03-25 06:00:11',
#   'id': 10017},
#  {'nom': 'Z.I. Rocade Est',
#   'escalator': False,
#   'pmr': False,
#   'desserte': 'ZI5B:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 5405,
#   'last_update_fme': '2021-03-25 06:00:11',
#   'id': 10033},
#  {'nom': 'Montchat Place Ronde',
#   'escalator': False,
#   'pmr': True,
#   'desserte': 'C26A:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 687,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 43120},
#  {'nom': 'Sathonay Village Eglise',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '77A:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 5502,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 46498},
#  {'nom': 'La Rama',
#   'escalator': False,
#   'pmr': False,
#   'desserte': 'R3A:A,R3A:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 5506,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 46500},
#  {'nom': 'Chemin de Crepieux',
#   'escalator': False,
#   'pmr': False,
#   'desserte': 'S5A:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 5503,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 46513},
#  {'nom': 'Chemin de Crepieux',
#   'escalator': False,
#   'pmr': False,
#   'desserte': 'S5A:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 5504,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 46514},
#  {'nom': 'Berliet - Lyonnais',
#   'escalator': False,
#   'pmr': False,
#   'desserte': '54A:A,87A:A,ZI1A:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 10731,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 47761},
#  {'nom': 'Hôtel Région Montrochet',
#   'escalator': False,
#   'pmr': True,
#   'desserte': 'S1A:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 10886,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 43835},
#  {'nom': 'Vaulx Place Boissier',
#   'escalator': False,
#   'pmr': False,
#   'desserte': '7A:A,83A:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 10883,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 45842},
#  {'nom': 'Archives Departementales',
#   'escalator': False,
#   'pmr': True,
#   'desserte': 'T4A:A,T4A:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 765,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 45864},
#  {'nom': 'Fonderie',
#   'escalator': False,
#   'pmr': False,
#   'desserte': '83A:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 10868,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 45885},
#  {'nom': 'Liauthaud',
#   'escalator': False,
#   'pmr': False,
#   'desserte': '81A:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 5418,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 46432},
#  {'nom': 'Montee de Bianne',
#   'escalator': False,
#   'pmr': False,
#   'desserte': '32A:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 9202,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 46480},
#  {'nom': 'Route de Bianne',
#   'escalator': False,
#   'pmr': False,
#   'desserte': '32A:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 9203,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 46489},
#  {'nom': 'Centre Village',
#   'escalator': False,
#   'pmr': False,
#   'desserte': '77A:A,77A:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 5499,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 46495},
#  {'nom': 'Les Pepinieres',
#   'escalator': False,
#   'pmr': False,
#   'desserte': '55B:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 10758,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 47762},
#  {'nom': 'Route de Mions',
#   'escalator': False,
#   'pmr': False,
#   'desserte': '62A:R,C25B:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 10789,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 47763},
#  {'nom': 'Mions Les Tilleuls',
#   'escalator': False,
#   'pmr': False,
#   'desserte': '62A:R,87A:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 10791,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 47765},
#  {'nom': 'Langevin',
#   'escalator': False,
#   'pmr': False,
#   'desserte': '93A:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 10874,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 47775},
#  {'nom': 'Orsel',
#   'escalator': False,
#   'pmr': False,
#   'desserte': 'C7B:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 10800,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 47780},
#  {'nom': 'Les Sources',
#   'escalator': False,
#   'pmr': False,
#   'desserte': 'C14A:A,C14A:R,S15A:A,S15A:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 10829,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 47781},
#  {'nom': 'Mont Louis',
#   'escalator': False,
#   'pmr': False,
#   'desserte': 'C14A:A,S15A:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 10830,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 47782},
#  {'nom': 'Bourdarias',
#   'escalator': False,
#   'pmr': True,
#   'desserte': 'C25B:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 9303,
#   'last_update_fme': '2021-03-25 06:00:10',
#   'id': 235},
#  {'nom': 'Boutasse - C. Rousset',
#   'escalator': False,
#   'pmr': True,
#   'desserte': 'C17A:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 406,
#   'last_update_fme': '2021-03-25 06:00:10',
#   'id': 256},
#  {'nom': 'Brossolette-Genas',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '24A:A,25A:A,52A:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 9260,
#   'last_update_fme': '2021-03-25 06:00:10',
#   'id': 269},
#  {'nom': 'Mermoz - Californie',
#   'escalator': False,
#   'pmr': True,
#   'desserte': 'C15A:A,PL2A:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 9757,
#   'last_update_fme': '2021-03-25 06:00:10',
#   'id': 325},
#  {'nom': 'Caluire Centre',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '33A:R,38A:R,38B:R,S5A:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 9758,
#   'last_update_fme': '2021-03-25 06:00:10',
#   'id': 328},
#  {'nom': 'Centre Psychotherapique',
#   'escalator': False,
#   'pmr': False,
#   'desserte': 'S16A:A,S3B:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 10530,
#   'last_update_fme': '2021-03-25 06:00:10',
#   'id': 360},
#  {'nom': 'Charles Richard',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '25A:R,C26A:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 1102,
#   'last_update_fme': '2021-03-25 06:00:10',
#   'id': 420},
#  {'nom': 'Charmet',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '17B:R,C7B:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 1108,
#   'last_update_fme': '2021-03-25 06:00:10',
#   'id': 428},
#  {'nom': 'Ecully Centre',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '19A:R,3A:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 10712,
#   'last_update_fme': '2021-03-25 06:00:10',
#   'id': 834},
#  {'nom': 'Entree de Decines',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '67A:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 1395,
#   'last_update_fme': '2021-03-25 06:00:10',
#   'id': 853},
#  {'nom': 'Etats-Unis Viviani',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '26A:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 9759,
#   'last_update_fme': '2021-03-25 06:00:10',
#   'id': 873},
#  {'nom': 'Felix Faure Vivier Merle',
#   'escalator': False,
#   'pmr': True,
#   'desserte': 'C11A:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 9414,
#   'last_update_fme': '2021-03-25 06:00:10',
#   'id': 901},
#  {'nom': 'Feuillat - Lacassagne',
#   'escalator': False,
#   'pmr': False,
#   'desserte': '25A:R,C13A:A,C13B:A,C16A:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 1409,
#   'last_update_fme': '2021-03-25 06:00:10',
#   'id': 912},
#  {'nom': 'Republique - Reaux',
#   'escalator': False,
#   'pmr': False,
#   'desserte': '28A:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 9768,
#   'last_update_fme': '2021-03-25 06:00:11',
#   'id': 2579},
#  {'nom': 'Republique - Reaux',
#   'escalator': False,
#   'pmr': False,
#   'desserte': '28A:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 9769,
#   'last_update_fme': '2021-03-25 06:00:11',
#   'id': 2580},
#  {'nom': 'Rochetaillee',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '40A:A,70A:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 9909,
#   'last_update_fme': '2021-03-25 06:00:11',
#   'id': 2619},
#  {'nom': 'Foucaud - Picasso',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '57A:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 1435,
#   'last_update_fme': '2021-03-25 06:00:10',
#   'id': 954},
#  {'nom': 'St-Irenee - Cx Blanche',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '46A:A,49A:A,C20D:A,C20E:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 3073,
#   'last_update_fme': '2021-03-25 06:00:11',
#   'id': 10081},
#  {'nom': 'Fonderie',
#   'escalator': False,
#   'pmr': False,
#   'desserte': '83A:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 10869,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 45886},
#  {'nom': 'Vaulx Jean Moulin',
#   'escalator': False,
#   'pmr': False,
#   'desserte': '83A:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 10870,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 45887},
#  {'nom': 'Vaulx Jean Moulin',
#   'escalator': False,
#   'pmr': False,
#   'desserte': '83A:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 10871,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 45888},
#  {'nom': 'Lucien Maitre',
#   'escalator': False,
#   'pmr': True,
#   'desserte': 'S5A:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 5115,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 46070},
#  {'nom': 'Vieux Crepieux',
#   'escalator': False,
#   'pmr': False,
#   'desserte': 'S5A:A,S5A:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 5505,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 46515},
#  {'nom': 'Genas Place Republique',
#   'escalator': False,
#   'pmr': False,
#   'desserte': '28A:R,48B:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 9760,
#   'last_update_fme': '2021-03-25 06:00:11',
#   'id': 1018},
#  {'nom': 'Genas Place Republique',
#   'escalator': False,
#   'pmr': False,
#   'desserte': '28A:A,48B:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 9761,
#   'last_update_fme': '2021-03-25 06:00:11',
#   'id': 1019},
#  {'nom': 'Danton - Republique',
#   'escalator': False,
#   'pmr': False,
#   'desserte': '28A:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 9762,
#   'last_update_fme': '2021-03-25 06:00:11',
#   'id': 1026},
#  {'nom': 'La Begude',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '39A:R,60A:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 5964,
#   'last_update_fme': '2021-03-25 06:00:11',
#   'id': 1315},
#  {'nom': 'La Buissonniere',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '77A:A,77A:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 5969,
#   'last_update_fme': '2021-03-25 06:00:11',
#   'id': 1332},
#  {'nom': 'La Croix de Solaize',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '39A:A,39A:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 9568,
#   'last_update_fme': '2021-03-25 06:00:11',
#   'id': 1365},
#  {'nom': 'Elisee Reclus',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '79A:R,ZI3A:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 9674,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 46518},
#  {'nom': 'Bifurcation du Rosay',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '20A:R,2A:R,71A:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 5518,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 46523},
#  {'nom': "Parc Tete d'Or Churchill",
#   'escalator': False,
#   'pmr': False,
#   'desserte': 'C4A:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 9820,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 46593},
#  {'nom': 'Antoine Roybet',
#   'escalator': False,
#   'pmr': False,
#   'desserte': '29A:R,48B:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 5583,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 46601},
#  {'nom': 'Reaux Roybet',
#   'escalator': False,
#   'pmr': False,
#   'desserte': '29A:R,48B:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 5585,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 46603},
#  {'nom': 'La Feuillee',
#   'escalator': False,
#   'pmr': False,
#   'desserte': '31A:A,31A:R,40A:A,40A:R,PL2A:A,PL3A:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 10447,
#   'last_update_fme': '2021-03-25 06:00:11',
#   'id': 1377},
#  {'nom': 'La Foret',
#   'escalator': False,
#   'pmr': False,
#   'desserte': '84A:A,R2A:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 5995,
#   'last_update_fme': '2021-03-25 06:00:11',
#   'id': 1389},
#  {'nom': 'La Gabrielle',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '115A:R,118A:R,21A:R,61B:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 9270,
#   'last_update_fme': '2021-03-25 06:00:11',
#   'id': 1393},
#  {'nom': 'La Pagere - Les Brosses',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '24A:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 10703,
#   'last_update_fme': '2021-03-25 06:00:11',
#   'id': 1426},
#  {'nom': 'La Pelletiere',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '132:A,171:A,S8A:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 6024,
#   'last_update_fme': '2021-03-25 06:00:11',
#   'id': 1431},
#  {'nom': 'La Roue',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '33A:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 6034,
#   'last_update_fme': '2021-03-25 06:00:11',
#   'id': 1445},
#  {'nom': 'La Sarra',
#   'escalator': False,
#   'pmr': False,
#   'desserte': '90B:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 6036,
#   'last_update_fme': '2021-03-25 06:00:11',
#   'id': 1449},
#  {'nom': 'La Saulaie',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '15C:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 10402,
#   'last_update_fme': '2021-03-25 06:00:11',
#   'id': 1452},
#  {'nom': 'La Vernique',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '19A:R,3A:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 10713,
#   'last_update_fme': '2021-03-25 06:00:11',
#   'id': 1470},
#  {'nom': 'Laurent Bonnevay',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '83A:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 10862,
#   'last_update_fme': '2021-03-25 06:00:11',
#   'id': 1504},
#  {'nom': 'R.N.6 - A. Pare',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '29A:A,29A:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 1841,
#   'last_update_fme': '2021-03-25 06:00:11',
#   'id': 1529},
#  {'nom': 'Le Gregoire',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '3A:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 1850,
#   'last_update_fme': '2021-03-25 06:00:11',
#   'id': 1542},
#  {'nom': 'Le Rotagnier',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '68B:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 10346,
#   'last_update_fme': '2021-03-25 06:00:11',
#   'id': 1575},
#  {'nom': 'Les Selettes',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '15F:R,18B:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 1937,
#   'last_update_fme': '2021-03-25 06:00:11',
#   'id': 1641},
#  {'nom': 'Les Cotes',
#   'escalator': False,
#   'pmr': False,
#   'desserte': '15C:A,15F:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 1951,
#   'last_update_fme': '2021-03-25 06:00:11',
#   'id': 1656},
#  {'nom': 'Les Grillons',
#   'escalator': False,
#   'pmr': False,
#   'desserte': '68B:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 1990,
#   'last_update_fme': '2021-03-25 06:00:11',
#   'id': 1697},
#  {'nom': 'Les Hautannes',
#   'escalator': False,
#   'pmr': False,
#   'desserte': '96A:A,96A:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 9907,
#   'last_update_fme': '2021-03-25 06:00:11',
#   'id': 1700},
#  {'nom': 'Les Meurieres',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '62A:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 10771,
#   'last_update_fme': '2021-03-25 06:00:11',
#   'id': 1717},
#  {'nom': 'Caluire - Bords de Saone',
#   'escalator': False,
#   'pmr': False,
#   'desserte': 'S5A:A,S5A:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 10882,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 47798},
#  {'nom': "Avenue de l'Industrie",
#   'escalator': False,
#   'pmr': True,
#   'desserte': '76A:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 856,
#   'last_update_fme': '2021-03-25 06:00:10',
#   'id': 93},
#  {'nom': 'Cite Ribaud',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '28A:R,68B:A,ZI5B:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 1174,
#   'last_update_fme': '2021-03-25 06:00:10',
#   'id': 531},
#  {'nom': 'Feuillat Freres Lumiere',
#   'escalator': False,
#   'pmr': True,
#   'desserte': 'C16A:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 1407,
#   'last_update_fme': '2021-03-25 06:00:10',
#   'id': 910},
#  {'nom': 'Croix-Rousse',
#   'escalator': False,
#   'pmr': True,
#   'desserte': 'C13A:A,C13A:R,C13B:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 10299,
#   'last_update_fme': '2021-03-25 06:00:11',
#   'id': 2367},
#  {'nom': 'Pont De Lattre RD',
#   'escalator': False,
#   'pmr': True,
#   'desserte': 'C6C:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 10471,
#   'last_update_fme': '2021-03-25 06:00:11',
#   'id': 2495},
#  {'nom': 'Bel Air - Aubepines',
#   'escalator': False,
#   'pmr': True,
#   'desserte': 'C24E:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 706,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 46100},
#  {'nom': 'Danton - Republique',
#   'escalator': False,
#   'pmr': False,
#   'desserte': '28A:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 9763,
#   'last_update_fme': '2021-03-25 06:00:11',
#   'id': 1027},
#  {'nom': 'Bel Air - Aubepines',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '73E:R,C24E:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 705,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 46101},
#  {'nom': 'Thurins Les Vergers',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '11B:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 4968,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 46111},
#  {'nom': 'La Croix des Hormes',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '97A:A,97A:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 5186,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 46119},
#  {'nom': "Gare d'Oullins",
#   'escalator': False,
#   'pmr': True,
#   'desserte': '11B:R,12B:R,14B:R,18B:R,328A:A,328A:R,78B:R,88B:A,88B:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 739,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 46120},
#  {'nom': 'Les Provences',
#   'escalator': False,
#   'pmr': True,
#   'desserte': 'C19A:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 9640,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 47368},
#  {'nom': 'Allende - Egalite',
#   'escalator': False,
#   'pmr': False,
#   'desserte': '37A:R,57A:R,C8A:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 10351,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 47639},
#  {'nom': 'Vaulx-en-Velin Aragon',
#   'escalator': False,
#   'pmr': False,
#   'desserte': '37A:R,57A:R,C8A:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 10352,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 47640},
#  {'nom': 'Grandclement',
#   'escalator': False,
#   'pmr': True,
#   'desserte': 'C11A:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 9904,
#   'last_update_fme': '2021-03-25 06:00:11',
#   'id': 1076},
#  {'nom': 'Gros Platane',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '40A:A,70A:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 9905,
#   'last_update_fme': '2021-03-25 06:00:11',
#   'id': 1114},
#  {'nom': 'Gros Platane',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '40A:R,70A:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 9906,
#   'last_update_fme': '2021-03-25 06:00:11',
#   'id': 1115},
#  {'nom': 'Saxe - Préfecture',
#   'escalator': False,
#   'pmr': True,
#   'desserte': 'C9A:A,C9A:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 421,
#   'last_update_fme': '2021-03-25 06:00:11',
#   'id': 1122},
#  {'nom': 'Hôtel de Ville L. Pradel',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '132:R,171:R,9A:R,9B:R,C5A:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 116,
#   'last_update_fme': '2021-03-25 06:00:11',
#   'id': 1191},
#  {'nom': 'Ile Barbe',
#   'escalator': False,
#   'pmr': False,
#   'desserte': '40A:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 1575,
#   'last_update_fme': '2021-03-25 06:00:11',
#   'id': 1206},
#  {'nom': 'Impasse Mathieu',
#   'escalator': False,
#   'pmr': True,
#   'desserte': 'C1A:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 1580,
#   'last_update_fme': '2021-03-25 06:00:11',
#   'id': 1213},
#  {'nom': "L'Aigas",
#   'escalator': False,
#   'pmr': True,
#   'desserte': '98G:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 5956,
#   'last_update_fme': '2021-03-25 06:00:11',
#   'id': 1295},
#  {'nom': 'Gare de Francheville',
#   'escalator': False,
#   'pmr': True,
#   'desserte': 'C20D:A,C20E:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 9764,
#   'last_update_fme': '2021-03-25 06:00:11',
#   'id': 1308},
#  {'nom': 'Marius Poncet',
#   'escalator': False,
#   'pmr': False,
#   'desserte': '72C:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 10773,
#   'last_update_fme': '2021-03-25 06:00:11',
#   'id': 1916},
#  {'nom': 'Marne Pagere',
#   'escalator': False,
#   'pmr': False,
#   'desserte': '24A:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 10704,
#   'last_update_fme': '2021-03-25 06:00:11',
#   'id': 1921},
#  {'nom': 'Mermoz - Moselle',
#   'escalator': False,
#   'pmr': True,
#   'desserte': 'PL2A:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 10590,
#   'last_update_fme': '2021-03-25 06:00:11',
#   'id': 2090},
#  {'nom': 'Mermoz - Moselle',
#   'escalator': False,
#   'pmr': True,
#   'desserte': 'C15A:A,C15A:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 10177,
#   'last_update_fme': '2021-03-25 06:00:11',
#   'id': 2091},
#  {'nom': 'Moulin à Vent',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '34A:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 10744,
#   'last_update_fme': '2021-03-25 06:00:11',
#   'id': 2095},
#  {'nom': 'Grd Parc Miribel Jonage',
#   'escalator': False,
#   'pmr': False,
#   'desserte': '83A:A,83A:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 10863,
#   'last_update_fme': '2021-03-25 06:00:11',
#   'id': 2176},
#  {'nom': 'Part-Dieu Renaudel',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '25A:A,C13A:R,C13B:R,C7B:A,C9A:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 10700,
#   'last_update_fme': '2021-03-25 06:00:11',
#   'id': 2212},
#  {'nom': 'Gare Part-Dieu V.Merle',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '328A:A,70A:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 10454,
#   'last_update_fme': '2021-03-25 06:00:11',
#   'id': 2230},
#  {'nom': 'Pierre Joseph Proudhon',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '69A:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 10717,
#   'last_update_fme': '2021-03-25 06:00:11',
#   'id': 2330},
#  {'nom': 'Grange Bruyere',
#   'escalator': False,
#   'pmr': True,
#   'desserte': 'C20D:A,C20E:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 10387,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 47644},
#  {'nom': 'Lycee Jean Perrin',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '20A:A,2A:A,71A:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 10354,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 47645},
#  {'nom': 'Veyrie',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '86A:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 2946,
#   'last_update_fme': '2021-03-25 06:00:11',
#   'id': 3118},
#  {'nom': 'Avenue de la Paix',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '5A:A,86A:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 859,
#   'last_update_fme': '2021-03-25 06:00:10',
#   'id': 94},
#  {'nom': 'Chemin des Moulins',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '17B:A,C7B:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 1130,
#   'last_update_fme': '2021-03-25 06:00:10',
#   'id': 473},
#  {'nom': "L'Hormet",
#   'escalator': False,
#   'pmr': True,
#   'desserte': 'C19A:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 5959,
#   'last_update_fme': '2021-03-25 06:00:11',
#   'id': 1303},
#  {'nom': "Rochette Cercle d'Aviron",
#   'escalator': False,
#   'pmr': False,
#   'desserte': '40A:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 6033,
#   'last_update_fme': '2021-03-25 06:00:11',
#   'id': 1444},
#  {'nom': 'La Roue',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '33A:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 6035,
#   'last_update_fme': '2021-03-25 06:00:11',
#   'id': 1446},
#  {'nom': 'Nicolas Sicard',
#   'escalator': False,
#   'pmr': True,
#   'desserte': 'C21A:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 3032,
#   'last_update_fme': '2021-03-25 06:00:11',
#   'id': 3388},
#  {'nom': 'Lionel Terray',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '26A:R,C15A:R,C17A:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 3077,
#   'last_update_fme': '2021-03-25 06:00:11',
#   'id': 3498},
#  {'nom': 'Fourvière',
#   'escalator': False,
#   'pmr': False,
#   'desserte': '346A:A,346A:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 10877,
#   'last_update_fme': '2021-03-25 06:00:12',
#   'id': 10877},
#  {'nom': 'Meyzieu Z.i.',
#   'escalator': False,
#   'pmr': False,
#   'desserte': '47A:A,47A:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 10379,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 47647},
#  {'nom': 'Camping International',
#   'escalator': False,
#   'pmr': False,
#   'desserte': '3A:A,89D:A,89E:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 10620,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 47649},
#  {'nom': 'Dardilly Les Mouilles',
#   'escalator': False,
#   'pmr': False,
#   'desserte': '3A:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 10625,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 47650},
#  {'nom': 'Lycee Agroalimentaire',
#   'escalator': False,
#   'pmr': False,
#   'desserte': '78B:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 10421,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 47653},
#  {'nom': 'Champvert - Les Massues',
#   'escalator': False,
#   'pmr': False,
#   'desserte': '46A:R,90B:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 10756,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 47657},
#  {'nom': 'La Buissiere Viralamande',
#   'escalator': False,
#   'pmr': False,
#   'desserte': '132:A,171:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 10580,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 47660},
#  {'nom': 'La Vuldy',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '72C:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 1803,
#   'last_update_fme': '2021-03-25 06:00:11',
#   'id': 1479},
#  {'nom': 'Le Broteau',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '18B:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 1834,
#   'last_update_fme': '2021-03-25 06:00:11',
#   'id': 1524},
#  {'nom': 'Les Places',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '73D:R,73E:R',
#   'last_update': '2021-03-25 01:31:17',
# ...
#   'pmr': True,
#   'desserte': '63A:A,63A:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 2174,
#   'last_update_fme': '2021-03-25 06:00:11',
#   'id': 1959},
#  {'nom': 'Pierre-Benite Centre',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '15C:A,18B:A,C7B:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 2421,
#   'last_update_fme': '2021-03-25 06:00:11',
#   'id': 2318},
#  {'nom': 'Sathonay Mairie',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '9A:A,9B:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 2633,
#   'last_update_fme': '2021-03-25 06:00:11',
#   'id': 2686},
#  {'nom': 'Sathonay Mutualite',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '33A:R,9A:R,9B:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 2637,
#   'last_update_fme': '2021-03-25 06:00:11',
#   'id': 2689},
#  {'nom': 'Tassin Combattants',
#   'escalator': False,
#   'pmr': False,
#   'desserte': '86A:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 2812,
#   'last_update_fme': '2021-03-25 06:00:11',
#   'id': 2947},
#  {'nom': 'Vianney',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '89D:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 2951,
#   'last_update_fme': '2021-03-25 06:00:11',
#   'id': 3123},
#  {'nom': 'Z.I. Rillieux 8 mai 1945',
#   'escalator': False,
#   'pmr': False,
#   'desserte': 'ZI4A:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 3042,
#   'last_update_fme': '2021-03-25 06:00:11',
#   'id': 3410},
#  {'nom': 'Jean Baptiste Perret',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '71A:R,S16A:R,S3B:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 4344,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 41760},
#  {'nom': 'Francheville Taffignon',
#   'escalator': False,
#   'pmr': True,
#   'desserte': 'C19A:A,C19A:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 1054,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 41778},
#  {'nom': 'Nelli',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '52A:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 4829,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 43299},
#  {'nom': 'C. Cial Sept Chemins',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '52A:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 4833,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 43301},
#  {'nom': 'Parilly Univ. Hippodrome',
#   'escalator': False,
#   'pmr': False,
#   'desserte': '52A:A,52A:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 4819,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 43302},
#  {'nom': 'Beauregard',
#   'escalator': False,
#   'pmr': False,
#   'desserte': 'S9A:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 4867,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 43636},
#  {'nom': 'La Vosne',
#   'escalator': False,
#   'pmr': False,
#   'desserte': 'S14A:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 1798,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 43880},
#  {'nom': 'Torrieres',
#   'escalator': False,
#   'pmr': False,
#   'desserte': 'S14A:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 4904,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 43881},
#  {'nom': 'Vaulx - Marcel Cachin',
#   'escalator': False,
#   'pmr': False,
#   'desserte': '37A:A,57A:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 4822,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 43936},
#  {'nom': 'Bellecour A. Poncet',
#   'escalator': False,
#   'pmr': True,
#   'desserte': 'C10A:A,C10A:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 9812,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 44598},
#  {'nom': 'Grange Blanche',
#   'escalator': False,
#   'pmr': True,
#   'desserte': 'T5:A,T5:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 9138,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 45271},
#  {'nom': 'College Balzac',
#   'escalator': False,
#   'pmr': True,
#   'desserte': 'C16A:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 4944,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 45279},
#  {'nom': 'Vaulx Lamartine',
#   'escalator': False,
#   'pmr': False,
#   'desserte': '7A:R,83A:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 2909,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 45889},
#  {'nom': 'Vaulx Lakanal',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '7A:R,83A:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 2908,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 45891},
#  {'nom': 'Noisetiers',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '10D:A,10D:R,GE4A:A,GE4A:R,S3B:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 5045,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 45907},
#  {'nom': 'Joseph Moulin',
#   'escalator': False,
#   'pmr': True,
#   'desserte': 'C24E:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 3236,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 46102},
#  {'nom': 'Grigny Jean Moulin',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '80A:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 5126,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 46140},
#  {'nom': 'Peroniere',
#   'escalator': False,
#   'pmr': False,
#   'desserte': '84A:A,84A:R,R2A:A,R2A:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 5132,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 46148},
#  {'nom': 'Clos des Chassagnes',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '17B:R,8B:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 1207,
#   'last_update_fme': '2021-03-25 06:00:10',
#   'id': 562},
#  {'nom': 'La Mulatiere Mairie',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '17B:A,8B:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 1370,
#   'last_update_fme': '2021-03-25 06:00:10',
#   'id': 832},
#  {'nom': 'Grandclement',
#   'escalator': False,
#   'pmr': True,
#   'desserte': 'C11A:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 1500,
#   'last_update_fme': '2021-03-25 06:00:11',
#   'id': 1077},
#  {'nom': 'Greillon',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '19A:A,31A:A,40A:A,C14A:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 1516,
#   'last_update_fme': '2021-03-25 06:00:11',
#   'id': 1108},
#  {'nom': 'Hopital Lyon Sud',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '17B:A,17B:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 1568,
#   'last_update_fme': '2021-03-25 06:00:11',
#   'id': 1182},
#  {'nom': 'Irigny Mairie',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '15C:R,15F:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 1585,
#   'last_update_fme': '2021-03-25 06:00:11',
#   'id': 1221},
#  {'nom': 'Laurent Bonnevay',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '57A:A,57A:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 229,
#   'last_update_fme': '2021-03-25 06:00:11',
#   'id': 1510},
#  {'nom': 'Laurent Bonnevay',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '67A:A,67A:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 5164,
#   'last_update_fme': '2021-03-25 06:00:11',
#   'id': 1512},
#  {'nom': 'Les Esses',
#   'escalator': False,
#   'pmr': True,
#   'desserte': 'C13A:R,C13B:R,C18A:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 1967,
#   'last_update_fme': '2021-03-25 06:00:11',
#   'id': 1673},
#  {'nom': 'Les Grillons',
#   'escalator': False,
#   'pmr': False,
#   'desserte': '68B:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 1989,
#   'last_update_fme': '2021-03-25 06:00:11',
#   'id': 1696},
#  {'nom': 'Les Lauriers',
#   'escalator': False,
#   'pmr': False,
#   'desserte': '97A:A,97A:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 1996,
#   'last_update_fme': '2021-03-25 06:00:11',
#   'id': 1709},
#  {'nom': 'Les Pepinieres',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '55B:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 6059,
#   'last_update_fme': '2021-03-25 06:00:11',
#   'id': 1741},
#  {'nom': 'Menival Centre',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '65B:R,C21A:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 2170,
#   'last_update_fme': '2021-03-25 06:00:11',
#   'id': 1951},
#  {'nom': 'Pierre-Benite Centre',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '15C:R,18B:R,C7B:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 2420,
#   'last_update_fme': '2021-03-25 06:00:11',
#   'id': 2319},
#  {'nom': 'Centre Culturel',
#   'escalator': False,
#   'pmr': False,
#   'desserte': 'S15A:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 2590,
#   'last_update_fme': '2021-03-25 06:00:11',
#   'id': 2613},
#  {'nom': 'Saxe - Bonnel',
#   'escalator': False,
#   'pmr': True,
#   'desserte': 'C9A:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 2641,
#   'last_update_fme': '2021-03-25 06:00:11',
#   'id': 2698},
#  {'nom': 'Saxe - Gambetta',
#   'escalator': False,
#   'pmr': True,
#   'desserte': 'C12A:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 199,
#   'last_update_fme': '2021-03-25 06:00:11',
#   'id': 2702},
#  {'nom': 'St-Alexandre',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '55B:A,C20D:A,C21A:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 2690,
#   'last_update_fme': '2021-03-25 06:00:11',
#   'id': 2759},
#  {'nom': 'Stade de Parilly',
#   'escalator': False,
#   'pmr': True,
#   'desserte': 'C25B:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 2778,
#   'last_update_fme': '2021-03-25 06:00:11',
#   'id': 2897},
#  {'nom': 'Victor Hugo',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '62A:A,87A:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 2954,
#   'last_update_fme': '2021-03-25 06:00:11',
#   'id': 3124},
#  {'nom': 'Victor Hugo',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '62A:R,87A:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 2953,
#   'last_update_fme': '2021-03-25 06:00:11',
#   'id': 3125},
#  {'nom': 'Francheville Bourg',
#   'escalator': False,
#   'pmr': True,
#   'desserte': 'C20D:R,C20E:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 3272,
#   'last_update_fme': '2021-03-25 06:00:11',
#   'id': 10018},
#  {'nom': 'Cimetiere de St-Priest',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '30B:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 3091,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 43945},
#  {'nom': 'Parc Lyder',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '62A:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 3604,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 45852},
#  {'nom': 'Charlie Chaplin',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '62A:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 5036,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 45856},
#  {'nom': 'Lycee Colbert',
#   'escalator': False,
#   'pmr': True,
#   'desserte': 'T4A:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 753,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 45870},
#  {'nom': 'Part-Dieu Servient',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '38A:A,38B:A,C13A:A,C13B:A,C25B:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 429,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 46151},
#  {'nom': 'Musée des Confluences',
#   'escalator': False,
#   'pmr': True,
#   'desserte': 'T1A:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 773,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 46154},
#  {'nom': 'Halle Tony Garnier',
#   'escalator': False,
#   'pmr': True,
#   'desserte': 'T1A:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 784,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 46155},
#  {'nom': 'Halle Tony Garnier',
#   'escalator': False,
#   'pmr': True,
#   'desserte': 'T1A:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 781,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 46156},
#  {'nom': 'ENS Lyon',
#   'escalator': False,
#   'pmr': True,
#   'desserte': 'T1A:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 788,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 46157},
#  {'nom': 'J.Jaures - Malherbe',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '95A:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 9970,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 47408},
#  {'nom': 'Fenelon',
#   'escalator': False,
#   'pmr': False,
#   'desserte': '95A:A,ZI2A:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 9971,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 47409},
#  {'nom': 'Jonage Le Vivier',
#   'escalator': False,
#   'pmr': False,
#   'desserte': '95A:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 9972,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 47410},
#  {'nom': 'Hopital St Jean de Dieu',
#   'escalator': False,
#   'pmr': True,
#   'desserte': 'C12A:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 1172,
#   'last_update_fme': '2021-03-25 06:00:10',
#   'id': 529},
#  {'nom': 'Curis la Planche',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '84A:A,R2A:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 1267,
#   'last_update_fme': '2021-03-25 06:00:10',
#   'id': 658},
#  {'nom': 'Collège Plan du Loup',
#   'escalator': False,
#   'pmr': True,
#   'desserte': 'C19A:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 725,
#   'last_update_fme': '2021-03-25 06:00:10',
#   'id': 897},
#  {'nom': 'Foch',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '27A:R,C4A:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 306,
#   'last_update_fme': '2021-03-25 06:00:10',
#   'id': 931},
#  {'nom': 'Henriette',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '45B:R,65B:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 1548,
#   'last_update_fme': '2021-03-25 06:00:11',
#   'id': 1157},
#  {'nom': 'Hôtel de Ville L. Pradel',
#   'escalator': False,
#   'pmr': False,
#   'desserte': 'C13B:A,C14A:A,C3A:R,PL2A:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 113,
#   'last_update_fme': '2021-03-25 06:00:11',
#   'id': 1190},
#  {'nom': 'La Vosne',
#   'escalator': False,
#   'pmr': False,
#   'desserte': '97A:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 1797,
#   'last_update_fme': '2021-03-25 06:00:11',
#   'id': 1476},
#  {'nom': 'Rd Pt Charles de Gaulle',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '26A:R',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 9853,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 47420},
#  {'nom': 'Galline',
#   'escalator': False,
#   'pmr': False,
#   'desserte': '69A:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 9855,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 47422},
#  {'nom': 'Dumas',
#   'escalator': False,
#   'pmr': False,
#   'desserte': '69A:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 9856,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 47423},
#  {'nom': 'Joliot-Curie - M. Sembat',
#   'escalator': False,
#   'pmr': True,
#   'desserte': '79A:A',
#   'last_update': '2021-03-25 01:31:17',
#   'ascenseur': False,
#   'gid': 9677,
#   'last_update_fme': '2021-03-25 06:00:13',
#   'id': 47424}]

# %%
lyon_transports = lyon_transports_json["values"]

# %%
import json 
with open('lyon_bikes_records.json', 'w') as fp:
   json.dump(data_lyon, fp,ensure_ascii=False)

# %%
lyon_transports = pd.DataFrame()
for i in range(len(lyon_transports_json)):
    
    stop_name = paris_traports_array[i]["fields"]["stop_name"]
    latitude = paris_traports_array[i]["fields"]["stop_coordinates"][0]
    longitude = paris_traports_array[i]["fields"]["stop_coordinates"][1]
    
    list_to_append = [stop_name,latitude,longitude]
    line_labels = ['stop_name'] + ['latitude'] + ['longitude']
    dic = {line_labels[i]: list_to_append[i] for i in range(len(list_to_append))}   
    paris_transports = paris_transports.append(dic,ignore_index=True)

# %%
#lyon_transports_json

# %% [markdown]
# ### Lyon Velos

# %%
lyon_velos_file = open("originalJSON/lyon_velos.json","r")
lyon_velos_json= json.load(lyon_velos_file)

# %%
paris_transports = pd.DataFrame()
for i in range(len(paris_traports_array)):
    
    stop_name = paris_traports_array[i]["fields"]["stop_name"]
    latitude = paris_traports_array[i]["fields"]["stop_coordinates"][0]
    longitude = paris_traports_array[i]["fields"]["stop_coordinates"][1]
    
    list_to_append = [stop_name,latitude,longitude]
    line_labels = ['stop_name'] + ['latitude'] + ['longitude']
    dic = {line_labels[i]: list_to_append[i] for i in range(len(list_to_append))}   
    paris_transports = paris_transports.append(dic,ignore_index=True)

# %%
paris_transports = pd.DataFrame()
for i in range(len(paris_traports_array)):
    
    stop_name = paris_traports_array[i]["fields"]["stop_name"]
    latitude = paris_traports_array[i]["fields"]["stop_coordinates"][0]
    longitude = paris_traports_array[i]["fields"]["stop_coordinates"][1]
    
    list_to_append = [stop_name,latitude,longitude]
    line_labels = ['stop_name'] + ['latitude'] + ['longitude']
    dic = {line_labels[i]: list_to_append[i] for i in range(len(list_to_append))}   
    paris_transports = paris_transports.append(dic,ignore_index=True)

# %%
lyon_velos_file = open("originalJSON/lyon4.json","r")
lyon_velos_json= json.load(lyon_velos_file)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-12-c1c9512aa472> in <module>
#       1 lyon_velos_file = open("originalJSON/lyon4.json","r")
# ----> 2 lyon_velos_json= json.load(lyon_velos_file)
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/json/__init__.py in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
#     295         parse_float=parse_float, parse_int=parse_int,
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     344             parse_int is None and parse_float is None and
#     345             parse_constant is None and object_pairs_hook is None and not kw):
# --> 346         return _default_decoder.decode(s)
#     347     if cls is None:
#     348         cls = JSONDecoder
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/json/decoder.py in decode(self, s, _w)
#     338         end = _w(s, end).end()
#     339         if end != len(s):
# --> 340             raise JSONDecodeError("Extra data", s, end)
#     341         return obj
#     342
#
# JSONDecodeError: Extra data: line 1 column 79049 (char 79048)
