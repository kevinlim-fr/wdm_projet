# %%
import requests

url_lyon = 'https://download.data.grandlyon.com/wfs/rdata?SERVICE=WFS&VERSION=1.1.0&outputformat=GEOJSON&request=GetFeature&typename=jcd_jcdecaux.jcdvelov&SRSNAME=urn:ogc:def:crs:EPSG::4171'
data_lyon = requests.get(url_lyon).json()

data_lyon
# Out:
# {'type': 'FeatureCollection',
#  'name': 'jcd_jcdecaux.jcdvelov',
#  'features': [{'type': 'Feature',
#    'properties': {'number': '7038',
#     'name': 'Place Stalingard',
#     'address': 'Place Stalingrad',
#     'address2': 'Angle avec Grande Rue de la Guillotière',
#     'commune': 'Lyon 7 ème',
#     'nmarrond': '38',
#     'bonus': '',
#     'pole': 'maillage',
#     'lat': '45.7495788810534300',
#     'lng': '4.8529655050157780',
#     'bike_stands': '13',
#     'status': 'OPEN',
#     'available_bike_stands': '10',
#     'available_bikes': '2',
#     'availabilitycode': '1',
#     'availability': 'Vert',
#     'banking': 'false',
#     'gid': '944',
#     'last_update': '2021-03-24 15:57:59',
#     'last_update_fme': '2021-03-24 16:02:02',
#     'code_insee': '69387',
#     'langue': '',
#     'etat': '',
#     'nature': '',
#     'titre': '',
#     'description': '',
#     'startdate': '',
#     'enddate': ''},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.852965505015778, 45.74957888105343]}},
#   {'type': 'Feature',
#    'properties': {'number': '4007',
#     'name': 'Place Flammarion',
#     'address': 'Place Flammarion',
#     'address2': 'côté Rue Philippe de Lassalle',
#     'commune': 'Lyon 4 ème',
#     'nmarrond': '7',
#     'bonus': '',
#     'pole': 'maillage',
#     'lat': '45.7793264516606800',
#     'lng': '4.8203031984414520',
#     'bike_stands': '18',
#     'status': 'OPEN',
#     'available_bike_stands': '3',
#     'available_bikes': '12',
#     'availabilitycode': '1',
#     'availability': 'Vert',
#     'banking': 'false',
#     'gid': '873',
#     'last_update': '2021-03-24 15:57:04',
#     'last_update_fme': '2021-03-24 16:02:03',
#     'code_insee': '69384',
#     'langue': '',
#     'etat': '',
#     'nature': '',
#     'titre': '',
#     'description': '',
#     'startdate': '',
#     'enddate': ''},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.820303198441452, 45.77932645166068]}},
#   {'type': 'Feature',
#    'properties': {'number': '5002',
#     'name': 'Place des Compagnons de la chanson',
#     'address': 'Place des Compagnons de la chanson',
#     'address2': 'angle Rue des Aqueducs',
#     'commune': 'Lyon 5 ème',
#     'nmarrond': '2',
#     'bonus': '',
#     'pole': 'funiculaire, coeur quartier',
#     'lat': '45.7565273368784000',
#     'lng': '4.7966121788894250',
#     'bike_stands': '18',
#     'status': 'OPEN',
#     'available_bike_stands': '10',
#     'available_bikes': '8',
#     'availabilitycode': '1',
#     'availability': 'Vert',
#     'banking': 'false',
#     'gid': '1039',
#     'last_update': '2021-03-24 15:56:04',
#     'last_update_fme': '2021-03-24 16:02:03',
#     'code_insee': '69385',
#     'langue': '',
#     'etat': '',
#     'nature': '',
#     'titre': '',
#     'description': '',
#     'startdate': '',
#     'enddate': ''},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.796612178889425, 45.7565273368784]}},
#   {'type': 'Feature',
#    'properties': {'number': '9042',
#     'name': 'Vaise Docks',
#     'address': 'Face 50, Rue des Docks',
#     'address2': '',
#     'commune': 'Lyon 9 ème',
#     'nmarrond': '42',
#     'bonus': '',
#     'pole': 'Complexe cinéma Pathé',
#     'lat': '45.7865084443620300',
#     'lng': '4.8114412174203720',
#     'bike_stands': '19',
#     'status': 'OPEN',
#     'available_bike_stands': '7',
#     'available_bikes': '12',
#     'availabilitycode': '1',
#     'availability': 'Vert',
#     'banking': 'false',
#     'gid': '1022',
#     'last_update': '2021-03-24 16:00:25',
#     'last_update_fme': '2021-03-24 16:02:03',
#     'code_insee': '69389',
#     'langue': '',
#     'etat': '',
#     'nature': '',
#     'titre': '',
#     'description': '',
#     'startdate': '',
#     'enddate': ''},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.811441217420372, 45.78650844436203]}},
#   {'type': 'Feature',
#    'properties': {'number': '7013',
#     'name': 'Halle Tony Garnier',
#     'address': '8, Avenue Tony Garnier',
#     'address2': 'Angle Rue Pierre Riboulet',
#     'commune': 'Lyon 7 ème',
#     'nmarrond': '13',
#     'bonus': '',
#     'pole': 'Halle Tony Garnier',
#     'lat': '45.7308422388673200',
#     'lng': '4.8237404067653960',
#     'bike_stands': '20',
#     'status': 'OPEN',
#     'available_bike_stands': '7',
#     'available_bikes': '13',
#     'availabilitycode': '1',
#     'availability': 'Vert',
#     'banking': 'false',
#     'gid': '1094',
#     'last_update': '2021-03-24 15:57:05',
#     'last_update_fme': '2021-03-24 16:02:03',
#     'code_insee': '69387',
#     'langue': '',
#     'etat': '',
#     'nature': '',
#     'titre': '',
#     'description': '',
#     'startdate': '',
#     'enddate': ''},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.823740406765396, 45.73084223886732]}},
#   {'type': 'Feature',
#    'properties': {'number': '3053',
#     'name': 'Gambetta / Jusserand',
#     'address': '97, Avenue Jules Jusserand',
#     'address2': 'Angle Cours Gambetta',
#     'commune': 'Lyon 3 ème',
#     'nmarrond': '53',
#     'bonus': '',
#     'pole': 'bureaux, itinéraire cyclable',
#     'lat': '45.7511124102764400',
#     'lng': '4.8555850883006510',
#     'bike_stands': '13',
#     'status': 'OPEN',
#     'available_bike_stands': '9',
#     'available_bikes': '4',
#     'availabilitycode': '1',
#     'availability': 'Vert',
#     'banking': 'false',
#     'gid': '1051',
#     'last_update': '2021-03-24 15:57:40',
#     'last_update_fme': '2021-03-24 16:02:03',
#     'code_insee': '69383',
#     'langue': '',
#     'etat': '',
#     'nature': '',
#     'titre': '',
#     'description': '',
#     'startdate': '',
#     'enddate': ''},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.855585088300651, 45.75111241027644]}},
#   {'type': 'Feature',
#    'properties': {'number': '2024',
#     'name': 'République / Maupin',
#     'address': '9, Rue Maupin',
#     'address2': 'Angle Rue Président Edouard Herriot',
#     'commune': 'Lyon 2 ème',
#     'nmarrond': '24',
#     'bonus': '',
#     'pole': 'commerces',
#     'lat': '45.7587390821938500',
#     'lng': '4.8340765154131455',
#     'bike_stands': '25',
#     'status': 'OPEN',
#     'available_bike_stands': '0',
#     'available_bikes': '25',
#     'availabilitycode': '2',
#     'availability': 'Bleu',
#     'banking': 'false',
#     'gid': '1028',
#     'last_update': '2021-03-24 15:58:36',
#     'last_update_fme': '2021-03-24 16:02:03',
#     'code_insee': '69382',
#     'langue': '',
#     'etat': '',
#     'nature': '',
#     'titre': '',
#     'description': '',
#     'startdate': '',
#     'enddate': ''},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.834076515413146, 45.75873908219385]}},
#   {'type': 'Feature',
#    'properties': {'number': '26001',
#     'name': 'Saint Didier - Pasteur / Saint-Cyr',
#     'address': '113, Rue de St Cyr',
#     'address2': '',
#     'commune': "SAINT-DIDIER-AU-MONT-D'OR",
#     'nmarrond': '',
#     'bonus': '',
#     'pole': ' ',
#     'lat': '45.7915736750577340',
#     'lng': '4.8085346353439210',
#     'bike_stands': '17',
#     'status': 'OPEN',
#     'available_bike_stands': '15',
#     'available_bikes': '2',
#     'availabilitycode': '1',
#     'availability': 'Vert',
#     'banking': 'false',
#     'gid': '1276',
#     'last_update': '2021-03-24 15:57:02',
#     'last_update_fme': '2021-03-24 16:02:03',
#     'code_insee': '69194',
#     'langue': '',
#     'etat': '',
#     'nature': '',
#     'titre': '',
#     'description': '',
#     'startdate': '',
#     'enddate': ''},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.808534635343921, 45.791573675057734]}},
#   {'type': 'Feature',
#    'properties': {'number': '7014',
#     'name': 'Marseille / Félissent',
#     'address': '3, Rue Félissent',
#     'address2': 'angle Rue de Marseille',
#     'commune': 'Lyon 7 ème',
#     'nmarrond': '14',
#     'bonus': '',
#     'pole': 'maillage',
#     'lat': '45.7529863435116100',
#     'lng': '4.8414152874617790',
#     'bike_stands': '30',
#     'status': 'OPEN',
#     'available_bike_stands': '2',
#     'available_bikes': '28',
#     'availabilitycode': '1',
#     'availability': 'Vert',
#     'banking': 'false',
#     'gid': '1052',
#     'last_update': '2021-03-24 16:00:22',
#     'last_update_fme': '2021-03-24 16:02:03',
#     'code_insee': '69387',
#     'langue': '',
#     'etat': '',
#     'nature': '',
#     'titre': '',
#     'description': '',
#     'startdate': '',
#     'enddate': ''},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.841415287461779, 45.75298634351161]}},
#   {'type': 'Feature',
#    'properties': {'number': '8007',
#     'name': 'Frères Lumière',
#     'address': 'Rue des Frères Lumières',
#     'address2': 'angle rue Villon',
#     'commune': 'Lyon 8 ème',
#     'nmarrond': '7',
#     'bonus': '',
#     'pole': 'commerces',
#     'lat': '45.7450177556259450',
#     'lng': '4.8664326009099320',
#     'bike_stands': '15',
#     'status': 'OPEN',
#     'available_bike_stands': '14',
#     'available_bikes': '1',
#     'availabilitycode': '1',
#     'availability': 'Vert',
#     'banking': 'false',
#     'gid': '843',
#     'last_update': '2021-03-24 15:57:22',
#     'last_update_fme': '2021-03-24 16:02:03',
#     'code_insee': '69388',
#     'langue': '',
#     'etat': '',
#     'nature': '',
#     'titre': '',
#     'description': '',
#     'startdate': '',
#     'enddate': ''},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.866432600909932, 45.745017755625945]}},
#   {'type': 'Feature',
#    'properties': {'number': '9006',
#     'name': 'Théâtre Nouvelle Génération',
#     'address': 'Face 2, Rue Tissot',
#     'address2': 'angle Rue de Bourgogne',
#     'commune': 'Lyon 9 ème',
#     'nmarrond': '6',
#     'bonus': '',
#     'pole': 'maillage',
#     'lat': '45.7772955373720100',
#     'lng': '4.8033117445656650',
#     'bike_stands': '16',
#     'status': 'OPEN',
#     'available_bike_stands': '4',
#     'available_bikes': '12',
#     'availabilitycode': '1',
#     'availability': 'Vert',
#     'banking': 'false',
#     'gid': '1054',
#     'last_update': '2021-03-24 15:59:25',
#     'last_update_fme': '2021-03-24 16:02:03',
#     'code_insee': '69389',
#     'langue': '',
#     'etat': '',
#     'nature': '',
#     'titre': '',
#     'description': '',
#     'startdate': '',
#     'enddate': ''},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.803311744565665, 45.77729553737201]}},
#   {'type': 'Feature',
#    'properties': {'number': '10032',
#     'name': 'Primat / Decorps',
#     'address': 'Angle rue Emile Decorps / Rue Max Barel',
#     'address2': '',
#     'commune': 'VILLEURBANNE',
#     'nmarrond': '32',
#     'bonus': '',
#     'pole': 'Pôle Pixel',
#     'lat': '45.7571184153073900',
#     'lng': '4.8999931509132550',
#     'bike_stands': '13',
#     'status': 'OPEN',
#     'available_bike_stands': '13',
#     'available_bikes': '0',
#     'availabilitycode': '3',
#     'availability': 'Orange',
#     'banking': 'false',
#     'gid': '1024',
#     'last_update': '2021-03-24 15:54:03',
#     'last_update_fme': '2021-03-24 16:02:03',
#     'code_insee': '69266',
#     'langue': '',
#     'etat': '',
#     'nature': '',
#     'titre': '',
#     'description': '',
#     'startdate': '',
#     'enddate': ''},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.899993150913255, 45.75711841530739]}},
#   {'type': 'Feature',
#    'properties': {'number': '8021',
#     'name': 'Paul Santy',
#     'address': '101, Avenue Paul Santy',
#     'address2': '',
#     'commune': 'Lyon 8 ème',
#     'nmarrond': '21',
#     'bonus': '',
#     'pole': 'itinéraire cyclable',
#     'lat': '45.7285181510160800',
#     'lng': '4.8773059343942400',
#     'bike_stands': '16',
#     'status': 'OPEN',
#     'available_bike_stands': '10',
#     'available_bikes': '6',
#     'availabilitycode': '1',
#     'availability': 'Vert',
#     'banking': 'false',
#     'gid': '896',
#     'last_update': '2021-03-24 15:51:56',
#     'last_update_fme': '2021-03-24 16:02:03',
#     'code_insee': '69388',
#     'langue': '',
#     'etat': '',
#     'nature': '',
#     'titre': '',
#     'description': '',
#     'startdate': '',
#     'enddate': ''},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.87730593439424, 45.72851815101608]}},
#   {'type': 'Feature',
#    'properties': {'number': '2001',
#     'name': 'Bellecour / République',
#     'address': '4, Place Le Viste',
#     'address2': 'angle Rue de La République',
#     'commune': 'Lyon 2 ème',
#     'nmarrond': '1',
#     'bonus': '',
#     'pole': 'métro A D, site, commerces',
#     'lat': '45.7579850990088100',
#     'lng': '4.8345938219838450',
#     'bike_stands': '18',
#     'status': 'OPEN',
#     'available_bike_stands': '3',
#     'available_bikes': '15',
#     'availabilitycode': '1',
#     'availability': 'Vert',
#     'banking': 'false',
#     'gid': '803',
#     'last_update': '2021-03-24 16:01:06',
#     'last_update_fme': '2021-03-24 16:02:03',
#     'code_insee': '69382',
#     'langue': '',
#     'etat': '',
#     'nature': '',
#     'titre': '',
#     'description': '',
#     'startdate': '',
#     'enddate': ''},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.834593821983845, 45.75798509900881]}},
#   {'type': 'Feature',
#    'properties': {'number': '8059',
#     'name': 'Laënnec / Pinel',
#     'address': 'Rue Paradin',
#     'address2': '',
#     'commune': 'Lyon 8 ème',
#     'nmarrond': '59',
#     'bonus': '',
#     'pole': 'Jardin public',
#     'lat': '45.7353725112499350',
#     'lng': '4.8895389263694160',
#     'bike_stands': '15',
#     'status': 'OPEN',
#     'available_bike_stands': '15',
#     'available_bikes': '0',
#     'availabilitycode': '3',
#     'availability': 'Orange',
#     'banking': 'false',
#     'gid': '787',
#     'last_update': '2021-03-24 15:54:52',
#     'last_update_fme': '2021-03-24 16:02:03',
#     'code_insee': '69388',
#     'langue': '',
#     'etat': '',
#     'nature': '',
#     'titre': '',
#     'description': '',
#     'startdate': '',
#     'enddate': ''},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.889538926369416, 45.735372511249935]}},
#   {'type': 'Feature',
#    'properties': {'number': '3070',
#     'name': 'Rebatel / Saint-Maximin',
#     'address': '62, Rue St Maximin',
#     'address2': '',
#     'commune': 'Lyon 3 ème',
#     'nmarrond': '',
#     'bonus': '',
#     'pole': 'st_maximin_rebatel',
#     'lat': '45.7478194334711700',
#     'lng': '4.8722698711079255',
#     'bike_stands': '30',
#     'status': 'OPEN',
#     'available_bike_stands': '26',
#     'available_bikes': '4',
#     'availabilitycode': '1',
#     'availability': 'Vert',
#     'banking': 'false',
#     'gid': '1265',
#     'last_update': '2021-03-24 15:54:16',
#     'last_update_fme': '2021-03-24 16:02:03',
#     'code_insee': '69383',
#     'langue': '',
#     'etat': '',
#     'nature': '',
#     'titre': '',
#     'description': '',
#     'startdate': '',
#     'enddate': ''},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.872269871107926, 45.74781943347117]}},
#   {'type': 'Feature',
#    'properties': {'number': '10074',
#     'name': 'Zola / Passage Rey',
#     'address': '141, Cours Emile Zola',
#     'address2': 'Angle Passage Rey',
#     'commune': 'VILLEURBANNE',
#     'nmarrond': '74',
#     'bonus': '',
#     'pole': 'Salle de gym des Gratte-Ciel, centre-ville',
#     'lat': '45.7700978432658200',
#     'lng': '4.8766904175328010',
#     'bike_stands': '19',
#     'status': 'OPEN',
#     'available_bike_stands': '14',
#     'available_bikes': '5',
#     'availabilitycode': '1',
#     'availability': 'Vert',
#     'banking': 'false',
#     'gid': '909',
#     'last_update': '2021-03-24 15:56:09',
#     'last_update_fme': '2021-03-24 16:02:03',
#     'code_insee': '69266',
#     'langue': '',
#     'etat': '',
#     'nature': '',
#     'titre': '',
#     'description': '',
#     'startdate': '',
#     'enddate': ''},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.876690417532801, 45.77009784326582]}},
#   {'type': 'Feature',
#    'properties': {'number': '8015',
#     'name': 'Jean XXIII',
#     'address': '25, Rue Maryse Bastié',
#     'address2': '',
#     'commune': 'Lyon 8 ème',
#     'nmarrond': '15',
#     'bonus': '',
#     'pole': 'Tramway, habitations',
#     'lat': '45.7403259296418700',
#     'lng': '4.8741942706838780',
#     'bike_stands': '16',
#     'status': 'OPEN',
#     'available_bike_stands': '15',
#     'available_bikes': '1',
#     'availabilitycode': '1',
#     'availability': 'Vert',
#     'banking': 'false',
#     'gid': '764',
#     'last_update': '2021-03-24 15:53:21',
#     'last_update_fme': '2021-03-24 16:02:03',
#     'code_insee': '69388',
#     'langue': '',
#     'etat': '',
#     'nature': '',
#     'titre': '',
#     'description': '',
#     'startdate': '',
#     'enddate': ''},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.874194270683878, 45.74032592964187]}},
#   {'type': 'Feature',
#    'properties': {'number': '3089',
#     'name': 'Trarieux / Lacassagne',
#     'address': '221, Avenue Lacassagne',
#     'address2': '',
#     'commune': 'Lyon 3 ème',
#     'nmarrond': '89',
#     'bonus': '',
#     'pole': "Ecole d'infirmière",
#     'lat': '45.7453008083141900',
#     'lng': '4.8890420355008900',
#     'bike_stands': '24',
#     'status': 'OPEN',
#     'available_bike_stands': '20',
#     'available_bikes': '4',
#     'availabilitycode': '1',
#     'availability': 'Vert',
#     'banking': 'false',
#     'gid': '918',
#     'last_update': '2021-03-24 16:00:00',
#     'last_update_fme': '2021-03-24 16:02:03',
#     'code_insee': '69383',
#     'langue': '',
#     'etat': '',
#     'nature': '',
#     'titre': '',
#     'description': '',
#     'startdate': '',
#     'enddate': ''},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.88904203550089, 45.74530080831419]}},
#   {'type': 'Feature',
#    'properties': {'number': '5055',
#     'name': 'Buyer / Apollinaire',
#     'address': '103, Avenue Barthélémy Buyer',
#     'address2': '',
#     'commune': 'Lyon 5 ème',
#     'nmarrond': '55',
#     'bonus': '',
#     'pole': 'Centre commercial',
#     'lat': '45.7620132943614000',
#     'lng': '4.8027598903443770',
#     'bike_stands': '22',
#     'status': 'OPEN',
#     'available_bike_stands': '21',
#     'available_bikes': '1',
#     'availabilitycode': '1',
#     'availability': 'Vert',
#     'banking': 'false',
#     'gid': '891',
#     'last_update': '2021-03-24 16:01:14',
#     'last_update_fme': '2021-03-24 16:02:03',
#     'code_insee': '69385',
#     'langue': '',
#     'etat': '',
#     'nature': '',
#     'titre': '',
#     'description': '',
#     'startdate': '',
#     'enddate': ''},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.802759890344377, 45.7620132943614]}},
#   {'type': 'Feature',
#    'properties': {'number': '34001',
#     'name': 'Neuville - Quai Pasteur',
#     'address': '5, Quai Pasteur',
#     'address2': 'Angle Place Ampère',
#     'commune': 'NEUVILLE-SUR-SAONE',
#     'nmarrond': '',
#     'bonus': '',
#     'pole': ' ',
#     'lat': '45.8766089913122200',
#     'lng': '4.8386237264875970',
#     'bike_stands': '20',
#     'status': 'OPEN',
#     'available_bike_stands': '12',
#     'available_bikes': '8',
#     'availabilitycode': '1',
#     'availability': 'Vert',
#     'banking': 'false',
#     'gid': '1250',
#     'last_update': '2021-03-24 15:53:49',
#     'last_update_fme': '2021-03-24 16:02:03',
#     'code_insee': '69143',
#     'langue': '',
#     'etat': '',
#     'nature': '',
#     'titre': '',
#     'description': '',
#     'startdate': '',
#     'enddate': ''},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.838623726487597, 45.87660899131222]}},
#   {'type': 'Feature',
#    'properties': {'number': '3082',
#     'name': 'Saxe / Moncey',
#     'address': 'Face 119, Avenue Maréchal de Saxe',
#     'address2': '',
#     'commune': 'Lyon 3 ème',
#     'nmarrond': '82',
#     'bonus': '',
#     'pole': 'Coeur de quartier, DDE',
#     'lat': '45.7575642739996500',
#     'lng': '4.8461181734350030',
#     'bike_stands': '28',
#     'status': 'OPEN',
#     'available_bike_stands': '9',
#     'available_bikes': '19',
#     'availabilitycode': '1',
#     'availability': 'Vert',
#     'banking': 'false',
#     'gid': '960',
#     'last_update': '2021-03-24 15:59:27',
#     'last_update_fme': '2021-03-24 16:02:03',
#     'code_insee': '69383',
#     'langue': '',
#     'etat': '',
#     'nature': '',
#     'titre': '',
#     'description': '',
#     'startdate': '',
#     'enddate': ''},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.846118173435003, 45.75756427399965]}},
#   {'type': 'Feature',
#    'properties': {'number': '11003',
#     'name': 'Caluire / La Rochette',
#     'address': 'Place de la Rochette',
#     'address2': '',
#     'commune': 'CALUIRE-ET-CUIRE',
#     'nmarrond': '3',
#     'bonus': '',
#     'pole': '',
#     'lat': '45.7916701826039940',
#     'lng': '4.8235970239637440',
#     'bike_stands': '20',
#     'status': 'OPEN',
#     'available_bike_stands': '13',
#     'available_bikes': '7',
#     'availabilitycode': '1',
#     'availability': 'Vert',
#     'banking': 'false',
#     'gid': '956',
#     'last_update': '2021-03-24 15:58:56',
#     'last_update_fme': '2021-03-24 16:02:03',
#     'code_insee': '69034',
#     'langue': '',
#     'etat': '',
#     'nature': '',
#     'titre': '',
#     'description': '',
#     'startdate': '',
#     'enddate': ''},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.823597023963744, 45.791670182603994]}},
#   {'type': 'Feature',
#    'properties': {'number': '9014',
#     'name': 'Quai du Commerce',
#     'address': 'Face 18, Quai du Commerce',
#     'address2': 'Angle rue Rhin & Danube',
#     'commune': 'Lyon 9 ème',
#     'nmarrond': '14',
#     'bonus': '',
#     'pole': 'itinéraires cyclables',
#     'lat': '45.7823734809172700',
#     'lng': '4.8107471737568830',
#     'bike_stands': '23',
#     'status': 'CLOSED',
#     'available_bike_stands': '0',
#     'available_bikes': '0',
#     'availabilitycode': '0',
#     'availability': 'Gris',
#     'banking': 'true',
#     'gid': '1008',
#     'last_update': '2021-03-24 00:30:20',
#     'last_update_fme': '2021-03-24 00:30:20',
#     'code_insee': '69389',
#     'langue': '',
#     'etat': '',
#     'nature': '',
#     'titre': '',
#     'description': '',
#     'startdate': '',
#     'enddate': ''},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.810747173756883, 45.78237348091727]}},
#   {'type': 'Feature',
#    'properties': {'number': '10116',
#     'name': 'Blum / Faÿs',
#     'address': '171, Rue Léon Blum',
#     'address2': '',
#     'commune': 'VILLEURBANNE',
#     'nmarrond': '116',
#     'bonus': '',
#     'pole': 'Square, commerces, lycée technique',
#     'lat': '45.7605212388028900',
#     'lng': '4.9059454396164750',
#     'bike_stands': '16',
#     'status': 'OPEN',
#     'available_bike_stands': '12',
#     'available_bikes': '4',
#     'availabilitycode': '1',
#     'availability': 'Vert',
#     'banking': 'false',
#     'gid': '961',
#     'last_update': '2021-03-24 15:56:51',
#     'last_update_fme': '2021-03-24 16:02:03',
#     'code_insee': '69266',
#     'langue': '',
#     'etat': '',
#     'nature': '',
#     'titre': '',
#     'description': '',
#     'startdate': '',
#     'enddate': ''},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.905945439616475, 45.76052123880289]}},
#   {'type': 'Feature',
#    'properties': {'number': '10039',
#     'name': 'Bouvier',
#     'address': 'Face 2, Rue du Professeur Emile Bouvier',
#     'address2': 'Angle rue du 8 Mai 1945',
#     'commune': 'VILLEURBANNE',
#     'nmarrond': '39',
#     'bonus': '',
#     'pole': 'coeur quartier',
#     'lat': '45.7794643121307400',
#     'lng': '4.8915809514291190',
#     'bike_stands': '16',
#     'status': 'OPEN',
#     'available_bike_stands': '12',
#     'available_bikes': '4',
#     'availabilitycode': '1',
#     'availability': 'Vert',
#     'banking': 'false',
#     'gid': '831',
#     'last_update': '2021-03-24 15:56:31',
#     'last_update_fme': '2021-03-24 16:02:03',
#     'code_insee': '69266',
#     'langue': '',
#     'etat': '',
#     'nature': '',
#     'titre': '',
#     'description': '',
#     'startdate': '',
#     'enddate': ''},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.891580951429119, 45.77946431213074]}},
#   {'type': 'Feature',
#    'properties': {'number': '6006',
#     'name': 'Boulevard des Belges',
#     'address': '49, Boulevard des Belges',
#     'address2': 'Face rue Duquenne',
#     'commune': 'Lyon 6 ème',
#     'nmarrond': '6',
#     'bonus': '',
#     'pole': "Parc de la Tête d'Or",
#     'lat': '45.7733270382747500',
#     'lng': '4.8519894989151780',
#     'bike_stands': '15',
#     'status': 'OPEN',
#     'available_bike_stands': '2',
#     'available_bikes': '13',
#     'availabilitycode': '1',
#     'availability': 'Vert',
#     'banking': 'false',
#     'gid': '835',
#     'last_update': '2021-03-24 16:01:05',
#     'last_update_fme': '2021-03-24 16:02:03',
#     'code_insee': '69386',
#     'langue': '',
#     'etat': '',
#     'nature': '',
#     'titre': '',
#     'description': '',
#     'startdate': '',
#     'enddate': ''},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.851989498915178, 45.77332703827475]}},
#   {'type': 'Feature',
#    'properties': {'number': '2007',
#     'name': 'Patinoire Charlemagne',
#     'address': '100, Cours Charlemagne',
#     'address2': 'Rue Casimir Périer',
#     'commune': 'Lyon 2 ème',
#     'nmarrond': '7',
#     'bonus': '',
#     'pole': 'Patinoire Charlemagnes, Station tramway',
#     'lat': '45.7426115005543960',
#     'lng': '4.8204716703055040',
#     'bike_stands': '37',
#     'status': 'OPEN',
#     'available_bike_stands': '14',
#     'available_bikes': '23',
#     'availabilitycode': '1',
#     'availability': 'Vert',
#     'banking': 'false',
#     'gid': '830',
#     'last_update': '2021-03-24 15:59:40',
#     'last_update_fme': '2021-03-24 16:02:03',
#     'code_insee': '69382',
#     'langue': '',
#     'etat': '',
#     'nature': '',
#     'titre': '',
#     'description': '',
#     'startdate': '',
#     'enddate': ''},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.820471670305504, 45.742611500554396]}},
#   {'type': 'Feature',
#    'properties': {'number': '8004',
#     'name': 'Mairie du 8e',
#     'address': 'Face 29, Avenue Jean Mermoz',
#     'address2': '',
#     'commune': 'Lyon 8 ème',
#     'nmarrond': '4',
#     'bonus': '',
#     'pole': 'Mairie du 8e',
#     'lat': '45.7351509957905000',
#     'lng': '4.8728173875360470',
#     'bike_stands': '21',
#     'status': 'OPEN',
#     'available_bike_stands': '21',
#     'available_bikes': '0',
#     'availabilitycode': '3',
#     'availability': 'Orange',
#     'banking': 'false',
#     'gid': '894',
#     'last_update': '2021-03-24 15:56:26',
#     'last_update_fme': '2021-03-24 16:02:03',
#     'code_insee': '69388',
#     'langue': '',
#     'etat': '',
#     'nature': '',
#     'titre': '',
#     'description': '',
#     'startdate': '',
#     'enddate': ''},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.872817387536047, 45.7351509957905]}},
#   {'type': 'Feature',
#    'properties': {'number': '16005',
#     'name': 'Vénissieux - Gare',
#     'address': '122b Avenue Jules Guesde',
#     'address2': '',
#     'commune': 'VENISSIEUX',
#     'nmarrond': '',
#     'bonus': '',
#     'pole': 'Vénissieux',
#     'lat': '45.7085339720955660',
#     'lng': '4.8870248117095900',
#     'bike_stands': '25',
#     'status': 'OPEN',
#     'available_bike_stands': '23',
#     'available_bikes': '2',
#     'availabilitycode': '1',
#     'availability': 'Vert',
#     'banking': 'false',
#     'gid': '1248',
#     'last_update': '2021-03-24 15:56:19',
#     'last_update_fme': '2021-03-24 16:02:03',
#     'code_insee': '69259',
#     'langue': '',
#     'etat': '',
#     'nature': '',
#     'titre': '',
#     'description': '',
#     'startdate': '',
#     'enddate': ''},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.88702481170959, 45.708533972095566]}},
#   {'type': 'Feature',
#    'properties': {'number': '10025',
#     'name': 'Totem',
#     'address': '40, Cours Tolstoï',
#     'address2': '',
#     'commune': 'VILLEURBANNE',
#     'nmarrond': '25',
#     'bonus': '',
#     'pole': 'Centre Quartier',
#     'lat': '45.7636407030235000',
#     'lng': '4.8731410878807795',
#     'bike_stands': '16',
#     'status': 'OPEN',
#     'available_bike_stands': '12',
#     'available_bikes': '4',
#     'availabilitycode': '1',
#     'availability': 'Vert',
#     'banking': 'false',
#     'gid': '900',
#     'last_update': '2021-03-24 16:01:05',
#     'last_update_fme': '2021-03-24 16:02:03',
#     'code_insee': '69266',
#     'langue': '',
#     'etat': '',
#     'nature': '',
#     'titre': '',
#     'description': '',
#     'startdate': '',
#     'enddate': ''},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.873141087880779, 45.7636407030235]}},
#   {'type': 'Feature',
#    'properties': {'number': '8034',
#     'name': 'Berthelot / Villon',
#     'address': 'Face 98, Rue Villon',
#     'address2': 'angle rue Berthelot',
#     'commune': 'Lyon 8 ème',
#     'nmarrond': '34',
#     'bonus': '',
#     'pole': 'tram',
#     'lat': '45.7383023357079350',
#     'lng': '4.8627327832044810',
#     'bike_stands': '13',
#     'status': 'OPEN',
#     'available_bike_stands': '13',
#     'available_bikes': '0',
#     'availabilitycode': '3',
#     'availability': 'Orange',
#     'banking': 'false',
#     'gid': '1086',
#     'last_update': '2021-03-24 15:57:46',
#     'last_update_fme': '2021-03-24 16:02:03',
#     'code_insee': '69388',
#     'langue': '',
#     'etat': '',
#     'nature': '',
#     'titre': '',
#     'description': '',
#     'startdate': '',
#     'enddate': ''},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.862732783204481, 45.738302335707935]}},
#   {'type': 'Feature',
#    'properties': {'number': '3100',
#     'name': 'Sisley /  Dauphiné',
#     'address': '4, Rue Professeur Paul Sisley',
#     'address2': '',
#     'commune': 'Lyon 3 ème',
#     'nmarrond': '100',
#     'bonus': '',
#     'pole': 'Jardin public, tramway',
#     'lat': '45.7528275113150600',
#     'lng': '4.8687687708041860',
#     'bike_stands': '17',
#     'status': 'OPEN',
#     'available_bike_stands': '14',
#     'available_bikes': '3',
#     'availabilitycode': '1',
#     'availability': 'Vert',
#     'banking': 'false',
#     'gid': '941',
#     'last_update': '2021-03-24 15:51:28',
#     'last_update_fme': '2021-03-24 16:02:03',
#     'code_insee': '69383',
#     'langue': '',
#     'etat': '',
#     'nature': '',
#     'titre': '',
#     'description': '',
#     'startdate': '',
#     'enddate': ''},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.868768770804186, 45.75282751131506]}},
#   {'type': 'Feature',
#    'properties': {'number': '28002',
#     'name': 'Fontaines S/S - Gambetta',
#     'address': 'Place des Rendez vous',
#     'address2': '',
#     'commune': 'FONTAINES-SUR-SAONE',
#     'nmarrond': '',
#     'bonus': '',
#     'pole': '',
#     'lat': '45.8354059997715200',
#     'lng': '4.8457000001885610',
#     'bike_stands': '20',
#     'status': 'OPEN',
#     'available_bike_stands': '9',
#     'available_bikes': '11',
#     'availabilitycode': '1',
#     'availability': 'Vert',
#     'banking': 'false',
#     'gid': '1230',
#     'last_update': '2021-03-24 15:54:12',
#     'last_update_fme': '2021-03-24 16:02:03',
#     'code_insee': '69088',
#     'langue': '',
#     'etat': '',
#     'nature': '',
#     'titre': '',
#     'description': '',
#     'startdate': '',
#     'enddate': ''},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.845700000188561, 45.83540599977152]}},
#   {'type': 'Feature',
#    'properties': {'number': '8052',
#     'name': 'Clinique Montplaisir',
#     'address': '2, Avenue des Frères Lumière',
#     'address2': '',
#     'commune': 'Lyon 8 ème',
#     'nmarrond': '52',
#     'bonus': '',
#     'pole': 'Clinique, renforcement 8001',
#     'lat': '45.7470826073157540',
#     'lng': '4.8601908518953540',
#     'bike_stands': '16',
#     'status': 'OPEN',
#     'available_bike_stands': '14',
#     'available_bikes': '2',
#     'availabilitycode': '1',
#     'availability': 'Vert',
#     'banking': 'false',
#     'gid': '1013',
#     'last_update': '2021-03-24 15:59:34',
#     'last_update_fme': '2021-03-24 16:02:03',
#     'code_insee': '69388',
#     'langue': '',
#     'etat': '',
#     'nature': '',
#     'titre': '',
#     'description': '',
#     'startdate': '',
#     'enddate': ''},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.860190851895354, 45.747082607315754]}},
#   {'type': 'Feature',
#    'properties': {'number': '7061',
#     'name': 'Jaurès / Université',
#     'address': "53, Rue de l'Université",
#     'address2': '',
#     'commune': 'Lyon 7 ème',
#     'nmarrond': '61',
#     'bonus': '',
#     'pole': 'Coeur de quartier, commerces',
#     'lat': '45.7485374331787540',
#     'lng': '4.8432493337468060',
#     'bike_stands': '20',
#     'status': 'OPEN',
#     'available_bike_stands': '8',
#     'available_bikes': '12',
#     'availabilitycode': '1',
#     'availability': 'Vert',
#     'banking': 'false',
#     'gid': '772',
#     'last_update': '2021-03-24 15:57:44',
#     'last_update_fme': '2021-03-24 16:02:03',
#     'code_insee': '69387',
#     'langue': '',
#     'etat': '',
#     'nature': '',
#     'titre': '',
#     'description': '',
#     'startdate': '',
#     'enddate': ''},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.843249333746806, 45.748537433178754]}},
#   {'type': 'Feature',
#    'properties': {'number': '10013',
#     'name': 'Cusset',
#     'address': '13, Rue Pierre Voyant',
#     'address2': '',
#     'commune': 'VILLEURBANNE',
#     'nmarrond': '13',
#     'bonus': '',
#     'pole': 'métro A, centre quartier',
#     'lat': '45.7649456438753100',
#     'lng': '4.9010152745308350',
#     'bike_stands': '20',
#     'status': 'OPEN',
#     'available_bike_stands': '20',
#     'available_bikes': '0',
#     'availabilitycode': '3',
#     'availability': 'Orange',
#     'banking': 'false',
#     'gid': '876',
#     'last_update': '2021-03-24 16:00:48',
#     'last_update_fme': '2021-03-24 16:02:03',
#     'code_insee': '69266',
#     'langue': '',
#     'etat': '',
#     'nature': '',
#     'titre': '',
#     'description': '',
#     'startdate': '',
#     'enddate': ''},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.901015274530835, 45.76494564387531]}},
#   {'type': 'Feature',
#    'properties': {'number': '1032',
#     'name': 'Pizay',
#     'address': 'Face 22, Rue Pizay',
#     'address2': '',
#     'commune': 'Lyon 1 er',
#     'nmarrond': '32',
#     'bonus': '',
#     'pole': ' ',
#     'lat': '45.7672004172203160',
#     'lng': '4.8363916853563290',
#     'bike_stands': '22',
#     'status': 'OPEN',
#     'available_bike_stands': '0',
#     'available_bikes': '22',
#     'availabilitycode': '2',
#     'availability': 'Bleu',
#     'banking': 'false',
#     'gid': '1100',
#     'last_update': '2021-03-24 15:57:11',
#     'last_update_fme': '2021-03-24 16:02:03',
#     'code_insee': '69381',
#     'langue': '',
#     'etat': '',
#     'nature': '',
#     'titre': '',
#     'description': '',
#     'startdate': '',
#     'enddate': ''},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.836391685356329, 45.767200417220316]}},
#   {'type': 'Feature',
#    'properties': {'number': '8039',
#     'name': 'Pierre Delore',
#     'address': 'Face 2, Rue Pierre Delore',
#     'address2': '',
#     'commune': 'Lyon 8 ème',
#     'nmarrond': '39',
#     'bonus': '',
#     'pole': 'Habitat',
#     'lat': '45.7386358835747000',
#     'lng': '4.8524001839789180',
#     'bike_stands': '20',
#     'status': 'OPEN',
#     'available_bike_stands': '20',
#     'available_bikes': '0',
#     'availabilitycode': '3',
#     'availability': 'Orange',
#     'banking': 'false',
#     'gid': '898',
#     'last_update': '2021-03-24 15:55:16',
#     'last_update_fme': '2021-03-24 16:02:03',
#     'code_insee': '69388',
#     'langue': '',
#     'etat': '',
#     'nature': '',
#     'titre': '',
#     'description': '',
#     'startdate': '',
#     'enddate': ''},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.852400183978918, 45.7386358835747]}},
#   {'type': 'Feature',
#    'properties': {'number': '10055',
#     'name': 'Condorcet / Galline',
#     'address': 'Face 16, Avenue Galline',
#     'address2': 'Angle avenue de Condorcet',
#     'commune': 'VILLEURBANNE',
#     'nmarrond': '55',
#     'bonus': '',
#     'pole': 'maillage (habitat dense)',
#     'lat': '45.7763954484591800',
#     'lng': '4.8670871111508170',
#     'bike_stands': '15',
#     'status': 'OPEN',
#     'available_bike_stands': '7',
#     'available_bikes': '8',
#     'availabilitycode': '1',
#     'availability': 'Vert',
#     'banking': 'false',
#     'gid': '814',
#     'last_update': '2021-03-24 15:56:28',
#     'last_update_fme': '2021-03-24 16:02:03',
#     'code_insee': '69266',
#     'langue': '',
#     'etat': '',
#     'nature': '',
#     'titre': '',
#     'description': '',
#     'startdate': '',
#     'enddate': ''},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.867087111150817, 45.77639544845918]}},
#   {'type': 'Feature',
#    'properties': {'number': '10046',
#     'name': 'Charmettes / Zola',
#     'address': '25, Rue des Charmettes',
#     'address2': 'Angle cours Emile Zola',
#     'commune': 'VILLEURBANNE',
#     'nmarrond': '46',
#     'bonus': '',
#     'pole': 'maillage, arrêt C3 ?',
#     'lat': '45.7707410676207300',
#     'lng': '4.8673338286937360',
#     'bike_stands': '23',
#     'status': 'OPEN',
#     'available_bike_stands': '23',
#     'available_bikes': '0',
#     'availabilitycode': '3',
#     'availability': 'Orange',
#     'banking': 'false',
#     'gid': '887',
#     'last_update': '2021-03-24 15:58:56',
#     'last_update_fme': '2021-03-24 16:02:03',
#     'code_insee': '69266',
#     'langue': '',
#     'etat': '',
#     'nature': '',
#     'titre': '',
#     'description': '',
#     'startdate': '',
#     'enddate': ''},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.867333828693736, 45.77074106762073]}},
#   {'type': 'Feature',
#    'properties': {'number': '9002',
#     'name': 'Mairie du 9e',
#     'address': 'Rue du Bourbonnais',
#     'address2': 'sur le côté de la mairie',
#     'commune': 'Lyon 9 ème',
#     'nmarrond': '2',
#     'bonus': '',
#     'pole': 'mairie, coeur quartier, métro D',
#     'lat': '45.7742408280787800',
#     'lng': '4.8056660114147770',
#     'bike_stands': '27',
#     'status': 'OPEN',
#     'available_bike_stands': '18',
#     'available_bikes': '9',
#     'availabilitycode': '1',
#     'availability': 'Vert',
#     'banking': 'false',
#     'gid': '1074',
#     'last_update': '2021-03-24 15:57:29',
#     'last_update_fme': '2021-03-24 16:02:03',
#     'code_insee': '69389',
#     'langue': '',
#     'etat': '',
#     'nature': '',
#     'titre': '',
#     'description': '',
#     'startdate': '',
#     'enddate': ''},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.805666011414777, 45.77424082807878]}},
#   {'type': 'Feature',
#    'properties': {'number': '3036',
#     'name': 'Félix Faure / Vivier Merle',
#     'address': 'Face 106, Avenue Félix Faure',
#     'address2': '',
#     'commune': 'Lyon 3 ème',
#     'nmarrond': '36',
#     'bonus': '',
#     'pole': '',
#     'lat': '45.7538149056220500',
#     'lng': '4.8598558941293660',
#     'bike_stands': '35',
#     'status': 'CLOSED',
#     'available_bike_stands': '0',
#     'available_bikes': '0',
#     'availabilitycode': '0',
#     'availability': 'Gris',
#     'banking': 'false',
#     'gid': '952',
#     'last_update': '2021-03-24 00:30:20',
#     'last_update_fme': '2021-03-24 00:30:20',
#     'code_insee': '69383',
#     'langue': '',
#     'etat': '',
#     'nature': '',
#     'titre': '',
#     'description': '',
#     'startdate': '',
#     'enddate': ''},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.859855894129366, 45.75381490562205]}},
#   {'type': 'Feature',
#    'properties': {'number': '2035',
#     'name': 'Childebert / Rivière',
#     'address': '2, Rue Marcel-Gabriel Rivière',
#     'address2': 'Place de la République',
#     'commune': 'Lyon 2 ème',
#     'nmarrond': '35',
#     'bonus': '',
#     'pole': 'Commerces, hôtel Dieu, place, Parking',
#     'lat': '45.7598862786474200',
#     'lng': '4.8357987999345910',
#     'bike_stands': '23',
#     'status': 'OPEN',
#     'available_bike_stands': '1',
#     'available_bikes': '22',
#     'availabilitycode': '1',
#     'availability': 'Vert',
#     'banking': 'false',
#     'gid': '860',
#     'last_update': '2021-03-24 15:57:18',
#     'last_update_fme': '2021-03-24 16:02:03',
#     'code_insee': '69382',
#     'langue': '',
#     'etat': '',
#     'nature': '',
#     'titre': '',
#     'description': '',
#     'startdate': '',
#     'enddate': ''},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.835798799934591, 45.75988627864742]}},
#   {'type': 'Feature',
#    'properties': {'number': '3097',
#     'name': 'Augagneur / Fosse aux Ours',
#     'address': '28, Quai Victor Augagneur',
#     'address2': '',
#     'commune': 'Lyon 3 ème',
#     'nmarrond': '97',
#     'bonus': '',
#     'pole': 'Commerces, quartier, point nodal (Guillotière, 7e,',
#     'lat': '45.7571997023265400',
#     'lng': '4.8404991375424880',
#     'bike_stands': '40',
#     'status': 'OPEN',
#     'available_bike_stands': '2',
#     'available_bikes': '38',
#     'availabilitycode': '1',
#     'availability': 'Vert',
#     'banking': 'false',
#     'gid': '988',
#     'last_update': '2021-03-24 16:01:14',
#     'last_update_fme': '2021-03-24 16:02:03',
#     'code_insee': '69383',
#     'langue': '',
#     'etat': '',
#     'nature': '',
#     'titre': '',
#     'description': '',
#     'startdate': '',
#     'enddate': ''},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.840499137542488, 45.75719970232654]}},
#   {'type': 'Feature',
#    'properties': {'number': '20002',
#     'name': 'Oullins - Mairie',
#     'address': '4, Rue Etienne Dolet',
#     'address2': '',
#     'commune': 'OULLINS',
#     'nmarrond': '',
#     'bonus': '',
#     'pole': 'mairie_oullins',
#     'lat': '45.7140014190252940',
#     'lng': '4.8065443341113525',
#     'bike_stands': '18',
#     'status': 'OPEN',
#     'available_bike_stands': '14',
#     'available_bikes': '4',
#     'availabilitycode': '1',
#     'availability': 'Vert',
#     'banking': 'false',
#     'gid': '1239',
#     'last_update': '2021-03-24 15:53:55',
#     'last_update_fme': '2021-03-24 16:02:03',
#     'code_insee': '69149',
#     'langue': '',
#     'etat': '',
#     'nature': '',
#     'titre': '',
#     'description': '',
#     'startdate': '',
#     'enddate': ''},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.806544334111353, 45.714001419025294]}},
#   {'type': 'Feature',
#    'properties': {'number': '10061',
#     'name': 'République',
#     'address': '105, cours Emile Zola',
#     'address2': ' ',
#     'commune': 'VILLEURBANNE',
#     'nmarrond': '61',
#     'bonus': '',
#     'pole': 'métro',
#     'lat': '45.7707838400683800',
#     'lng': '4.8729593888672900',
#     'bike_stands': '17',
#     'status': 'OPEN',
#     'available_bike_stands': '12',
#     'available_bikes': '5',
#     'availabilitycode': '1',
#     'availability': 'Vert',
#     'banking': 'false',
#     'gid': '907',
#     'last_update': '2021-03-24 16:00:31',
#     'last_update_fme': '2021-03-24 16:02:03',
#     'code_insee': '69266',
#     'langue': '',
#     'etat': '',
#     'nature': '',
#     'titre': '',
#     'description': '',
#     'startdate': '',
#     'enddate': ''},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.87295938886729, 45.77078384006838]}},
#   {'type': 'Feature',
#    'properties': {'number': '5050',
#     'name': 'Théâtre Romain',
#     'address': "6, Rue de l'Antiquaille",
#     'address2': '',
#     'commune': 'Lyon 5 ème',
#     'nmarrond': '50',
#     'bonus': '',
#     'pole': 'Théâtre antique, lycée',
#     'lat': '45.7583623960292900',
#     'lng': '4.8210866415482530',
#     'bike_stands': '12',
#     'status': 'OPEN',
#     'available_bike_stands': '11',
#     'available_bikes': '1',
#     'availabilitycode': '1',
#     'availability': 'Vert',
#     'banking': 'false',
#     'gid': '790',
#     'last_update': '2021-03-24 15:52:16',
#     'last_update_fme': '2021-03-24 16:02:03',
#     'code_insee': '69385',
#     'langue': '',
#     'etat': '',
#     'nature': '',
#     'titre': '',
#     'description': '',
#     'startdate': '',
#     'enddate': ''},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.821086641548253, 45.75836239602929]}},
#   {'type': 'Feature',
#    'properties': {'number': '7002',
#     'name': 'Universités Lyon III / Lyon II',
#     'address': 'Face 16, Quai Claude Bernard',
#     'address2': "Entre Pont de l'université et rue Chevreul",
#     'commune': 'Lyon 7 ème',
#     'nmarrond': '2',
#     'bonus': '',
#     'pole': 'Université Lyon 2 et Lyon 3',
#     'lat': '45.7514132273513000',
#     'lng': '4.8363931815987780',
#     'bike_stands': '40',
#     'status': 'OPEN',
#     'available_bike_stands': '16',
#     'available_bikes': '24',
#     'availabilitycode': '1',
#     'availability': 'Vert',
#     'banking': 'false',
#     'gid': '1088',
#     'last_update': '2021-03-24 15:56:44',
#     'last_update_fme': '2021-03-24 16:02:03',
#     'code_insee': '69387',
#     'langue': '',
#     'etat': '',
#     'nature': '',
#     'titre': '',
#     'description': '',
#     'startdate': '',
#     'enddate': ''},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.836393181598778, 45.7514132273513]}},
#   {'type': 'Feature',
#    'properties': {'number': '3007',
#     'name': "Place d'Arsonval",
#     'address': "Place d'Arsonval",
#     'address2': 'A côté du stand de fleurs',
#     'commune': 'Lyon 3 ème',
#     'nmarrond': '7',
#     'bonus': '',
#     'pole': 'hôpital Herriot, métro D, tram, fac de pharmacie',
#     'lat': '45.7434156767836340',
#     'lng': '4.8789206164428370',
#     'bike_stands': '32',
#     'status': 'OPEN',
#     'available_bike_stands': '29',
#     'available_bikes': '3',
#     'availabilitycode': '1',
#     'availability': 'Vert',
#     'banking': 'false',
#     'gid': '1050',
#     'last_update': '2021-03-24 15:57:56',
#     'last_update_fme': '2021-03-24 16:02:03',
#     'code_insee': '69383',
#     'langue': '',
#     'etat': '',
#     'nature': '',
#     'titre': '',
#     'description': '',
#     'startdate': '',
#     'enddate': ''},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.878920616442837, 45.743415676783634]}},
#   {'type': 'Feature',
#    'properties': {'number': '3006',
#     'name': 'Villette / St-Antoine',
#     'address': 'Face 1, Rue Saint Antoine',
#     'address2': 'angle avec rue de la Villette',
#     'commune': 'Lyon 3 ème',
#     'nmarrond': '',
#     'bonus': '',
#     'pole': 'Lyon 3ème arrondissement',
#     'lat': '45.7628598508923400',
#     'lng': '4.8622869000871980',
#     'bike_stands': '23',
#     'status': 'OPEN',
#     'available_bike_stands': '0',
#     'available_bikes': '22',
#     'availabilitycode': '2',
#     'availability': 'Bleu',
#     'banking': 'false',
#     'gid': '1222',
#     'last_update': '2021-03-24 15:58:45',
#     'last_update_fme': '2021-03-24 16:02:03',
#     'code_insee': '69383',
#     'langue': '',
#     'etat': '',
#     'nature': '',
#     'titre': '',
#     'description': '',
#     'startdate': '',
#     'enddate': ''},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.862286900087198, 45.76285985089234]}},
#   {'type': 'Feature',
#    'properties': {'number': '4011',
#     'name': 'Place Joannès Ambre',
#     'address': 'Place Joannès Ambre',
#     'address2': 'Angle grande rue de la Croix Rousse',
#     'commune': 'Lyon 4 ème',
#     'nmarrond': '11',
#     'bonus': '',
#     'pole': 'Théâtre, coeur quartier, hôpital',
#     'lat': '45.7815755185206100',
#     'lng': '4.8328577220510200',
#     'bike_stands': '20',
#     'status': 'OPEN',
#     'available_bike_stands': '14',
#     'available_bikes': '6',
#     'availabilitycode': '1',
#     'availability': 'Vert',
#     'banking': 'false',
#     'gid': '1072',
#     'last_update': '2021-03-24 15:57:33',
#     'last_update_fme': '2021-03-24 16:02:03',
#     'code_insee': '69384',
#     'langue': '',
#     'etat': '',
#     'nature': '',
#     'titre': '',
#     'description': '',
#     'startdate': '',
#     'enddate': ''},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.83285772205102, 45.78157551852061]}},
#   {'type': 'Feature',
#    'properties': {'number': '11002',
#     'name': 'Caluire - Saint-Clair',
#     'address': '48 cours Aristide Briand',
#     'address2': '',
#     'commune': 'CALUIRE-ET-CUIRE',
#     'nmarrond': '2',
#     'bonus': '',
#     'pole': 'Commerces, centre de quartier',
#     'lat': '45.7854707644412200',
#     'lng': '4.8478421222935550',
#     'bike_stands': '20',
#     'status': 'OPEN',
#     'available_bike_stands': '19',
#     'available_bikes': '1',
#     'availabilitycode': '1',
#     'availability': 'Vert',
#     'banking': 'false',
#     'gid': '993',
#     'last_update': '2021-03-24 15:52:01',
#     'last_update_fme': '2021-03-24 16:02:03',
#     'code_insee': '69034',
#     'langue': '',
#     'etat': '',
#     'nature': '',
#     'titre': '',
#     'description': '',
#     'startdate': '',
#     'enddate': ''},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.847842122293555, 45.78547076444122]}},
#   {'type': 'Feature',
#    'properties': {'number': '3003',
#     'name': 'Part-Dieu / Deruelle',
#     'address': 'Boulevard Eugène Deruelle',
#     'address2': 'Face rue Masséna, entrée centre commercial',
#     'commune': 'Lyon 3 ème',
#     'nmarrond': '3',
#     'bonus': '',
#     'pole': 'centre commercial',
#     'lat': '45.7629790120815440',
#     'lng': '4.8550066229888000',
#     'bike_stands': '30',
#     'status': 'OPEN',
#     'available_bike_stands': '4',
#     'available_bikes': '25',
#     'availabilitycode': '1',
#     'availability': 'Vert',
#     'banking': 'false',
#     'gid': '1017',
#     'last_update': '2021-03-24 15:55:45',
#     'last_update_fme': '2021-03-24 16:02:03',
#     'code_insee': '69383',
#     'langue': '',
#     'etat': '',
#     'nature': '',
#     'titre': '',
#     'description': '',
#     'startdate': '',
#     'enddate': ''},
#    'geometry': {'type': 'Point',
# ...
#   {'type': 'Feature',
#    'properties': {'number': '10119',
#     'name': 'Villeurbanne Saint-Jean',
#     'address': '2, Rue des Acacias',
#     'address2': '',
#     'commune': 'VILLEURBANNE',
#     'nmarrond': '119',
#     'bonus': '',
#     'pole': 'Collège Jean Vilar',
#     'lat': '45.7804458217109400',
#     'lng': '4.9044888457892960',
#     'bike_stands': '12',
#     'status': 'OPEN',
#     'available_bike_stands': '0',
#     'available_bikes': '12',
#     'availabilitycode': '2',
#     'availability': 'Bleu',
#     'banking': 'false',
#     'gid': '782',
#     'last_update': '2021-03-24 15:59:38',
#     'last_update_fme': '2021-03-24 16:02:02',
#     'code_insee': '69266',
#     'langue': '',
#     'etat': '',
#     'nature': '',
#     'titre': '',
#     'description': '',
#     'startdate': '',
#     'enddate': ''},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.904488845789296, 45.78044582171094]}},
#   {'type': 'Feature',
#    'properties': {'number': '10023',
#     'name': 'Jaurès / Saint Exupéry',
#     'address': '54, Rue Jean Jaurès',
#     'address2': '',
#     'commune': 'VILLEURBANNE',
#     'nmarrond': '',
#     'bonus': '',
#     'pole': '',
#     'lat': '45.7576523213066860',
#     'lng': '4.8834709512316210',
#     'bike_stands': '25',
#     'status': 'OPEN',
#     'available_bike_stands': '25',
#     'available_bikes': '0',
#     'availabilitycode': '3',
#     'availability': 'Orange',
#     'banking': 'false',
#     'gid': '1281',
#     'last_update': '2021-03-24 15:52:30',
#     'last_update_fme': '2021-03-24 16:02:03',
#     'code_insee': '69266',
#     'langue': '',
#     'etat': '',
#     'nature': '',
#     'titre': '',
#     'description': '',
#     'startdate': '',
#     'enddate': ''},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.883470951231621, 45.757652321306686]}},
#   {'type': 'Feature',
#    'properties': {'number': '10054',
#     'name': 'Stalingrad / Meliès',
#     'address': '2, Rue Georges Meliès',
#     'address2': '',
#     'commune': 'VILLEURBANNE',
#     'nmarrond': '54',
#     'bonus': '',
#     'pole': 'centre de congrès, bureaux',
#     'lat': '45.7766967138823300',
#     'lng': '4.8595230519892390',
#     'bike_stands': '24',
#     'status': 'OPEN',
#     'available_bike_stands': '1',
#     'available_bikes': '23',
#     'availabilitycode': '1',
#     'availability': 'Vert',
#     'banking': 'false',
#     'gid': '901',
#     'last_update': '2021-03-24 15:58:47',
#     'last_update_fme': '2021-03-24 16:02:03',
#     'code_insee': '69266',
#     'langue': '',
#     'etat': '',
#     'nature': '',
#     'titre': '',
#     'description': '',
#     'startdate': '',
#     'enddate': ''},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.859523051989239, 45.77669671388233]}},
#   {'type': 'Feature',
#    'properties': {'number': '1021',
#     'name': 'Terreaux / Beaux Arts',
#     'address': '8, Rue du Président Edouard Herriot',
#     'address2': '',
#     'commune': 'Lyon 1 er',
#     'nmarrond': '21',
#     'bonus': '',
#     'pole': 'Palais des Beaux Arts',
#     'lat': '45.7670410048109700',
#     'lng': '4.8342839059717140',
#     'bike_stands': '11',
#     'status': 'OPEN',
#     'available_bike_stands': '5',
#     'available_bikes': '6',
#     'availabilitycode': '1',
#     'availability': 'Vert',
#     'banking': 'false',
#     'gid': '806',
#     'last_update': '2021-03-24 15:53:57',
#     'last_update_fme': '2021-03-24 16:02:03',
#     'code_insee': '69381',
#     'langue': '',
#     'etat': '',
#     'nature': '',
#     'titre': '',
#     'description': '',
#     'startdate': '',
#     'enddate': ''},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.834283905971714, 45.76704100481097]}},
#   {'type': 'Feature',
#    'properties': {'number': '2002',
#     'name': 'Bellecour / Saint Exupéry',
#     'address': 'Face 34, Place Bellecour',
#     'address2': 'côté Rue Paul Lintier',
#     'commune': 'Lyon 2 ème',
#     'nmarrond': '2',
#     'bonus': '',
#     'pole': 'métro A D, site, commerces',
#     'lat': '45.7581569109321860',
#     'lng': '4.8304346949094690',
#     'bike_stands': '40',
#     'status': 'OPEN',
#     'available_bike_stands': '5',
#     'available_bikes': '35',
#     'availabilitycode': '1',
#     'availability': 'Vert',
#     'banking': 'false',
#     'gid': '800',
#     'last_update': '2021-03-24 15:55:11',
#     'last_update_fme': '2021-03-24 16:02:03',
#     'code_insee': '69382',
#     'langue': '',
#     'etat': '',
#     'nature': '',
#     'titre': '',
#     'description': '',
#     'startdate': '',
#     'enddate': ''},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.830434694909469, 45.758156910932186]}},
#   {'type': 'Feature',
#    'properties': {'number': '3087',
#     'name': 'Part-Dieu / Garibaldi',
#     'address': '4, Boulevard Eugène Deruelle',
#     'address2': '',
#     'commune': 'Lyon 3 ème',
#     'nmarrond': '87',
#     'bonus': '',
#     'pole': 'Centre Commercial, bureaux, renforcement 2-003',
#     'lat': '45.7627511569952000',
#     'lng': '4.8524277723450730',
#     'bike_stands': '20',
#     'status': 'OPEN',
#     'available_bike_stands': '4',
#     'available_bikes': '16',
#     'availabilitycode': '1',
#     'availability': 'Vert',
#     'banking': 'false',
#     'gid': '1018',
#     'last_update': '2021-03-24 15:51:43',
#     'last_update_fme': '2021-03-24 16:02:03',
#     'code_insee': '69383',
#     'langue': '',
#     'etat': '',
#     'nature': '',
#     'titre': '',
#     'description': '',
#     'startdate': '',
#     'enddate': ''},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.852427772345073, 45.7627511569952]}},
#   {'type': 'Feature',
#    'properties': {'number': '5001',
#     'name': 'Place Varillon (funiculaire St-Just)',
#     'address': '63, Rue de Trion',
#     'address2': '',
#     'commune': 'Lyon 5 ème',
#     'nmarrond': '1',
#     'bonus': '',
#     'pole': 'Métro Saint Just, habitations, commerces',
#     'lat': '45.7573003219205000',
#     'lng': '4.8150900113095240',
#     'bike_stands': '23',
#     'status': 'OPEN',
#     'available_bike_stands': '13',
#     'available_bikes': '10',
#     'availabilitycode': '1',
#     'availability': 'Vert',
#     'banking': 'false',
#     'gid': '1037',
#     'last_update': '2021-03-24 16:00:16',
#     'last_update_fme': '2021-03-24 16:02:03',
#     'code_insee': '69385',
#     'langue': '',
#     'etat': '',
#     'nature': '',
#     'titre': '',
#     'description': '',
#     'startdate': '',
#     'enddate': ''},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.815090011309524, 45.7573003219205]}},
#   {'type': 'Feature',
#    'properties': {'number': '3018',
#     'name': 'Créqui / Voltaire',
#     'address': 'Rue de Créqui',
#     'address2': 'angle place Voltaire',
#     'commune': 'Lyon 3 ème',
#     'nmarrond': '18',
#     'bonus': '',
#     'pole': 'Coeur de quartier',
#     'lat': '45.7566983441751900',
#     'lng': '4.8484034857557150',
#     'bike_stands': '30',
#     'status': 'OPEN',
#     'available_bike_stands': '23',
#     'available_bikes': '7',
#     'availabilitycode': '1',
#     'availability': 'Vert',
#     'banking': 'false',
#     'gid': '780',
#     'last_update': '2021-03-24 15:58:49',
#     'last_update_fme': '2021-03-24 16:02:03',
#     'code_insee': '69383',
#     'langue': '',
#     'etat': '',
#     'nature': '',
#     'titre': '',
#     'description': '',
#     'startdate': '',
#     'enddate': ''},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.848403485755715, 45.75669834417519]}},
#   {'type': 'Feature',
#    'properties': {'number': '7051',
#     'name': 'Guillotière / Veyron',
#     'address': '241, Grande Rue de la Guillotière',
#     'address2': '',
#     'commune': 'Lyon 7 ème',
#     'nmarrond': '',
#     'bonus': '',
#     'pole': '',
#     'lat': '45.7479327825068000',
#     'lng': '4.8563371818097670',
#     'bike_stands': '30',
#     'status': '',
#     'available_bike_stands': '',
#     'available_bikes': '',
#     'availabilitycode': '',
#     'availability': '',
#     'banking': '',
#     'gid': '1279',
#     'last_update': '2021-03-24 00:30:20',
#     'last_update_fme': '2021-03-24 00:30:20',
#     'code_insee': '69387',
#     'langue': '',
#     'etat': '',
#     'nature': '',
#     'titre': '',
#     'description': '',
#     'startdate': '',
#     'enddate': ''},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.856337181809767, 45.7479327825068]}},
#   {'type': 'Feature',
#    'properties': {'number': '18001',
#     'name': 'Pierre Bénite - Europe',
#     'address': '22, Rue Voltaire',
#     'address2': '',
#     'commune': 'PIERRE-BENITE',
#     'nmarrond': '',
#     'bonus': '',
#     'pole': 'europe',
#     'lat': '45.7032558571012300',
#     'lng': '4.8212003761276780',
#     'bike_stands': '15',
#     'status': 'OPEN',
#     'available_bike_stands': '10',
#     'available_bikes': '5',
#     'availabilitycode': '1',
#     'availability': 'Vert',
#     'banking': 'false',
#     'gid': '1262',
#     'last_update': '2021-03-24 15:53:42',
#     'last_update_fme': '2021-03-24 16:02:03',
#     'code_insee': '69152',
#     'langue': '',
#     'etat': '',
#     'nature': '',
#     'titre': '',
#     'description': '',
#     'startdate': '',
#     'enddate': ''},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.821200376127678, 45.70325585710123]}},
#   {'type': 'Feature',
#    'properties': {'number': '8057',
#     'name': 'Vienne / Montagny',
#     'address': '184 route de Vienne',
#     'address2': '',
#     'commune': 'Lyon 8 ème',
#     'nmarrond': '57',
#     'bonus': '',
#     'pole': 'Maillage',
#     'lat': '45.7324819782407700',
#     'lng': '4.8534099750018610',
#     'bike_stands': '20',
#     'status': 'OPEN',
#     'available_bike_stands': '9',
#     'available_bikes': '11',
#     'availabilitycode': '1',
#     'availability': 'Vert',
#     'banking': 'false',
#     'gid': '786',
#     'last_update': '2021-03-24 15:58:52',
#     'last_update_fme': '2021-03-24 16:02:03',
#     'code_insee': '69388',
#     'langue': '',
#     'etat': '',
#     'nature': '',
#     'titre': '',
#     'description': '',
#     'startdate': '',
#     'enddate': ''},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.853409975001861, 45.73248197824077]}},
#   {'type': 'Feature',
#    'properties': {'number': '9004',
#     'name': 'Gare de Vaise',
#     'address': 'Face 14, Rue du 24 Mars 1852',
#     'address2': 'face entrée gare',
#     'commune': 'Lyon 9 ème',
#     'nmarrond': '4',
#     'bonus': '',
#     'pole': 'Gare, métro D',
#     'lat': '45.7797819839255400',
#     'lng': '4.8046653309593905',
#     'bike_stands': '22',
#     'status': 'OPEN',
#     'available_bike_stands': '1',
#     'available_bikes': '20',
#     'availabilitycode': '1',
#     'availability': 'Vert',
#     'banking': 'false',
#     'gid': '1014',
#     'last_update': '2021-03-24 15:55:46',
#     'last_update_fme': '2021-03-24 16:02:03',
#     'code_insee': '69389',
#     'langue': '',
#     'etat': '',
#     'nature': '',
#     'titre': '',
#     'description': '',
#     'startdate': '',
#     'enddate': ''},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.804665330959391, 45.77978198392554]}},
#   {'type': 'Feature',
#    'properties': {'number': '8002',
#     'name': 'Place Ambroise Courtois',
#     'address': 'Place Ambroise Courtois',
#     'address2': 'Face 107 Cours Albert Thomas',
#     'commune': 'Lyon 8 ème',
#     'nmarrond': '2',
#     'bonus': '',
#     'pole': 'Métro D, Institut Lumière, Place et avenue des frères Lumière',
#     'lat': '45.7452926164535000',
#     'lng': '4.8716789632578010',
#     'bike_stands': '20',
#     'status': 'OPEN',
#     'available_bike_stands': '16',
#     'available_bikes': '3',
#     'availabilitycode': '1',
#     'availability': 'Vert',
#     'banking': 'false',
#     'gid': '895',
#     'last_update': '2021-03-24 15:59:11',
#     'last_update_fme': '2021-03-24 16:02:03',
#     'code_insee': '69388',
#     'langue': '',
#     'etat': '',
#     'nature': '',
#     'titre': '',
#     'description': '',
#     'startdate': '',
#     'enddate': ''},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.871678963257801, 45.7452926164535]}},
#   {'type': 'Feature',
#    'properties': {'number': '10007',
#     'name': 'Piaton / Condorcet',
#     'address': 'Avenue Piaton',
#     'address2': 'Angle rue Condorcet',
#     'commune': 'VILLEURBANNE',
#     'nmarrond': '7',
#     'bonus': '',
#     'pole': 'centre quartier, itinéraire cyclable',
#     'lat': '45.7742151784181300',
#     'lng': '4.8675042131350820',
#     'bike_stands': '20',
#     'status': 'OPEN',
#     'available_bike_stands': '9',
#     'available_bikes': '10',
#     'availabilitycode': '1',
#     'availability': 'Vert',
#     'banking': 'false',
#     'gid': '1078',
#     'last_update': '2021-03-24 15:52:57',
#     'last_update_fme': '2021-03-24 16:02:03',
#     'code_insee': '69266',
#     'langue': '',
#     'etat': '',
#     'nature': '',
#     'titre': '',
#     'description': '',
#     'startdate': '',
#     'enddate': ''},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.867504213135082, 45.77421517841813]}},
#   {'type': 'Feature',
#    'properties': {'number': '9033',
#     'name': 'Gorge de Loup',
#     'address': '49 bis Esplanade Lina Cretet',
#     'address2': 'Rue Sergent Michel Berthet',
#     'commune': 'Lyon 9 ème',
#     'nmarrond': '33',
#     'bonus': '',
#     'pole': ' Lycée professionnel',
#     'lat': '45.7673654785190900',
#     'lng': '4.8056276995192775',
#     'bike_stands': '40',
#     'status': 'OPEN',
#     'available_bike_stands': '40',
#     'available_bikes': '0',
#     'availabilitycode': '3',
#     'availability': 'Orange',
#     'banking': 'false',
#     'gid': '892',
#     'last_update': '2021-03-24 15:54:19',
#     'last_update_fme': '2021-03-24 16:02:03',
#     'code_insee': '69389',
#     'langue': '',
#     'etat': '',
#     'nature': '',
#     'titre': '',
#     'description': '',
#     'startdate': '',
#     'enddate': ''},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.805627699519277, 45.76736547851909]}},
#   {'type': 'Feature',
#    'properties': {'number': '5009',
#     'name': 'Place Ennemond Fousseret',
#     'address': 'Quai Romain Rolland angle Quai de Bondy',
#     'address2': 'Place Fousseret',
#     'commune': 'Lyon 5 ème',
#     'nmarrond': '9',
#     'bonus': '',
#     'pole': 'Vieux Lyon',
#     'lat': '45.7646815056712300',
#     'lng': '4.8289833265225160',
#     'bike_stands': '16',
#     'status': 'OPEN',
#     'available_bike_stands': '9',
#     'available_bikes': '7',
#     'availabilitycode': '1',
#     'availability': 'Vert',
#     'banking': 'false',
#     'gid': '1032',
#     'last_update': '2021-03-24 15:59:24',
#     'last_update_fme': '2021-03-24 16:02:03',
#     'code_insee': '69385',
#     'langue': '',
#     'etat': '',
#     'nature': '',
#     'titre': '',
#     'description': '',
#     'startdate': '',
#     'enddate': ''},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.828983326522516, 45.76468150567123]}},
#   {'type': 'Feature',
#    'properties': {'number': '3034',
#     'name': 'Garibaldi / Pensionnat',
#     'address': '52, Rue du Pensionnat',
#     'address2': '',
#     'commune': 'Lyon 3 ème',
#     'nmarrond': '104',
#     'bonus': '',
#     'pole': 'Lyon 3ème arrondissement',
#     'lat': '45.7547065642496240',
#     'lng': '4.8534044474099280',
#     'bike_stands': '30',
#     'status': 'OPEN',
#     'available_bike_stands': '25',
#     'available_bikes': '5',
#     'availabilitycode': '1',
#     'availability': 'Vert',
#     'banking': 'false',
#     'gid': '1210',
#     'last_update': '2021-03-24 16:00:59',
#     'last_update_fme': '2021-03-24 16:02:03',
#     'code_insee': '69383',
#     'langue': '',
#     'etat': '',
#     'nature': '',
#     'titre': '',
#     'description': '',
#     'startdate': '',
#     'enddate': ''},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.853404447409928, 45.754706564249624]}},
#   {'type': 'Feature',
#    'properties': {'number': '8030',
#     'name': 'Laënnec',
#     'address': 'Rue Nungesser et Coli',
#     'address2': '25, Rue Laënnec',
#     'commune': 'Lyon 8 ème',
#     'nmarrond': '30',
#     'bonus': '',
#     'pole': 'fac, tram',
#     'lat': '45.7413487229911060',
#     'lng': '4.8797231637591720',
#     'bike_stands': '16',
#     'status': 'OPEN',
#     'available_bike_stands': '16',
#     'available_bikes': '0',
#     'availabilitycode': '3',
#     'availability': 'Orange',
#     'banking': 'false',
#     'gid': '1056',
#     'last_update': '2021-03-24 15:57:43',
#     'last_update_fme': '2021-03-24 16:02:03',
#     'code_insee': '69388',
#     'langue': '',
#     'etat': '',
#     'nature': '',
#     'titre': '',
#     'description': '',
#     'startdate': '',
#     'enddate': ''},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.879723163759172, 45.741348722991106]}}]}

# %%
for element in data_lyon['features']:
    del element['properties']['number']
    del element['properties']['address']
    del element['properties']['address2']
    del element['properties']['commune']
    del element['properties']['nmarrond']
    del element['properties']['pole']
    del element['properties']['bonus']
    del element['properties']['status']
    del element['properties']['availabilitycode']
    del element['properties']['availability']
    del element['properties']['banking']
    del element['properties']['gid']
    del element['properties']['last_update']
    del element['properties']['last_update_fme']
    del element['properties']['code_insee']
    del element['properties']['langue']
    del element['properties']['nature']
    del element['properties']['titre']
    del element['properties']['description']
    del element['properties']['startdate']
    del element['properties']['enddate']
    del element['properties']['etat']
    del element['geometry']
    element['properties']['ville'] = 'Lyon'

# %%
for element in data_lyon['features']:
    element['properties']['@type'] = "station"
data_lyon['name'] = 'Stations de velos Lyon'
data_lyon
# Out:
# {'type': 'FeatureCollection',
#  'name': 'Stations de velos Lyon',
#  'features': [{'type': 'Feature',
#    'properties': {'name': 'Place Stalingard',
#     'lat': '45.7495788810534300',
#     'lng': '4.8529655050157780',
#     'bike_stands': '13',
#     'available_bike_stands': '10',
#     'available_bikes': '2',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Place Flammarion',
#     'lat': '45.7793264516606800',
#     'lng': '4.8203031984414520',
#     'bike_stands': '18',
#     'available_bike_stands': '3',
#     'available_bikes': '12',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Place des Compagnons de la chanson',
#     'lat': '45.7565273368784000',
#     'lng': '4.7966121788894250',
#     'bike_stands': '18',
#     'available_bike_stands': '10',
#     'available_bikes': '8',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Vaise Docks',
#     'lat': '45.7865084443620300',
#     'lng': '4.8114412174203720',
#     'bike_stands': '19',
#     'available_bike_stands': '7',
#     'available_bikes': '12',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Halle Tony Garnier',
#     'lat': '45.7308422388673200',
#     'lng': '4.8237404067653960',
#     'bike_stands': '20',
#     'available_bike_stands': '7',
#     'available_bikes': '13',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Gambetta / Jusserand',
#     'lat': '45.7511124102764400',
#     'lng': '4.8555850883006510',
#     'bike_stands': '13',
#     'available_bike_stands': '9',
#     'available_bikes': '4',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'République / Maupin',
#     'lat': '45.7587390821938500',
#     'lng': '4.8340765154131455',
#     'bike_stands': '25',
#     'available_bike_stands': '0',
#     'available_bikes': '25',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Saint Didier - Pasteur / Saint-Cyr',
#     'lat': '45.7915736750577340',
#     'lng': '4.8085346353439210',
#     'bike_stands': '17',
#     'available_bike_stands': '15',
#     'available_bikes': '2',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Marseille / Félissent',
#     'lat': '45.7529863435116100',
#     'lng': '4.8414152874617790',
#     'bike_stands': '30',
#     'available_bike_stands': '2',
#     'available_bikes': '28',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Frères Lumière',
#     'lat': '45.7450177556259450',
#     'lng': '4.8664326009099320',
#     'bike_stands': '15',
#     'available_bike_stands': '14',
#     'available_bikes': '1',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Théâtre Nouvelle Génération',
#     'lat': '45.7772955373720100',
#     'lng': '4.8033117445656650',
#     'bike_stands': '16',
#     'available_bike_stands': '4',
#     'available_bikes': '12',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Primat / Decorps',
#     'lat': '45.7571184153073900',
#     'lng': '4.8999931509132550',
#     'bike_stands': '13',
#     'available_bike_stands': '13',
#     'available_bikes': '0',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Paul Santy',
#     'lat': '45.7285181510160800',
#     'lng': '4.8773059343942400',
#     'bike_stands': '16',
#     'available_bike_stands': '10',
#     'available_bikes': '6',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Bellecour / République',
#     'lat': '45.7579850990088100',
#     'lng': '4.8345938219838450',
#     'bike_stands': '18',
#     'available_bike_stands': '3',
#     'available_bikes': '15',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Laënnec / Pinel',
#     'lat': '45.7353725112499350',
#     'lng': '4.8895389263694160',
#     'bike_stands': '15',
#     'available_bike_stands': '15',
#     'available_bikes': '0',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Rebatel / Saint-Maximin',
#     'lat': '45.7478194334711700',
#     'lng': '4.8722698711079255',
#     'bike_stands': '30',
#     'available_bike_stands': '26',
#     'available_bikes': '4',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Zola / Passage Rey',
#     'lat': '45.7700978432658200',
#     'lng': '4.8766904175328010',
#     'bike_stands': '19',
#     'available_bike_stands': '14',
#     'available_bikes': '5',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Jean XXIII',
#     'lat': '45.7403259296418700',
#     'lng': '4.8741942706838780',
#     'bike_stands': '16',
#     'available_bike_stands': '15',
#     'available_bikes': '1',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Trarieux / Lacassagne',
#     'lat': '45.7453008083141900',
#     'lng': '4.8890420355008900',
#     'bike_stands': '24',
#     'available_bike_stands': '20',
#     'available_bikes': '4',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Buyer / Apollinaire',
#     'lat': '45.7620132943614000',
#     'lng': '4.8027598903443770',
#     'bike_stands': '22',
#     'available_bike_stands': '21',
#     'available_bikes': '1',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Neuville - Quai Pasteur',
#     'lat': '45.8766089913122200',
#     'lng': '4.8386237264875970',
#     'bike_stands': '20',
#     'available_bike_stands': '12',
#     'available_bikes': '8',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Saxe / Moncey',
#     'lat': '45.7575642739996500',
#     'lng': '4.8461181734350030',
#     'bike_stands': '28',
#     'available_bike_stands': '9',
#     'available_bikes': '19',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Caluire / La Rochette',
#     'lat': '45.7916701826039940',
#     'lng': '4.8235970239637440',
#     'bike_stands': '20',
#     'available_bike_stands': '13',
#     'available_bikes': '7',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Quai du Commerce',
#     'lat': '45.7823734809172700',
#     'lng': '4.8107471737568830',
#     'bike_stands': '23',
#     'available_bike_stands': '0',
#     'available_bikes': '0',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Blum / Faÿs',
#     'lat': '45.7605212388028900',
#     'lng': '4.9059454396164750',
#     'bike_stands': '16',
#     'available_bike_stands': '12',
#     'available_bikes': '4',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Bouvier',
#     'lat': '45.7794643121307400',
#     'lng': '4.8915809514291190',
#     'bike_stands': '16',
#     'available_bike_stands': '12',
#     'available_bikes': '4',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Boulevard des Belges',
#     'lat': '45.7733270382747500',
#     'lng': '4.8519894989151780',
#     'bike_stands': '15',
#     'available_bike_stands': '2',
#     'available_bikes': '13',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Patinoire Charlemagne',
#     'lat': '45.7426115005543960',
#     'lng': '4.8204716703055040',
#     'bike_stands': '37',
#     'available_bike_stands': '14',
#     'available_bikes': '23',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Mairie du 8e',
#     'lat': '45.7351509957905000',
#     'lng': '4.8728173875360470',
#     'bike_stands': '21',
#     'available_bike_stands': '21',
#     'available_bikes': '0',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Vénissieux - Gare',
#     'lat': '45.7085339720955660',
#     'lng': '4.8870248117095900',
#     'bike_stands': '25',
#     'available_bike_stands': '23',
#     'available_bikes': '2',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Totem',
#     'lat': '45.7636407030235000',
#     'lng': '4.8731410878807795',
#     'bike_stands': '16',
#     'available_bike_stands': '12',
#     'available_bikes': '4',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Berthelot / Villon',
#     'lat': '45.7383023357079350',
#     'lng': '4.8627327832044810',
#     'bike_stands': '13',
#     'available_bike_stands': '13',
#     'available_bikes': '0',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Sisley /  Dauphiné',
#     'lat': '45.7528275113150600',
#     'lng': '4.8687687708041860',
#     'bike_stands': '17',
#     'available_bike_stands': '14',
#     'available_bikes': '3',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Fontaines S/S - Gambetta',
#     'lat': '45.8354059997715200',
#     'lng': '4.8457000001885610',
#     'bike_stands': '20',
#     'available_bike_stands': '9',
#     'available_bikes': '11',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Clinique Montplaisir',
#     'lat': '45.7470826073157540',
#     'lng': '4.8601908518953540',
#     'bike_stands': '16',
#     'available_bike_stands': '14',
#     'available_bikes': '2',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Jaurès / Université',
#     'lat': '45.7485374331787540',
#     'lng': '4.8432493337468060',
#     'bike_stands': '20',
#     'available_bike_stands': '8',
#     'available_bikes': '12',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Cusset',
#     'lat': '45.7649456438753100',
#     'lng': '4.9010152745308350',
#     'bike_stands': '20',
#     'available_bike_stands': '20',
#     'available_bikes': '0',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Pizay',
#     'lat': '45.7672004172203160',
#     'lng': '4.8363916853563290',
#     'bike_stands': '22',
#     'available_bike_stands': '0',
#     'available_bikes': '22',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Pierre Delore',
#     'lat': '45.7386358835747000',
#     'lng': '4.8524001839789180',
#     'bike_stands': '20',
#     'available_bike_stands': '20',
#     'available_bikes': '0',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Condorcet / Galline',
#     'lat': '45.7763954484591800',
#     'lng': '4.8670871111508170',
#     'bike_stands': '15',
#     'available_bike_stands': '7',
#     'available_bikes': '8',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Charmettes / Zola',
#     'lat': '45.7707410676207300',
#     'lng': '4.8673338286937360',
#     'bike_stands': '23',
#     'available_bike_stands': '23',
#     'available_bikes': '0',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Mairie du 9e',
#     'lat': '45.7742408280787800',
#     'lng': '4.8056660114147770',
#     'bike_stands': '27',
#     'available_bike_stands': '18',
#     'available_bikes': '9',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Félix Faure / Vivier Merle',
#     'lat': '45.7538149056220500',
#     'lng': '4.8598558941293660',
#     'bike_stands': '35',
#     'available_bike_stands': '0',
#     'available_bikes': '0',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Childebert / Rivière',
#     'lat': '45.7598862786474200',
#     'lng': '4.8357987999345910',
#     'bike_stands': '23',
#     'available_bike_stands': '1',
#     'available_bikes': '22',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Augagneur / Fosse aux Ours',
#     'lat': '45.7571997023265400',
#     'lng': '4.8404991375424880',
#     'bike_stands': '40',
#     'available_bike_stands': '2',
#     'available_bikes': '38',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Oullins - Mairie',
#     'lat': '45.7140014190252940',
#     'lng': '4.8065443341113525',
#     'bike_stands': '18',
#     'available_bike_stands': '14',
#     'available_bikes': '4',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'République',
#     'lat': '45.7707838400683800',
#     'lng': '4.8729593888672900',
#     'bike_stands': '17',
#     'available_bike_stands': '12',
#     'available_bikes': '5',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Théâtre Romain',
#     'lat': '45.7583623960292900',
#     'lng': '4.8210866415482530',
#     'bike_stands': '12',
#     'available_bike_stands': '11',
#     'available_bikes': '1',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Universités Lyon III / Lyon II',
#     'lat': '45.7514132273513000',
#     'lng': '4.8363931815987780',
#     'bike_stands': '40',
#     'available_bike_stands': '16',
#     'available_bikes': '24',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': "Place d'Arsonval",
#     'lat': '45.7434156767836340',
#     'lng': '4.8789206164428370',
#     'bike_stands': '32',
#     'available_bike_stands': '29',
#     'available_bikes': '3',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Villette / St-Antoine',
#     'lat': '45.7628598508923400',
#     'lng': '4.8622869000871980',
#     'bike_stands': '23',
#     'available_bike_stands': '0',
#     'available_bikes': '22',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Place Joannès Ambre',
#     'lat': '45.7815755185206100',
#     'lng': '4.8328577220510200',
#     'bike_stands': '20',
#     'available_bike_stands': '14',
#     'available_bikes': '6',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Caluire - Saint-Clair',
#     'lat': '45.7854707644412200',
#     'lng': '4.8478421222935550',
#     'bike_stands': '20',
#     'available_bike_stands': '19',
#     'available_bikes': '1',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Part-Dieu / Deruelle',
#     'lat': '45.7629790120815440',
#     'lng': '4.8550066229888000',
#     'bike_stands': '30',
#     'available_bike_stands': '4',
#     'available_bikes': '25',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': "Place d'Helvétie",
#     'lat': '45.7731863072103200',
#     'lng': '4.8419593354412900',
#     'bike_stands': '30',
#     'available_bike_stands': '14',
#     'available_bikes': '16',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Villette',
#     'lat': '45.7577878804856440',
#     'lng': '4.8614973648418860',
#     'bike_stands': '38',
#     'available_bike_stands': '23',
#     'available_bikes': '15',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Bron - Centre Nautique',
#     'lat': '45.7429248383540640',
#     'lng': '4.9086213384119860',
#     'bike_stands': '13',
#     'available_bike_stands': '12',
#     'available_bikes': '1',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Philomène Magnin',
#     'lat': '45.7526125818453550',
#     'lng': '4.8587710033051470',
#     'bike_stands': '24',
#     'available_bike_stands': '19',
#     'available_bikes': '5',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Masaryk / Saint-Cyr',
#     'lat': '45.7786288989070300',
#     'lng': '4.8071200280976580',
#     'bike_stands': '13',
#     'available_bike_stands': '10',
#     'available_bikes': '3',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Vivier Merle / Paul Bert Ouest',
#     'lat': '45.7573393130977700',
#     'lng': '4.8585122373993705',
#     'bike_stands': '19',
#     'available_bike_stands': '8',
#     'available_bikes': '10',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Place de la Reconnaissance',
#     'lat': '45.7544402430766440',
#     'lng': '4.8853489189380230',
#     'bike_stands': '32',
#     'available_bike_stands': '27',
#     'available_bikes': '5',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Place Mendès France',
#     'lat': '45.7400516465032750',
#     'lng': '4.8594164128821960',
#     'bike_stands': '20',
#     'available_bike_stands': '16',
#     'available_bikes': '4',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Saint Fons - 4 chemins',
#     'lat': '45.7084437290321550',
#     'lng': '4.8548610775585280',
#     'bike_stands': '11',
#     'available_bike_stands': '10',
#     'available_bikes': '1',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Guillotière / Madeleine',
#     'lat': '45.7510565465262100',
#     'lng': '4.8480482303453220',
#     'bike_stands': '10',
#     'available_bike_stands': '8',
#     'available_bikes': '2',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Gailleton',
#     'lat': '45.7534495026210240',
#     'lng': '4.8333645518023690',
#     'bike_stands': '16',
#     'available_bike_stands': '4',
#     'available_bikes': '12',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Place Lebret',
#     'lat': '45.7356503881221000',
#     'lng': '4.8530426544700740',
#     'bike_stands': '14',
#     'available_bike_stands': '9',
#     'available_bikes': '5',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Brotteaux / Vauban',
#     'lat': '45.7663673112669600',
#     'lng': '4.8570018759142295',
#     'bike_stands': '15',
#     'available_bike_stands': '2',
#     'available_bikes': '13',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': "L'Ile Barbe",
#     'lat': '45.7974121962714450',
#     'lng': '4.8290463533634590',
#     'bike_stands': '16',
#     'available_bike_stands': '8',
#     'available_bikes': '8',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Mangini',
#     'lat': '45.7904088071307300',
#     'lng': '4.8163493917942380',
#     'bike_stands': '24',
#     'available_bike_stands': '7',
#     'available_bikes': '17',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Grégory Coupet',
#     'lat': '45.7817001067679500',
#     'lng': '4.8206000461275870',
#     'bike_stands': '16',
#     'available_bike_stands': '12',
#     'available_bikes': '4',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Rossellini / 11 Novembre',
#     'lat': '45.7793865753173900',
#     'lng': '4.8630954295037990',
#     'bike_stands': '30',
#     'available_bike_stands': '12',
#     'available_bikes': '16',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Place Valmy',
#     'lat': '45.7756749996432200',
#     'lng': '4.8053036651209080',
#     'bike_stands': '16',
#     'available_bike_stands': '1',
#     'available_bikes': '15',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': "Remparts d'Ainay",
#     'lat': '45.7530892095642200',
#     'lng': '4.8298071448327240',
#     'bike_stands': '24',
#     'available_bike_stands': '5',
#     'available_bikes': '19',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Martinière / Monplaisir',
#     'lat': '45.7408946957303000',
#     'lng': '4.8683054018251575',
#     'bike_stands': '20',
#     'available_bike_stands': '19',
#     'available_bikes': '1',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Célestins',
#     'lat': '45.7599398325897200',
#     'lng': '4.8320716113863760',
#     'bike_stands': '22',
#     'available_bike_stands': '0',
#     'available_bikes': '22',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Subsistances',
#     'lat': '45.7678957694769400',
#     'lng': '4.8198166574203690',
#     'bike_stands': '22',
#     'available_bike_stands': '3',
#     'available_bikes': '19',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Fontaines S/S - Quai JB Simon',
#     'lat': '45.8324657183306240',
#     'lng': '4.8487792326838310',
#     'bike_stands': '20',
#     'available_bike_stands': '16',
#     'available_bikes': '4',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Gabriel Péri',
#     'lat': '45.7723033504795540',
#     'lng': '4.8657606458135480',
#     'bike_stands': '12',
#     'available_bike_stands': '8',
#     'available_bikes': '4',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Philippe de Lassalle',
#     'lat': '45.7734801071979400',
#     'lng': '4.8213076459729780',
#     'bike_stands': '23',
#     'available_bike_stands': '21',
#     'available_bikes': '2',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Lafayette / Inkermann',
#     'lat': '45.7639360244316800',
#     'lng': '4.8659132544557260',
#     'bike_stands': '30',
#     'available_bike_stands': '27',
#     'available_bikes': '2',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Place Antonin Gourju',
#     'lat': '45.7594863490351000',
#     'lng': '4.8301699554160630',
#     'bike_stands': '30',
#     'available_bike_stands': '0',
#     'available_bikes': '30',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Porte des Enfants du Rhône',
#     'lat': '45.7774932959538900',
#     'lng': '4.8448707260176660',
#     'bike_stands': '40',
#     'available_bike_stands': '11',
#     'available_bikes': '29',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Préfecture / Sarrail',
#     'lat': '45.7648582723532300',
#     'lng': '4.8415654714910220',
#     'bike_stands': '20',
#     'available_bike_stands': '1',
#     'available_bikes': '19',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Saint-Romain / Berliet',
#     'lat': '45.7422568774361760',
#     'lng': '4.8603720894672350',
#     'bike_stands': '20',
#     'available_bike_stands': '18',
#     'available_bikes': '2',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Lyon Métropole',
#     'lat': '45.7881700188236600',
#     'lng': '4.8185602866725280',
#     'bike_stands': '25',
#     'available_bike_stands': '7',
#     'available_bikes': '18',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Saint Priest - Parc Technologique',
#     'lat': '45.7144103841041840',
#     'lng': '4.9310143156708940',
#     'bike_stands': '20',
#     'available_bike_stands': '18',
#     'available_bikes': '2',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Etats-Unis / Viviani',
#     'lat': '45.7247031652649550',
#     'lng': '4.8707659770891900',
#     'bike_stands': '20',
#     'available_bike_stands': '19',
#     'available_bikes': '1',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Place Antonin Poncet',
#     'lat': '45.7567623213032200',
#     'lng': '4.8339273966533850',
#     'bike_stands': '40',
#     'available_bike_stands': '7',
#     'available_bikes': '9',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Meissonier',
#     'lat': '45.7660850668592000',
#     'lng': '4.8328335830568180',
#     'bike_stands': '16',
#     'available_bike_stands': '2',
#     'available_bikes': '14',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Place Carnot',
#     'lat': '45.7512270521822700',
#     'lng': '4.8268908354867040',
#     'bike_stands': '30',
#     'available_bike_stands': '8',
#     'available_bikes': '22',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Philippe de Lassalle / Pillement',
#     'lat': '45.7774206479390600',
#     'lng': '4.8205384707114510',
#     'bike_stands': '13',
#     'available_bike_stands': '4',
#     'available_bikes': '9',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Mémoire et Société',
#     'lat': '45.7595776564178540',
#     'lng': '4.8827081207421840',
#     'bike_stands': '24',
#     'available_bike_stands': '21',
#     'available_bikes': '2',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Garibaldi',
#     'lat': '45.7706974838463400',
#     'lng': '4.8499357293643790',
#     'bike_stands': '11',
#     'available_bike_stands': '4',
#     'available_bikes': '7',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Saint-Just',
#     'lat': '45.7559666422450850',
#     'lng': '4.8189064482919700',
#     'bike_stands': '18',
#     'available_bike_stands': '11',
#     'available_bikes': '7',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Longefer / Krüger',
#     'lat': '45.7386714403411200',
#     'lng': '4.8781174224582780',
#     'bike_stands': '16',
#     'available_bike_stands': '10',
#     'available_bikes': '6',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Bron - Mairie',
#     'lat': '45.7339455296300700',
#     'lng': '4.9087206818679405',
#     'bike_stands': '23',
#     'available_bike_stands': '23',
#     'available_bikes': '0',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Gryphe / Montesquieu',
#     'lat': '45.7519114393107300',
#     'lng': '4.8437864046911105',
#     'bike_stands': '25',
#     'available_bike_stands': '18',
#     'available_bikes': '7',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Saint Pierre de Vaise',
#     'lat': '45.7730995725331500',
#     'lng': '4.8078137222645940',
#     'bike_stands': '15',
#     'available_bike_stands': '9',
#     'available_bikes': '6',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Place Sainte Anne',
#     'lat': '45.7570472666940200',
#     'lng': '4.8653318030820705',
#     'bike_stands': '18',
#     'available_bike_stands': '13',
#     'available_bikes': '5',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Université Lyon III',
#     'lat': '45.7485395662598650',
#     'lng': '4.8615417793642550',
#     'bike_stands': '36',
#     'available_bike_stands': '25',
#     'available_bikes': '11',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Hachette',
#     'lat': '45.7529160218789240',
#     'lng': '4.8638526893825510',
#     'bike_stands': '15',
#     'available_bike_stands': '12',
#     'available_bikes': '3',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Servant / Jaboulay',
#     'lat': '45.7467662258473740',
#     'lng': '4.8420506993495060',
#     'bike_stands': '16',
#     'available_bike_stands': '0',
#     'available_bikes': '16',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Doua / Avenue des Arts',
#     'lat': '45.7835136793198600',
#     'lng': '4.8712731104104920',
#     'bike_stands': '30',
#     'available_bike_stands': '2',
#     'available_bikes': '28',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Valdo / Rivet',
#     'lat': '45.7504814834310240',
#     'lng': '4.7887741211031210',
#     'bike_stands': '18',
#     'available_bike_stands': '17',
#     'available_bikes': '1',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Garibaldi / Vauban',
#     'lat': '45.7666921938824100',
#     'lng': '4.8520859812468150',
#     'bike_stands': '20',
#     'available_bike_stands': '10',
#     'available_bikes': '10',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Charles Hernu',
#     'lat': '45.7703105281291940',
#     'lng': '4.8620024989211670',
#     'bike_stands': '20',
#     'available_bike_stands': '3',
#     'available_bikes': '17',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Saint Genis Laval - Médiathèque',
#     'lat': '45.6978120018869000',
#     'lng': '4.7947728497160735',
#     'bike_stands': '12',
#     'available_bike_stands': '10',
#     'available_bikes': '2',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Bron - Place Curial',
#     'lat': '45.7366744242415300',
#     'lng': '4.9171004856320100',
#     'bike_stands': '25',
#     'available_bike_stands': '20',
#     'available_bikes': '5',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Place Bir-Hakeim',
#     'lat': '45.7525921437139600',
#     'lng': '4.8557101486887975',
#     'bike_stands': '19',
#     'available_bike_stands': '11',
#     'available_bikes': '8',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Quai Lassagne',
#     'lat': '45.7722014692572260',
#     'lng': '4.8379117929264730',
#     'bike_stands': '16',
#     'available_bike_stands': '11',
#     'available_bikes': '5',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Rockfeller / Esquirol',
#     'lat': '45.7413337186004100',
#     'lng': '4.8855408242791200',
#     'bike_stands': '19',
#     'available_bike_stands': '19',
#     'available_bikes': '0',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Cité Internationale - Cinéma',
#     'lat': '45.7847015036764200',
#     'lng': '4.8519081064540370',
#     'bike_stands': '32',
#     'available_bike_stands': '28',
#     'available_bikes': '4',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Place Bertone',
#     'lat': '45.7776173765049850',
#     'lng': '4.8345009421112760',
#     'bike_stands': '12',
#     'available_bike_stands': '12',
#     'available_bikes': '0',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'République / Stella',
#     'lat': '45.7607097863131200',
#     'lng': '4.8362889729420430',
#     'bike_stands': '27',
#     'available_bike_stands': '0',
#     'available_bikes': '27',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': '11 novembre / Gaston Berger',
#     'lat': '45.7790639863242460',
#     'lng': '4.8714964631896150',
#     'bike_stands': '35',
#     'available_bike_stands': '10',
#     'available_bikes': '24',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Place Aristide Briand',
#     'lat': '45.7530043530221000',
#     'lng': '4.8502474272199690',
#     'bike_stands': '38',
#     'available_bike_stands': '26',
#     'available_bikes': '11',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Balmont',
#     'lat': '45.7893151875845100',
#     'lng': '4.7991603409726270',
#     'bike_stands': '12',
#     'available_bike_stands': '10',
#     'available_bikes': '2',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Vaulx - Poudrette / La Soie',
#     'lat': '45.7644003130587800',
#     'lng': '4.9192757859473670',
#     'bike_stands': '20',
#     'available_bike_stands': '20',
#     'available_bikes': '0',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Créqui / Lafayette',
#     'lat': '45.7637960125263300',
#     'lng': '4.8470620002854570',
#     'bike_stands': '15',
#     'available_bike_stands': '8',
#     'available_bikes': '7',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Zola / France',
#     'lat': '45.7680704202145800',
#     'lng': '4.8871237200591935',
#     'bike_stands': '16',
#     'available_bike_stands': '3',
#     'available_bikes': '12',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Pressensé',
#     'lat': '45.7691684753850800',
#     'lng': '4.8967695846255020',
#     'bike_stands': '16',
#     'available_bike_stands': '15',
#     'available_bikes': '1',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Avenue Verguin',
#     'lat': '45.7729113974482800',
#     'lng': '4.8563267813588190',
#     'bike_stands': '20',
#     'available_bike_stands': '2',
#     'available_bikes': '17',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Techsud',
#     'lat': '45.7227999997408900',
#     'lng': '4.8427060003576160',
#     'bike_stands': '12',
#     'available_bike_stands': '5',
#     'available_bikes': '7',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'IUT - Feyssine',
#     'lat': '45.7856324623545000',
#     'lng': '4.8824104015349030',
#     'bike_stands': '30',
#     'available_bike_stands': '5',
#     'available_bikes': '25',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': "Place Rouget de L'Isle",
#     'lat': '45.7539631929670600',
#     'lng': '4.8673532946259150',
#     'bike_stands': '16',
#     'available_bike_stands': '9',
#     'available_bikes': '7',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Gare des Brotteaux',
#     'lat': '45.7669095802662650',
#     'lng': '4.8589921673125620',
#     'bike_stands': '16',
#     'available_bike_stands': '3',
#     'available_bikes': '13',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Bel Air / Les Brosses',
#     'lat': '45.7579070732360900',
#     'lng': '4.9108067086686680',
#     'bike_stands': '20',
#     'available_bike_stands': '18',
#     'available_bikes': '2',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Clos Savaron',
#     'lat': '45.7826362574796000',
#     'lng': '4.8255591851847730',
#     'bike_stands': '20',
#     'available_bike_stands': '19',
#     'available_bikes': '1',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Condorcet',
#     'lat': '45.7790305746488640',
#     'lng': '4.8668629009953690',
#     'bike_stands': '23',
#     'available_bike_stands': '0',
#     'available_bikes': '23',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Saint Exupéry',
#     'lat': '45.7588589710478640',
#     'lng': '4.8787495764625985',
#     'bike_stands': '15',
#     'available_bike_stands': '13',
#     'available_bikes': '2',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': "Allée de l'Europe",
#     'lat': '45.7836371650547900',
#     'lng': '4.7945253084995630',
#     'bike_stands': '12',
#     'available_bike_stands': '9',
#     'available_bikes': '3',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Albéric Pont',
#     'lat': '45.7534443435600400',
#     'lng': '4.8044009888454050',
#     'bike_stands': '16',
#     'available_bike_stands': '7',
#     'available_bikes': '9',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Lumière / Trouilhet',
#     'lat': '45.7435678516368260',
#     'lng': '4.8701017463457850',
#     'bike_stands': '16',
#     'available_bike_stands': '14',
#     'available_bikes': '2',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Sainte-Blandine',
#     'lat': '45.7444223014223040',
#     'lng': '4.8221428704396105',
#     'bike_stands': '16',
#     'available_bike_stands': '9',
#     'available_bikes': '6',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': "Place de l'Hippodrome",
#     'lat': '45.7455815521804800',
#     'lng': '4.8235326732363090',
#     'bike_stands': '24',
#     'available_bike_stands': '14',
#     'available_bikes': '10',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Place de la Ferrandière',
#     'lat': '45.7594733965948140',
#     'lng': '4.8693428966594270',
#     'bike_stands': '20',
#     'available_bike_stands': '16',
#     'available_bikes': '3',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Ménival / Eisenhower',
#     'lat': '45.7567552283432900',
#     'lng': '4.7832459078446250',
#     'bike_stands': '12',
#     'available_bike_stands': '3',
#     'available_bikes': '9',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Garibaldi / Domer',
#     'lat': '45.7477327368804800',
#     'lng': '4.8516273700582800',
#     'bike_stands': '19',
#     'available_bike_stands': '16',
#     'available_bikes': '3',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Feuillat / Lacassagne',
#     'lat': '45.7495627067970800',
#     'lng': '4.8759334029685050',
#     'bike_stands': '16',
#     'available_bike_stands': '13',
#     'available_bikes': '3',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Friche RVI',
#     'lat': '45.7483207051236600',
#     'lng': '4.8759239595508280',
#     'bike_stands': '20',
#     'available_bike_stands': '13',
#     'available_bikes': '7',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Delore / Audibert & Lavirotte',
#     'lat': '45.7357952320592900',
#     'lng': '4.8568128186712000',
#     'bike_stands': '18',
#     'available_bike_stands': '16',
#     'available_bikes': '2',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Place de la Paix',
#     'lat': '45.7680236126546500',
#     'lng': '4.8317412517184160',
#     'bike_stands': '20',
#     'available_bike_stands': '3',
#     'available_bikes': '17',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Paul Bert / Garibaldi',
#     'lat': '45.7571028581681740',
#     'lng': '4.8534807971166600',
#     'bike_stands': '20',
#     'available_bike_stands': '7',
#     'available_bikes': '13',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Sans Souci',
#     'lat': '45.7472487338214600',
#     'lng': '4.8652857830315160',
#     'bike_stands': '20',
#     'available_bike_stands': '19',
#     'available_bikes': '0',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Décines - Centre',
#     'lat': '45.7718733296366760',
#     'lng': '4.9557667876110880',
#     'bike_stands': '20',
#     'available_bike_stands': '11',
#     'available_bikes': '9',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Cité Internationale',
#     'lat': '45.7854214249623800',
#     'lng': '4.8541240727107640',
#     'bike_stands': '21',
#     'available_bike_stands': '16',
#     'available_bikes': '5',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Place Maréchal Lyautey',
#     'lat': '45.7693730577565400',
#     'lng': '4.8423179538871635',
#     'bike_stands': '20',
#     'available_bike_stands': '0',
#     'available_bikes': '20',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Bourbonnais',
#     'lat': '45.7734645659819600',
#     'lng': '4.8002879293936390',
#     'bike_stands': '12',
#     'available_bike_stands': '8',
#     'available_bikes': '4',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Perrache Est',
#     'lat': '45.7461030735744740',
#     'lng': '4.8256053939445850',
#     'bike_stands': '20',
#     'available_bike_stands': '4',
#     'available_bikes': '15',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Place Regaud',
#     'lat': '45.7630769295670000',
#     'lng': '4.8342866883470440',
#     'bike_stands': '12',
#     'available_bike_stands': '1',
#     'available_bikes': '11',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Parc du Centre',
#     'lat': '45.7719119252490800',
#     'lng': '4.8790707067819020',
#     'bike_stands': '16',
#     'available_bike_stands': '16',
#     'available_bikes': '0',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Berthelot / Cazeneuve',
#     'lat': '45.7373337133711400',
#     'lng': '4.8654943125527870',
#     'bike_stands': '20',
#     'available_bike_stands': '18',
#     'available_bikes': '2',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Métro Flachet',
#     'lat': '45.7670909450657100',
#     'lng': '4.8924286413845515',
#     'bike_stands': '22',
#     'available_bike_stands': '5',
#     'available_bikes': '17',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Part-Dieu / Villette',
#     'lat': '45.7600550578148400',
#     'lng': '4.8616738805899400',
#     'bike_stands': '30',
#     'available_bike_stands': '16',
#     'available_bikes': '14',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Place Gerson',
#     'lat': '45.7670544551410640',
#     'lng': '4.8270475070640995',
#     'bike_stands': '20',
#     'available_bike_stands': '7',
#     'available_bikes': '13',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Perrache / Carnot',
#     'lat': '45.7500996433260700',
#     'lng': '4.8280515013551550',
#     'bike_stands': '18',
#     'available_bike_stands': '1',
#     'available_bikes': '17',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Confluence / Docks',
#     'lat': '45.7396275873331000',
#     'lng': '4.8150259306438120',
#     'bike_stands': '26',
#     'available_bike_stands': '2',
#     'available_bikes': '24',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Sala / Rue du Plat',
#     'lat': '45.7568084876169440',
#     'lng': '4.8283743801395120',
#     'bike_stands': '14',
#     'available_bike_stands': '7',
#     'available_bikes': '7',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Terreaux / Terme',
#     'lat': '45.7677346863698560',
#     'lng': '4.8321350621908300',
#     'bike_stands': '16',
#     'available_bike_stands': '0',
#     'available_bikes': '16',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Pêcherie',
#     'lat': '45.7659547300349500',
#     'lng': '4.8311781246444845',
#     'bike_stands': '17',
#     'available_bike_stands': '4',
#     'available_bikes': '13',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Place Raspail',
#     'lat': '45.7557687140506700',
#     'lng': '4.8407327899664360',
#     'bike_stands': '22',
#     'available_bike_stands': '19',
#     'available_bikes': '3',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Doua / Rue des sports',
#     'lat': '45.7844851872384300',
#     'lng': '4.8774042325766300',
#     'bike_stands': '30',
#     'available_bike_stands': '13',
#     'available_bikes': '17',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Vaillant / Perroncel',
#     'lat': '45.7753988102813600',
#     'lng': '4.8802630912578130',
#     'bike_stands': '17',
#     'available_bike_stands': '11',
#     'available_bikes': '6',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Anatole France / Barbusse',
#     'lat': '45.7681141025166000',
#     'lng': '4.8790813175577960',
#     'bike_stands': '20',
#     'available_bike_stands': '17',
#     'available_bikes': '3',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Jean Jaurès',
#     'lat': '45.7375180973509360',
#     'lng': '4.8375089199170210',
#     'bike_stands': '16',
#     'available_bike_stands': '7',
#     'available_bikes': '9',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Parc des Berges',
#     'lat': '45.7377409586890200',
#     'lng': '4.8244875157097110',
#     'bike_stands': '25',
#     'available_bike_stands': '11',
#     'available_bikes': '14',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Patinoire Baraban',
#     'lat': '45.7620516689039150',
#     'lng': '4.8685003507160690',
#     'bike_stands': '20',
#     'available_bike_stands': '15',
#     'available_bikes': '5',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Tabareau',
#     'lat': '45.7740806705343900',
#     'lng': '4.8251597121983645',
#     'bike_stands': '10',
#     'available_bike_stands': '6',
#     'available_bikes': '4',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Place Danton',
#     'lat': '45.7548124485154400',
#     'lng': '4.8575743726010305',
#     'bike_stands': '18',
#     'available_bike_stands': '13',
#     'available_bikes': '5',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Lafayette / Corneille',
#     'lat': '45.7637594783418750',
#     'lng': '4.8437773405191870',
#     'bike_stands': '13',
#     'available_bike_stands': '1',
#     'available_bikes': '12',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Berthelot / Route de Vienne',
#     'lat': '45.7425795049166550',
#     'lng': '4.8505637556621760',
#     'bike_stands': '15',
#     'available_bike_stands': '14',
#     'available_bikes': '1',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Charmettes / Bellecombe',
#     'lat': '45.7663703493176260',
#     'lng': '4.8650841638710620',
#     'bike_stands': '16',
#     'available_bike_stands': '16',
#     'available_bikes': '0',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Institut Lumière',
#     'lat': '45.7458332337286600',
#     'lng': '4.8706387106502870',
#     'bike_stands': '18',
#     'available_bike_stands': '17',
#     'available_bikes': '1',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Francis de Pressenssé',
#     'lat': '45.7314272671117600',
#     'lng': '4.8600379663129870',
#     'bike_stands': '22',
#     'available_bike_stands': '21',
#     'available_bikes': '1',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Masset / Saint-Pierre de Vaise',
#     'lat': '45.7704769200645740',
#     'lng': '4.8009004832411430',
#     'bike_stands': '16',
#     'available_bike_stands': '12',
#     'available_bikes': '4',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Place de la paix',
#     'lat': '45.7520997282193140',
#     'lng': '4.9146430086846320',
#     'bike_stands': '17',
#     'available_bike_stands': '14',
#     'available_bikes': '3',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Place du Lac',
#     'lat': '45.7588856223001300',
#     'lng': '4.8537678938544730',
# ...
#     'lng': '4.8447649388425830',
#     'bike_stands': '20',
#     'available_bike_stands': '1',
#     'available_bikes': '19',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Marseille / Université',
#     'lat': '45.7509549511840560',
#     'lng': '4.8392671207183300',
#     'bike_stands': '40',
#     'available_bike_stands': '3',
#     'available_bikes': '36',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Salengro / Descartes',
#     'lat': '45.7762463810845300',
#     'lng': '4.8716371652356000',
#     'bike_stands': '15',
#     'available_bike_stands': '8',
#     'available_bikes': '6',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Point du Jour / Granges',
#     'lat': '45.7561939286588800',
#     'lng': '4.8027110791690140',
#     'bike_stands': '13',
#     'available_bike_stands': '6',
#     'available_bikes': '7',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Verdun / Desgrand',
#     'lat': '45.7840513436847400',
#     'lng': '4.8970859241187770',
#     'bike_stands': '21',
#     'available_bike_stands': '0',
#     'available_bikes': '21',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Vénissieux - Place Romand',
#     'lat': '45.7257547271142850',
#     'lng': '4.8583509977388920',
#     'bike_stands': '20',
#     'available_bike_stands': '19',
#     'available_bikes': '1',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Saint Priest - Cité Berliet',
#     'lat': '45.7059819724876400',
#     'lng': '4.9009848506091010',
#     'bike_stands': '20',
#     'available_bike_stands': '18',
#     'available_bikes': '2',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': '11 novembre',
#     'lat': '45.7796937078335100',
#     'lng': '4.8600085938999790',
#     'bike_stands': '35',
#     'available_bike_stands': '2',
#     'available_bikes': '33',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Place Adrien Godien',
#     'lat': '45.7787675773143300',
#     'lng': '4.8410695622109970',
#     'bike_stands': '30',
#     'available_bike_stands': '24',
#     'available_bikes': '6',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Branly / Pasteur',
#     'lat': '45.7915896614286200',
#     'lng': '4.8433313161068385',
#     'bike_stands': '15',
#     'available_bike_stands': '8',
#     'available_bikes': '7',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Vénissieux - Levy - Vienne',
#     'lat': '45.7193988058185000',
#     'lng': '4.8548015762351050',
#     'bike_stands': '18',
#     'available_bike_stands': '11',
#     'available_bikes': '7',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Musée Africain',
#     'lat': '45.7502533119060360',
#     'lng': '4.8579250300630620',
#     'bike_stands': '22',
#     'available_bike_stands': '19',
#     'available_bikes': '3',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Tolstoï / Florian',
#     'lat': '45.7618051903302860',
#     'lng': '4.8807224046277390',
#     'bike_stands': '21',
#     'available_bike_stands': '21',
#     'available_bikes': '0',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Sergent Berthet / Gorge de Loup',
#     'lat': '45.7701340720176050',
#     'lng': '4.8051580030149460',
#     'bike_stands': '16',
#     'available_bike_stands': '13',
#     'available_bikes': '3',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Saxe / Dunoir',
#     'lat': '45.7609213906398600',
#     'lng': '4.8451935986950010',
#     'bike_stands': '37',
#     'available_bike_stands': '10',
#     'available_bikes': '27',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Berlioz / Chalinel',
#     'lat': '45.8011198081158200',
#     'lng': '4.8252725616689830',
#     'bike_stands': '15',
#     'available_bike_stands': '14',
#     'available_bikes': '1',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'GrandClément',
#     'lat': '45.7597183207295700',
#     'lng': '4.8899469363178760',
#     'bike_stands': '19',
#     'available_bike_stands': '19',
#     'available_bikes': '0',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Fulchiron',
#     'lat': '45.7520011769432900',
#     'lng': '4.8216617983516280',
#     'bike_stands': '19',
#     'available_bike_stands': '16',
#     'available_bikes': '3',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Domer / Chevreul',
#     'lat': '45.7466748285384950',
#     'lng': '4.8444434656856060',
#     'bike_stands': '12',
#     'available_bike_stands': '4',
#     'available_bikes': '8',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Vinatier',
#     'lat': '45.7419115491076800',
#     'lng': '4.8939591141013690',
#     'bike_stands': '20',
#     'available_bike_stands': '20',
#     'available_bikes': '0',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Beauvisage / Préssensé',
#     'lat': '45.7278718558835000',
#     'lng': '4.8634420589052640',
#     'bike_stands': '17',
#     'available_bike_stands': '17',
#     'available_bikes': '0',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'BioParc',
#     'lat': '45.7404860034671760',
#     'lng': '4.8880825075933510',
#     'bike_stands': '20',
#     'available_bike_stands': '20',
#     'available_bikes': '0',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Quai Romain Rolland',
#     'lat': '45.7620370806926700',
#     'lng': '4.8288896824580405',
#     'bike_stands': '17',
#     'available_bike_stands': '7',
#     'available_bikes': '10',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Mercière / Ferrandière',
#     'lat': '45.7620553014781300',
#     'lng': '4.8332059556379780',
#     'bike_stands': '10',
#     'available_bike_stands': '0',
#     'available_bikes': '10',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Ménival / Joliot Curie',
#     'lat': '45.7546405115265300',
#     'lng': '4.7881488839855880',
#     'bike_stands': '20',
#     'available_bike_stands': '6',
#     'available_bikes': '14',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Charité / Récamier',
#     'lat': '45.7492533954913900',
#     'lng': '4.8298441257520310',
#     'bike_stands': '17',
#     'available_bike_stands': '0',
#     'available_bikes': '16',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Vaulx - Bibliothèque',
#     'lat': '45.7570697600648660',
#     'lng': '4.9273216112656590',
#     'bike_stands': '15',
#     'available_bike_stands': '13',
#     'available_bikes': '2',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Saint Cyr',
#     'lat': '45.7997914275755500',
#     'lng': '4.8196018687552730',
#     'bike_stands': '12',
#     'available_bike_stands': '11',
#     'available_bikes': '1',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Les Halles',
#     'lat': '45.7640576127189100',
#     'lng': '4.8499305460757520',
#     'bike_stands': '15',
#     'available_bike_stands': '0',
#     'available_bikes': '15',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Desaix',
#     'lat': '45.7572612599251600',
#     'lng': '4.8552008564228180',
#     'bike_stands': '28',
#     'available_bike_stands': '21',
#     'available_bikes': '7',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Rue de la Baleine',
#     'lat': '45.7633837102434300',
#     'lng': '4.8290114774217890',
#     'bike_stands': '14',
#     'available_bike_stands': '3',
#     'available_bikes': '3',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Vivier Merle / Paul Bert Est',
#     'lat': '45.7572314152350900',
#     'lng': '4.8589083673700480',
#     'bike_stands': '20',
#     'available_bike_stands': '13',
#     'available_bikes': '7',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Caluire - Passerelle de la Paix',
#     'lat': '45.7879516402910550',
#     'lng': '4.8530543333992190',
#     'bike_stands': '25',
#     'available_bike_stands': '20',
#     'available_bikes': '5',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Place des Archives',
#     'lat': '45.7479691410901740',
#     'lng': '4.8248617280093150',
#     'bike_stands': '40',
#     'available_bike_stands': '10',
#     'available_bikes': '21',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Lycée Marie Curie',
#     'lat': '45.7615279698755500',
#     'lng': '4.8956902199613600',
#     'bike_stands': '15',
#     'available_bike_stands': '14',
#     'available_bikes': '1',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Piscine de Vaise',
#     'lat': '45.7710182884515100',
#     'lng': '4.7964503487575510',
#     'bike_stands': '19',
#     'available_bike_stands': '1',
#     'available_bikes': '18',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': "Récamier / Tête d'Or",
#     'lat': '45.7643336975612060',
#     'lng': '4.8534921297061950',
#     'bike_stands': '16',
#     'available_bike_stands': '3',
#     'available_bikes': '13',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Docteur Damidot',
#     'lat': '45.7618201068858800',
#     'lng': '4.8861338655236200',
#     'bike_stands': '18',
#     'available_bike_stands': '18',
#     'available_bikes': '0',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'République / Paufique',
#     'lat': '45.7593809563465260',
#     'lng': '4.8353992022816500',
#     'bike_stands': '28',
#     'available_bike_stands': '0',
#     'available_bikes': '28',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Sainte Foy - Place Saint-Luc',
#     'lat': '45.7495654052048600',
#     'lng': '4.8008960240920420',
#     'bike_stands': '15',
#     'available_bike_stands': '8',
#     'available_bikes': '7',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Carmélites',
#     'lat': '45.7700015740910800',
#     'lng': '4.8292695053207500',
#     'bike_stands': '16',
#     'available_bike_stands': '14',
#     'available_bikes': '1',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Villeurbanne Saint-Jean',
#     'lat': '45.7804458217109400',
#     'lng': '4.9044888457892960',
#     'bike_stands': '12',
#     'available_bike_stands': '0',
#     'available_bikes': '12',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Jaurès / Saint Exupéry',
#     'lat': '45.7576523213066860',
#     'lng': '4.8834709512316210',
#     'bike_stands': '25',
#     'available_bike_stands': '25',
#     'available_bikes': '0',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Stalingrad / Meliès',
#     'lat': '45.7766967138823300',
#     'lng': '4.8595230519892390',
#     'bike_stands': '24',
#     'available_bike_stands': '1',
#     'available_bikes': '23',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Terreaux / Beaux Arts',
#     'lat': '45.7670410048109700',
#     'lng': '4.8342839059717140',
#     'bike_stands': '11',
#     'available_bike_stands': '5',
#     'available_bikes': '6',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Bellecour / Saint Exupéry',
#     'lat': '45.7581569109321860',
#     'lng': '4.8304346949094690',
#     'bike_stands': '40',
#     'available_bike_stands': '5',
#     'available_bikes': '35',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Part-Dieu / Garibaldi',
#     'lat': '45.7627511569952000',
#     'lng': '4.8524277723450730',
#     'bike_stands': '20',
#     'available_bike_stands': '4',
#     'available_bikes': '16',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Place Varillon (funiculaire St-Just)',
#     'lat': '45.7573003219205000',
#     'lng': '4.8150900113095240',
#     'bike_stands': '23',
#     'available_bike_stands': '13',
#     'available_bikes': '10',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Créqui / Voltaire',
#     'lat': '45.7566983441751900',
#     'lng': '4.8484034857557150',
#     'bike_stands': '30',
#     'available_bike_stands': '23',
#     'available_bikes': '7',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Guillotière / Veyron',
#     'lat': '45.7479327825068000',
#     'lng': '4.8563371818097670',
#     'bike_stands': '30',
#     'available_bike_stands': '',
#     'available_bikes': '',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Pierre Bénite - Europe',
#     'lat': '45.7032558571012300',
#     'lng': '4.8212003761276780',
#     'bike_stands': '15',
#     'available_bike_stands': '10',
#     'available_bikes': '5',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Vienne / Montagny',
#     'lat': '45.7324819782407700',
#     'lng': '4.8534099750018610',
#     'bike_stands': '20',
#     'available_bike_stands': '9',
#     'available_bikes': '11',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Gare de Vaise',
#     'lat': '45.7797819839255400',
#     'lng': '4.8046653309593905',
#     'bike_stands': '22',
#     'available_bike_stands': '1',
#     'available_bikes': '20',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Place Ambroise Courtois',
#     'lat': '45.7452926164535000',
#     'lng': '4.8716789632578010',
#     'bike_stands': '20',
#     'available_bike_stands': '16',
#     'available_bikes': '3',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Piaton / Condorcet',
#     'lat': '45.7742151784181300',
#     'lng': '4.8675042131350820',
#     'bike_stands': '20',
#     'available_bike_stands': '9',
#     'available_bikes': '10',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Gorge de Loup',
#     'lat': '45.7673654785190900',
#     'lng': '4.8056276995192775',
#     'bike_stands': '40',
#     'available_bike_stands': '40',
#     'available_bikes': '0',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Place Ennemond Fousseret',
#     'lat': '45.7646815056712300',
#     'lng': '4.8289833265225160',
#     'bike_stands': '16',
#     'available_bike_stands': '9',
#     'available_bikes': '7',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Garibaldi / Pensionnat',
#     'lat': '45.7547065642496240',
#     'lng': '4.8534044474099280',
#     'bike_stands': '30',
#     'available_bike_stands': '25',
#     'available_bikes': '5',
#     'ville': 'Lyon',
#     '@type': 'station'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Laënnec',
#     'lat': '45.7413487229911060',
#     'lng': '4.8797231637591720',
#     'bike_stands': '16',
#     'available_bike_stands': '16',
#     'available_bikes': '0',
#     'ville': 'Lyon',
#     '@type': 'station'}}]}

# %%
data_lyon={
    "@context":{
        "@vocab": "http://schema.org/", 
		"@base": "http://data.org/", 
		"name": "name",
        "available_bike_stands":"available_bike_stands",
        "available_bikes":"available_bikes",
        "bike_stands":"bike_stands",
		"lat": "lat", 
		"long": "long",
        "ville":"ville",
    },
    "features":[
        data_lyon
    ]
}

# %%
import json 
with open('lyon_bikes_records.json', 'w') as fp:
   json.dump(data_lyon, fp,ensure_ascii=False)

# %%
url_rennes= 'https://data.rennesmetropole.fr/api/records/1.0/search/?dataset=etat-des-stations-le-velo-star-en-temps-reel'
data_rennes = requests.get(url_rennes).json()

data_rennes
# Out:
# {'nhits': 54,
#  'parameters': {'dataset': ['etat-des-stations-le-velo-star-en-temps-reel'],
#   'timezone': 'UTC',
#   'rows': 10,
#   'start': 0,
#   'format': 'json'},
#  'records': [{'datasetid': 'etat-des-stations-le-velo-star-en-temps-reel',
#    'recordid': '88a8871cd455b991aae541e2d60ebdab34840e3e',
#    'fields': {'etat': 'En fonctionnement',
#     'lastupdate': '2021-03-24T15:01:09+00:00',
#     'nombrevelosdisponibles': 6,
#     'nombreemplacementsactuels': 16,
#     'nom': 'Musée Beaux-Arts',
#     'nombreemplacementsdisponibles': 10,
#     'idstation': '5510',
#     'coordonnees': [48.109601, -1.67408]},
#    'geometry': {'type': 'Point', 'coordinates': [-1.67408, 48.109601]},
#    'record_timestamp': '2021-03-24T15:01:00+00:00'},
#   {'datasetid': 'etat-des-stations-le-velo-star-en-temps-reel',
#    'recordid': 'b476b4248e499552a1449cb8afe72cc68c83c060',
#    'fields': {'etat': 'En panne',
#     'lastupdate': '2021-03-24T15:01:09+00:00',
#     'nombrevelosdisponibles': 10,
#     'nombreemplacementsactuels': 24,
#     'nom': 'Champs Libres',
#     'nombreemplacementsdisponibles': 14,
#     'idstation': '5516',
#     'coordonnees': [48.105537, -1.674328]},
#    'geometry': {'type': 'Point', 'coordinates': [-1.674328, 48.105537]},
#    'record_timestamp': '2021-03-24T15:01:00+00:00'},
#   {'datasetid': 'etat-des-stations-le-velo-star-en-temps-reel',
#    'recordid': 'bd0f83abcec2974fda4a9be7b78f4bfbb3af4b27',
#    'fields': {'etat': 'En fonctionnement',
#     'lastupdate': '2021-03-24T15:01:09+00:00',
#     'nombrevelosdisponibles': 18,
#     'nombreemplacementsactuels': 24,
#     'nom': 'Brest - Verdun',
#     'nombreemplacementsdisponibles': 6,
#     'idstation': '5534',
#     'coordonnees': [48.113009, -1.693264]},
#    'geometry': {'type': 'Point', 'coordinates': [-1.693264, 48.113009]},
#    'record_timestamp': '2021-03-24T15:01:00+00:00'},
#   {'datasetid': 'etat-des-stations-le-velo-star-en-temps-reel',
#    'recordid': 'bc23b982c96a853bb90665c1d574e7d9c204daed',
#    'fields': {'etat': 'En fonctionnement',
#     'lastupdate': '2021-03-24T15:01:09+00:00',
#     'nombrevelosdisponibles': 11,
#     'nombreemplacementsactuels': 20,
#     'nom': 'Marbeuf',
#     'nombreemplacementsdisponibles': 9,
#     'idstation': '5538',
#     'coordonnees': [48.111749, -1.702077]},
#    'geometry': {'type': 'Point', 'coordinates': [-1.702077, 48.111749]},
#    'record_timestamp': '2021-03-24T15:01:00+00:00'},
#   {'datasetid': 'etat-des-stations-le-velo-star-en-temps-reel',
#    'recordid': '77cac0a1ecd7f2af56c8668b201afe2a20e1c6bb',
#    'fields': {'etat': 'En fonctionnement',
#     'lastupdate': '2021-03-24T15:01:09+00:00',
#     'nombrevelosdisponibles': 14,
#     'nombreemplacementsactuels': 24,
#     'nom': 'Plaine de Baud',
#     'nombreemplacementsdisponibles': 10,
#     'idstation': '5546',
#     'coordonnees': [48.112461, -1.643674]},
#    'geometry': {'type': 'Point', 'coordinates': [-1.643674, 48.112461]},
#    'record_timestamp': '2021-03-24T15:01:00+00:00'},
#   {'datasetid': 'etat-des-stations-le-velo-star-en-temps-reel',
#    'recordid': 'f31381b27f50bb4bc23672b3ea5cc7abfca309c3',
#    'fields': {'etat': 'En panne',
#     'lastupdate': '2021-02-02T12:19:05+00:00',
#     'nombrevelosdisponibles': 8,
#     'nombreemplacementsactuels': 17,
#     'nom': 'Gros-Chêne',
#     'nombreemplacementsdisponibles': 9,
#     'idstation': '5578',
#     'coordonnees': [48.126795, -1.665101]},
#    'geometry': {'type': 'Point', 'coordinates': [-1.665101, 48.126795]},
#    'record_timestamp': '2021-03-24T15:01:00+00:00'},
#   {'datasetid': 'etat-des-stations-le-velo-star-en-temps-reel',
#    'recordid': '7612c409a64e0434defb0d56508363c591be8afe',
#    'fields': {'etat': 'En fonctionnement',
#     'lastupdate': '2021-03-24T15:01:09+00:00',
#     'nombrevelosdisponibles': 8,
#     'nombreemplacementsactuels': 29,
#     'nom': 'Painlevé',
#     'nombreemplacementsdisponibles': 21,
#     'idstation': '5580',
#     'coordonnees': [48.123506, -1.659762]},
#    'geometry': {'type': 'Point', 'coordinates': [-1.659762, 48.123506]},
#    'record_timestamp': '2021-03-24T15:01:00+00:00'},
#   {'datasetid': 'etat-des-stations-le-velo-star-en-temps-reel',
#    'recordid': '0cedc710c25c3651e1d950725c9633a9065fd871',
#    'fields': {'etat': 'En fonctionnement',
#     'lastupdate': '2021-03-24T15:01:09+00:00',
#     'nombrevelosdisponibles': 16,
#     'nombreemplacementsactuels': 30,
#     'nom': 'Joliot-Curie - Chateaubriand',
#     'nombreemplacementsdisponibles': 14,
#     'idstation': '5581',
#     'coordonnees': [48.124389, -1.651203]},
#    'geometry': {'type': 'Point', 'coordinates': [-1.651203, 48.124389]},
#    'record_timestamp': '2021-03-24T15:01:00+00:00'},
#   {'datasetid': 'etat-des-stations-le-velo-star-en-temps-reel',
#    'recordid': '1ee377102079bbe4ea444ded261fd2dcbfe8d3fb',
#    'fields': {'etat': 'En panne',
#     'lastupdate': '2021-03-24T15:01:09+00:00',
#     'nombrevelosdisponibles': 0,
#     'nombreemplacementsactuels': 1,
#     'nom': 'La Poterie',
#     'nombreemplacementsdisponibles': 1,
#     'idstation': '5582',
#     'coordonnees': [48.087282, -1.644121]},
#    'geometry': {'type': 'Point', 'coordinates': [-1.644121, 48.087282]},
#    'record_timestamp': '2021-03-24T15:01:00+00:00'},
#   {'datasetid': 'etat-des-stations-le-velo-star-en-temps-reel',
#    'recordid': 'a226d7f1b153bc8736f2e19a35456f03c3596a5d',
#    'fields': {'etat': 'En fonctionnement',
#     'lastupdate': '2021-03-24T15:01:09+00:00',
#     'nombrevelosdisponibles': 5,
#     'nombreemplacementsactuels': 20,
#     'nom': 'Pont de Strasbourg',
#     'nombreemplacementsdisponibles': 15,
#     'idstation': '5587',
#     'coordonnees': [48.109859, -1.656028]},
#    'geometry': {'type': 'Point', 'coordinates': [-1.656028, 48.109859]},
#    'record_timestamp': '2021-03-24T15:01:00+00:00'}]}

# %%
data_rennes["type"]="FeatureCollection"
data_rennes["name"]="Stations de velos Rennes"
del data_rennes['nhits']
del data_rennes['parameters']

data_rennes
# Out:
# {'records': [{'datasetid': 'etat-des-stations-le-velo-star-en-temps-reel',
#    'recordid': '88a8871cd455b991aae541e2d60ebdab34840e3e',
#    'fields': {'etat': 'En fonctionnement',
#     'lastupdate': '2021-03-24T15:01:09+00:00',
#     'nombrevelosdisponibles': 6,
#     'nombreemplacementsactuels': 16,
#     'nom': 'Musée Beaux-Arts',
#     'nombreemplacementsdisponibles': 10,
#     'idstation': '5510',
#     'coordonnees': [48.109601, -1.67408]},
#    'geometry': {'type': 'Point', 'coordinates': [-1.67408, 48.109601]},
#    'record_timestamp': '2021-03-24T15:01:00+00:00'},
#   {'datasetid': 'etat-des-stations-le-velo-star-en-temps-reel',
#    'recordid': 'b476b4248e499552a1449cb8afe72cc68c83c060',
#    'fields': {'etat': 'En panne',
#     'lastupdate': '2021-03-24T15:01:09+00:00',
#     'nombrevelosdisponibles': 10,
#     'nombreemplacementsactuels': 24,
#     'nom': 'Champs Libres',
#     'nombreemplacementsdisponibles': 14,
#     'idstation': '5516',
#     'coordonnees': [48.105537, -1.674328]},
#    'geometry': {'type': 'Point', 'coordinates': [-1.674328, 48.105537]},
#    'record_timestamp': '2021-03-24T15:01:00+00:00'},
#   {'datasetid': 'etat-des-stations-le-velo-star-en-temps-reel',
#    'recordid': 'bd0f83abcec2974fda4a9be7b78f4bfbb3af4b27',
#    'fields': {'etat': 'En fonctionnement',
#     'lastupdate': '2021-03-24T15:01:09+00:00',
#     'nombrevelosdisponibles': 18,
#     'nombreemplacementsactuels': 24,
#     'nom': 'Brest - Verdun',
#     'nombreemplacementsdisponibles': 6,
#     'idstation': '5534',
#     'coordonnees': [48.113009, -1.693264]},
#    'geometry': {'type': 'Point', 'coordinates': [-1.693264, 48.113009]},
#    'record_timestamp': '2021-03-24T15:01:00+00:00'},
#   {'datasetid': 'etat-des-stations-le-velo-star-en-temps-reel',
#    'recordid': 'bc23b982c96a853bb90665c1d574e7d9c204daed',
#    'fields': {'etat': 'En fonctionnement',
#     'lastupdate': '2021-03-24T15:01:09+00:00',
#     'nombrevelosdisponibles': 11,
#     'nombreemplacementsactuels': 20,
#     'nom': 'Marbeuf',
#     'nombreemplacementsdisponibles': 9,
#     'idstation': '5538',
#     'coordonnees': [48.111749, -1.702077]},
#    'geometry': {'type': 'Point', 'coordinates': [-1.702077, 48.111749]},
#    'record_timestamp': '2021-03-24T15:01:00+00:00'},
#   {'datasetid': 'etat-des-stations-le-velo-star-en-temps-reel',
#    'recordid': '77cac0a1ecd7f2af56c8668b201afe2a20e1c6bb',
#    'fields': {'etat': 'En fonctionnement',
#     'lastupdate': '2021-03-24T15:01:09+00:00',
#     'nombrevelosdisponibles': 14,
#     'nombreemplacementsactuels': 24,
#     'nom': 'Plaine de Baud',
#     'nombreemplacementsdisponibles': 10,
#     'idstation': '5546',
#     'coordonnees': [48.112461, -1.643674]},
#    'geometry': {'type': 'Point', 'coordinates': [-1.643674, 48.112461]},
#    'record_timestamp': '2021-03-24T15:01:00+00:00'},
#   {'datasetid': 'etat-des-stations-le-velo-star-en-temps-reel',
#    'recordid': 'f31381b27f50bb4bc23672b3ea5cc7abfca309c3',
#    'fields': {'etat': 'En panne',
#     'lastupdate': '2021-02-02T12:19:05+00:00',
#     'nombrevelosdisponibles': 8,
#     'nombreemplacementsactuels': 17,
#     'nom': 'Gros-Chêne',
#     'nombreemplacementsdisponibles': 9,
#     'idstation': '5578',
#     'coordonnees': [48.126795, -1.665101]},
#    'geometry': {'type': 'Point', 'coordinates': [-1.665101, 48.126795]},
#    'record_timestamp': '2021-03-24T15:01:00+00:00'},
#   {'datasetid': 'etat-des-stations-le-velo-star-en-temps-reel',
#    'recordid': '7612c409a64e0434defb0d56508363c591be8afe',
#    'fields': {'etat': 'En fonctionnement',
#     'lastupdate': '2021-03-24T15:01:09+00:00',
#     'nombrevelosdisponibles': 8,
#     'nombreemplacementsactuels': 29,
#     'nom': 'Painlevé',
#     'nombreemplacementsdisponibles': 21,
#     'idstation': '5580',
#     'coordonnees': [48.123506, -1.659762]},
#    'geometry': {'type': 'Point', 'coordinates': [-1.659762, 48.123506]},
#    'record_timestamp': '2021-03-24T15:01:00+00:00'},
#   {'datasetid': 'etat-des-stations-le-velo-star-en-temps-reel',
#    'recordid': '0cedc710c25c3651e1d950725c9633a9065fd871',
#    'fields': {'etat': 'En fonctionnement',
#     'lastupdate': '2021-03-24T15:01:09+00:00',
#     'nombrevelosdisponibles': 16,
#     'nombreemplacementsactuels': 30,
#     'nom': 'Joliot-Curie - Chateaubriand',
#     'nombreemplacementsdisponibles': 14,
#     'idstation': '5581',
#     'coordonnees': [48.124389, -1.651203]},
#    'geometry': {'type': 'Point', 'coordinates': [-1.651203, 48.124389]},
#    'record_timestamp': '2021-03-24T15:01:00+00:00'},
#   {'datasetid': 'etat-des-stations-le-velo-star-en-temps-reel',
#    'recordid': '1ee377102079bbe4ea444ded261fd2dcbfe8d3fb',
#    'fields': {'etat': 'En panne',
#     'lastupdate': '2021-03-24T15:01:09+00:00',
#     'nombrevelosdisponibles': 0,
#     'nombreemplacementsactuels': 1,
#     'nom': 'La Poterie',
#     'nombreemplacementsdisponibles': 1,
#     'idstation': '5582',
#     'coordonnees': [48.087282, -1.644121]},
#    'geometry': {'type': 'Point', 'coordinates': [-1.644121, 48.087282]},
#    'record_timestamp': '2021-03-24T15:01:00+00:00'},
#   {'datasetid': 'etat-des-stations-le-velo-star-en-temps-reel',
#    'recordid': 'a226d7f1b153bc8736f2e19a35456f03c3596a5d',
#    'fields': {'etat': 'En fonctionnement',
#     'lastupdate': '2021-03-24T15:01:09+00:00',
#     'nombrevelosdisponibles': 5,
#     'nombreemplacementsactuels': 20,
#     'nom': 'Pont de Strasbourg',
#     'nombreemplacementsdisponibles': 15,
#     'idstation': '5587',
#     'coordonnees': [48.109859, -1.656028]},
#    'geometry': {'type': 'Point', 'coordinates': [-1.656028, 48.109859]},
#    'record_timestamp': '2021-03-24T15:01:00+00:00'}],
#  'type': 'FeatureCollection',
#  'name': 'Stations de velos Rennes'}

# %%
for element in data_rennes['records']:
    del element['datasetid']
    del element['recordid']
    del element['fields']['etat']
    del element['fields']['lastupdate']
    del element['fields']['idstation']
    del element['geometry']
    del element['record_timestamp']
    element['fields']
  

    
data_rennes
# Out:
# {'records': [{'fields': {'nombrevelosdisponibles': 6,
#     'nombreemplacementsactuels': 16,
#     'nom': 'Musée Beaux-Arts',
#     'nombreemplacementsdisponibles': 10,
#     'coordonnees': [48.109601, -1.67408]}},
#   {'fields': {'nombrevelosdisponibles': 10,
#     'nombreemplacementsactuels': 24,
#     'nom': 'Champs Libres',
#     'nombreemplacementsdisponibles': 14,
#     'coordonnees': [48.105537, -1.674328]}},
#   {'fields': {'nombrevelosdisponibles': 18,
#     'nombreemplacementsactuels': 24,
#     'nom': 'Brest - Verdun',
#     'nombreemplacementsdisponibles': 6,
#     'coordonnees': [48.113009, -1.693264]}},
#   {'fields': {'nombrevelosdisponibles': 11,
#     'nombreemplacementsactuels': 20,
#     'nom': 'Marbeuf',
#     'nombreemplacementsdisponibles': 9,
#     'coordonnees': [48.111749, -1.702077]}},
#   {'fields': {'nombrevelosdisponibles': 14,
#     'nombreemplacementsactuels': 24,
#     'nom': 'Plaine de Baud',
#     'nombreemplacementsdisponibles': 10,
#     'coordonnees': [48.112461, -1.643674]}},
#   {'fields': {'nombrevelosdisponibles': 8,
#     'nombreemplacementsactuels': 17,
#     'nom': 'Gros-Chêne',
#     'nombreemplacementsdisponibles': 9,
#     'coordonnees': [48.126795, -1.665101]}},
#   {'fields': {'nombrevelosdisponibles': 8,
#     'nombreemplacementsactuels': 29,
#     'nom': 'Painlevé',
#     'nombreemplacementsdisponibles': 21,
#     'coordonnees': [48.123506, -1.659762]}},
#   {'fields': {'nombrevelosdisponibles': 16,
#     'nombreemplacementsactuels': 30,
#     'nom': 'Joliot-Curie - Chateaubriand',
#     'nombreemplacementsdisponibles': 14,
#     'coordonnees': [48.124389, -1.651203]}},
#   {'fields': {'nombrevelosdisponibles': 0,
#     'nombreemplacementsactuels': 1,
#     'nom': 'La Poterie',
#     'nombreemplacementsdisponibles': 1,
#     'coordonnees': [48.087282, -1.644121]}},
#   {'fields': {'nombrevelosdisponibles': 5,
#     'nombreemplacementsactuels': 20,
#     'nom': 'Pont de Strasbourg',
#     'nombreemplacementsdisponibles': 15,
#     'coordonnees': [48.109859, -1.656028]}}],
#  'type': 'FeatureCollection',
#  'name': 'Stations de velos Rennes'}

# %%
for element in data_rennes['records']:
    element['type']='Feature'
    element['fields']['@type'] = "station"
    element['fields']['ville'] = 'Rennes'
    element['fields']['lat']= element['fields']['coordonnees'][0]
    element['fields']['long'] = element['fields']['coordonnees'][1]

# %%
data_rennes
# Out:
# {'records': [{'fields': {'nombrevelosdisponibles': 6,
#     'nombreemplacementsactuels': 16,
#     'nom': 'Musée Beaux-Arts',
#     'nombreemplacementsdisponibles': 10,
#     'coordonnees': [48.109601, -1.67408],
#     '@type': 'station',
#     'ville': 'Rennes',
#     'lat': 48.109601,
#     'long': -1.67408},
#    'type': 'Feature'},
#   {'fields': {'nombrevelosdisponibles': 10,
#     'nombreemplacementsactuels': 24,
#     'nom': 'Champs Libres',
#     'nombreemplacementsdisponibles': 14,
#     'coordonnees': [48.105537, -1.674328],
#     '@type': 'station',
#     'ville': 'Rennes',
#     'lat': 48.105537,
#     'long': -1.674328},
#    'type': 'Feature'},
#   {'fields': {'nombrevelosdisponibles': 18,
#     'nombreemplacementsactuels': 24,
#     'nom': 'Brest - Verdun',
#     'nombreemplacementsdisponibles': 6,
#     'coordonnees': [48.113009, -1.693264],
#     '@type': 'station',
#     'ville': 'Rennes',
#     'lat': 48.113009,
#     'long': -1.693264},
#    'type': 'Feature'},
#   {'fields': {'nombrevelosdisponibles': 11,
#     'nombreemplacementsactuels': 20,
#     'nom': 'Marbeuf',
#     'nombreemplacementsdisponibles': 9,
#     'coordonnees': [48.111749, -1.702077],
#     '@type': 'station',
#     'ville': 'Rennes',
#     'lat': 48.111749,
#     'long': -1.702077},
#    'type': 'Feature'},
#   {'fields': {'nombrevelosdisponibles': 14,
#     'nombreemplacementsactuels': 24,
#     'nom': 'Plaine de Baud',
#     'nombreemplacementsdisponibles': 10,
#     'coordonnees': [48.112461, -1.643674],
#     '@type': 'station',
#     'ville': 'Rennes',
#     'lat': 48.112461,
#     'long': -1.643674},
#    'type': 'Feature'},
#   {'fields': {'nombrevelosdisponibles': 8,
#     'nombreemplacementsactuels': 17,
#     'nom': 'Gros-Chêne',
#     'nombreemplacementsdisponibles': 9,
#     'coordonnees': [48.126795, -1.665101],
#     '@type': 'station',
#     'ville': 'Rennes',
#     'lat': 48.126795,
#     'long': -1.665101},
#    'type': 'Feature'},
#   {'fields': {'nombrevelosdisponibles': 8,
#     'nombreemplacementsactuels': 29,
#     'nom': 'Painlevé',
#     'nombreemplacementsdisponibles': 21,
#     'coordonnees': [48.123506, -1.659762],
#     '@type': 'station',
#     'ville': 'Rennes',
#     'lat': 48.123506,
#     'long': -1.659762},
#    'type': 'Feature'},
#   {'fields': {'nombrevelosdisponibles': 16,
#     'nombreemplacementsactuels': 30,
#     'nom': 'Joliot-Curie - Chateaubriand',
#     'nombreemplacementsdisponibles': 14,
#     'coordonnees': [48.124389, -1.651203],
#     '@type': 'station',
#     'ville': 'Rennes',
#     'lat': 48.124389,
#     'long': -1.651203},
#    'type': 'Feature'},
#   {'fields': {'nombrevelosdisponibles': 0,
#     'nombreemplacementsactuels': 1,
#     'nom': 'La Poterie',
#     'nombreemplacementsdisponibles': 1,
#     'coordonnees': [48.087282, -1.644121],
#     '@type': 'station',
#     'ville': 'Rennes',
#     'lat': 48.087282,
#     'long': -1.644121},
#    'type': 'Feature'},
#   {'fields': {'nombrevelosdisponibles': 5,
#     'nombreemplacementsactuels': 20,
#     'nom': 'Pont de Strasbourg',
#     'nombreemplacementsdisponibles': 15,
#     'coordonnees': [48.109859, -1.656028],
#     '@type': 'station',
#     'ville': 'Rennes',
#     'lat': 48.109859,
#     'long': -1.656028},
#    'type': 'Feature'}],
#  'type': 'FeatureCollection',
#  'name': 'Stations de velos Rennes'}

# %%
data_rennes={
    "@context":{
        "@vocab": "http://schema.org/", 
		"@base": "http://data.org/", 
		"name": "name",
        "nombreemplacementsdisponibles":"nombreemplacementsdisponibles",
        "nombreemplacementsactuels":"nombreemplacementsactuels",
		"lat": "lat", 
		"long": "long",
        "ville":"ville",
    },
    "features":[
        data_rennes
    ]
}

# %%
import json 
with open('rennes_bikes_records.json', 'w') as fp:
   json.dump(data_rennes, fp,ensure_ascii=False)

# %%
from urllib.request import urlopen
import xmltodict

data = urlopen("https://data.montpellier3m.fr/sites/default/files/ressources/TAM_MMM_VELOMAG.xml").read()

data = xmltodict.parse(data)
data
# Out:
# OrderedDict([('vcs',
#               OrderedDict([('@ver', '1'),
#                            ('sl',
#                             OrderedDict([('si',
#                                           [OrderedDict([('@na',
#                                                          '001 Rue Jules Ferry - Gare Saint-Roch'),
#                                                         ('@id', '001'),
#                                                         ('@la', '43.605366'),
#                                                         ('@lg', '3.881346'),
#                                                         ('@av', '3'),
#                                                         ('@fr', '9'),
#                                                         ('@to', '12')]),
#                                            OrderedDict([('@na', '002 Comédie'),
#                                                         ('@id', '002'),
#                                                         ('@la', '43.608148'),
#                                                         ('@lg', '3.878778'),
#                                                         ('@av', '6'),
#                                                         ('@fr', '18'),
#                                                         ('@to', '24')]),
#                                            OrderedDict([('@na',
#                                                          '003 Esplanade'),
#                                                         ('@id', '003'),
#                                                         ('@la', '43.609478'),
#                                                         ('@lg', '3.881293'),
#                                                         ('@av', '1'),
#                                                         ('@fr', '31'),
#                                                         ('@to', '32')]),
#                                            OrderedDict([('@na',
#                                                          '004 Hôtel de Ville'),
#                                                         ('@id', '004'),
#                                                         ('@la', '43.599088'),
#                                                         ('@lg', '3.894866'),
#                                                         ('@av', '4'),
#                                                         ('@fr', '12'),
#                                                         ('@to', '16')]),
#                                            OrderedDict([('@na', '005 Corum'),
#                                                         ('@id', '005'),
#                                                         ('@la', '43.613989'),
#                                                         ('@lg', '3.881600'),
#                                                         ('@av', '9'),
#                                                         ('@fr', '3'),
#                                                         ('@to', '12')]),
#                                            OrderedDict([('@na',
#                                                          '006 Place Albert 1er - St Charles'),
#                                                         ('@id', '006'),
#                                                         ('@la', '43.616768'),
#                                                         ('@lg', '3.873375'),
#                                                         ('@av', '19'),
#                                                         ('@fr', '12'),
#                                                         ('@to', '31')]),
#                                            OrderedDict([('@na', '007 Foch'),
#                                                         ('@id', '007'),
#                                                         ('@la', '43.610989'),
#                                                         ('@lg', '3.873345'),
#                                                         ('@av', '7'),
#                                                         ('@fr', '1'),
#                                                         ('@to', '8')]),
#                                            OrderedDict([('@na',
#                                                          '008 Halles Castellane'),
#                                                         ('@id', '008'),
#                                                         ('@la', '43.609935'),
#                                                         ('@lg', '3.877208'),
#                                                         ('@av', '8'),
#                                                         ('@fr', '4'),
#                                                         ('@to', '12')]),
#                                            OrderedDict([('@na',
#                                                          '009 Observatoire'),
#                                                         ('@id', '009'),
#                                                         ('@la', '43.606081'),
#                                                         ('@lg', '3.876931'),
#                                                         ('@av', '5'),
#                                                         ('@fr', '3'),
#                                                         ('@to', '8')]),
#                                            OrderedDict([('@na',
#                                                          '010 Rondelet'),
#                                                         ('@id', '010'),
#                                                         ('@la', '43.603038'),
#                                                         ('@lg', '3.875796'),
#                                                         ('@av', '7'),
#                                                         ('@fr', '9'),
#                                                         ('@to', '16')]),
#                                            OrderedDict([('@na',
#                                                          '011 Plan Cabanes'),
#                                                         ('@id', '011'),
#                                                         ('@la', '43.608491'),
#                                                         ('@lg', '3.868389'),
#                                                         ('@av', '3'),
#                                                         ('@fr', '9'),
#                                                         ('@to', '12')]),
#                                            OrderedDict([('@na',
#                                                          '012 Boutonnet'),
#                                                         ('@id', '012'),
#                                                         ('@la', '43.622629'),
#                                                         ('@lg', '3.868375'),
#                                                         ('@av', '6'),
#                                                         ('@fr', '6'),
#                                                         ('@to', '12')]),
#                                            OrderedDict([('@na',
#                                                          '013 Emile Combes'),
#                                                         ('@id', '013'),
#                                                         ('@la', '43.616742'),
#                                                         ('@lg', '3.87998'),
#                                                         ('@av', '3'),
#                                                         ('@fr', '5'),
#                                                         ('@to', '8')]),
#                                            OrderedDict([('@na',
#                                                          '014 Beaux-Arts'),
#                                                         ('@id', '014'),
#                                                         ('@la', '43.616698'),
#                                                         ('@lg', '3.884981'),
#                                                         ('@av', '4'),
#                                                         ('@fr', '4'),
#                                                         ('@to', '8')]),
#                                            OrderedDict([('@na',
#                                                          '015 Les Aubes'),
#                                                         ('@id', '015'),
#                                                         ('@la', '43.618692'),
#                                                         ('@lg', '3.893844'),
#                                                         ('@av', '4'),
#                                                         ('@fr', '4'),
#                                                         ('@to', '8')]),
#                                            OrderedDict([('@na',
#                                                          '016 Antigone centre'),
#                                                         ('@id', '016'),
#                                                         ('@la', '43.607942'),
#                                                         ('@lg', '3.890634'),
#                                                         ('@av', '13'),
#                                                         ('@fr', '3'),
#                                                         ('@to', '16')]),
#                                            OrderedDict([('@na',
#                                                          '017 Médiathèque Emile Zola'),
#                                                         ('@id', '017'),
#                                                         ('@la', '43.608218'),
#                                                         ('@lg', '3.893140'),
#                                                         ('@av', '4'),
#                                                         ('@fr', '12'),
#                                                         ('@to', '16')]),
#                                            OrderedDict([('@na',
#                                                          "018 Nombre d'Or"),
#                                                         ('@id', '018'),
#                                                         ('@la', '43.607859'),
#                                                         ('@lg', '3.886644'),
#                                                         ('@av', '6'),
#                                                         ('@fr', '10'),
#                                                         ('@to', '16')]),
#                                            OrderedDict([('@na',
#                                                          '019 Louis Blanc'),
#                                                         ('@id', '019'),
#                                                         ('@la', '43.614642'),
#                                                         ('@lg', '3.877648'),
#                                                         ('@av', '4'),
#                                                         ('@fr', '12'),
#                                                         ('@to', '16')]),
#                                            OrderedDict([('@na',
#                                                          '020 Gambetta'),
#                                                         ('@id', '020'),
#                                                         ('@la', '43.607106'),
#                                                         ('@lg', '3.870693'),
#                                                         ('@av', '5'),
#                                                         ('@fr', '3'),
#                                                         ('@to', '8')]),
#                                            OrderedDict([('@na',
#                                                          '021 Port Marianne'),
#                                                         ('@id', '021'),
#                                                         ('@la', '43.600320'),
#                                                         ('@lg', '3.898510'),
#                                                         ('@av', '9'),
#                                                         ('@fr', '7'),
#                                                         ('@to', '16')]),
#                                            OrderedDict([('@na',
#                                                          '022 Clemenceau'),
#                                                         ('@id', '022'),
#                                                         ('@la', '43.603539'),
#                                                         ('@lg', '3.872394'),
#                                                         ('@av', '5'),
#                                                         ('@fr', '7'),
#                                                         ('@to', '12')]),
#                                            OrderedDict([('@na',
#                                                          '023 Les Arceaux'),
#                                                         ('@id', '023'),
#                                                         ('@la', '43.611991'),
#                                                         ('@lg', '3.867157'),
#                                                         ('@av', '7'),
#                                                         ('@fr', '9'),
#                                                         ('@to', '16')]),
#                                            OrderedDict([('@na',
#                                                          '024 Cité Mion'),
#                                                         ('@id', '024'),
#                                                         ('@la', '43.601143'),
#                                                         ('@lg', '3.884373'),
#                                                         ('@av', '3'),
#                                                         ('@fr', '5'),
#                                                         ('@to', '8')]),
#                                            OrderedDict([('@na',
#                                                          '025 Nouveau Saint-Roch'),
#                                                         ('@id', '025'),
#                                                         ('@la', '43.599817'),
#                                                         ('@lg', '3.875757'),
#                                                         ('@av', '3'),
#                                                         ('@fr', '5'),
#                                                         ('@to', '8')]),
#                                            OrderedDict([('@na',
#                                                          '026 Renouvier'),
#                                                         ('@id', '026'),
#                                                         ('@la', '43.603553'),
#                                                         ('@lg', '3.867884'),
#                                                         ('@av', '5'),
#                                                         ('@fr', '3'),
#                                                         ('@to', '8')]),
#                                            OrderedDict([('@na',
#                                                          '027 Odysseum'),
#                                                         ('@id', '027'),
#                                                         ('@la', '43.603727'),
#                                                         ('@lg', '3.918979'),
#                                                         ('@av', '7'),
#                                                         ('@fr', '1'),
#                                                         ('@to', '8')]),
#                                            OrderedDict([('@na',
#                                                          '028 Saint-Denis'),
#                                                         ('@id', '028'),
#                                                         ('@la', '43.605021'),
#                                                         ('@lg', '3.875065'),
#                                                         ('@av', '4'),
#                                                         ('@fr', '4'),
#                                                         ('@to', '8')]),
#                                            OrderedDict([('@na', '029 Richter'),
#                                                         ('@id', '029'),
#                                                         ('@la', '43.603424'),
#                                                         ('@lg', '3.899263'),
#                                                         ('@av', '9'),
#                                                         ('@fr', '7'),
#                                                         ('@to', '16')]),
#                                            OrderedDict([('@na',
#                                                          '030 Charles Flahault'),
#                                                         ('@id', '030'),
#                                                         ('@la', '43.618762'),
#                                                         ('@lg', '3.865971'),
#                                                         ('@av', '2'),
#                                                         ('@fr', '6'),
#                                                         ('@to', '8')]),
#                                            OrderedDict([('@na',
#                                                          '031 Voltaire'),
#                                                         ('@id', '031'),
#                                                         ('@la', '43.603767'),
#                                                         ('@lg', '3.888659'),
#                                                         ('@av', '4'),
#                                                         ('@fr', '4'),
#                                                         ('@to', '8')]),
#                                            OrderedDict([('@na',
#                                                          "032 Prés d'Arènes"),
#                                                         ('@id', '032'),
#                                                         ('@la', '43.590480'),
#                                                         ('@lg', '3.884611'),
#                                                         ('@av', '1'),
#                                                         ('@fr', '7'),
#                                                         ('@to', '8')]),
#                                            OrderedDict([('@na',
#                                                          '033 Garcia Lorca'),
#                                                         ('@id', '033'),
#                                                         ('@la', '43.590757'),
#                                                         ('@lg', '3.890616'),
#                                                         ('@av', '2'),
#                                                         ('@fr', '6'),
#                                                         ('@to', '8')]),
#                                            OrderedDict([('@na',
#                                                          '034 Vert Bois'),
#                                                         ('@id', '034'),
#                                                         ('@la', '43.634580'),
#                                                         ('@lg', '3.868230'),
#                                                         ('@av', '0'),
#                                                         ('@fr', '16'),
#                                                         ('@to', '16')]),
#                                            OrderedDict([('@na', '035 Malbosc'),
#                                                         ('@id', '035'),
#                                                         ('@la', '43.633679'),
#                                                         ('@lg', '3.832861'),
#                                                         ('@av', '7'),
#                                                         ('@fr', '1'),
#                                                         ('@to', '8')]),
#                                            OrderedDict([('@na',
#                                                          '036 Occitanie'),
#                                                         ('@id', '036'),
#                                                         ('@la', '43.634242'),
#                                                         ('@lg', '3.849128'),
#                                                         ('@av', '8'),
#                                                         ('@fr', '24'),
#                                                         ('@to', '32')]),
#                                            OrderedDict([('@na',
#                                                          '037 FacdesSciences'),
#                                                         ('@id', '037'),
#                                                         ('@la', '43.631018'),
#                                                         ('@lg', '3.860697'),
#                                                         ('@av', '5'),
#                                                         ('@fr', '19'),
#                                                         ('@to', '24')]),
#                                            OrderedDict([('@na',
#                                                          '038 Fac de Lettres'),
#                                                         ('@id', '038'),
#                                                         ('@la', '43.630665'),
#                                                         ('@lg', '3.870230'),
#                                                         ('@av', '5'),
#                                                         ('@fr', '11'),
#                                                         ('@to', '16')]),
#                                            OrderedDict([('@na',
#                                                          '039 Aiguelongue'),
#                                                         ('@id', '039'),
#                                                         ('@la', '43.626163'),
#                                                         ('@lg', '3.882492'),
#                                                         ('@av', '3'),
#                                                         ('@fr', '5'),
#                                                         ('@to', '8')]),
#                                            OrderedDict([('@na',
#                                                          '040 Jeu de Mail des Abbés'),
#                                                         ('@id', '040'),
#                                                         ('@la', '43.619701'),
#                                                         ('@lg', '3.883831'),
#                                                         ('@av', '4'),
#                                                         ('@fr', '4'),
#                                                         ('@to', '8')]),
#                                            OrderedDict([('@na',
#                                                          '041 Euromédecine'),
#                                                         ('@id', '041'),
#                                                         ('@la', '43.639119'),
#                                                         ('@lg', '3.828199'),
#                                                         ('@av', '2'),
#                                                         ('@fr', '6'),
#                                                         ('@to', '8')]),
#                                            OrderedDict([('@na',
#                                                          '042 Marie Caizergues'),
#                                                         ('@id', '042'),
#                                                         ('@la', '43.619871'),
#                                                         ('@lg', '3.873812'),
#                                                         ('@av', '5'),
#                                                         ('@fr', '3'),
#                                                         ('@to', '8')]),
#                                            OrderedDict([('@na', '043 Sabines'),
#                                                         ('@id', '043'),
#                                                         ('@la', '43.584211'),
#                                                         ('@lg', '3.860031'),
#                                                         ('@av', '1'),
#                                                         ('@fr', '7'),
#                                                         ('@to', '8')]),
#                                            OrderedDict([('@na',
#                                                          '044 Celleneuve'),
#                                                         ('@id', '044'),
#                                                         ('@la', '43.614670'),
#                                                         ('@lg', '3.832624'),
#                                                         ('@av', '4'),
#                                                         ('@fr', '4'),
#                                                         ('@to', '8')]),
#                                            OrderedDict([('@na',
#                                                          '045 Jardin de la Lironde'),
#                                                         ('@id', '045'),
#                                                         ('@la', '43.605850'),
#                                                         ('@lg', '3.911576'),
#                                                         ('@av', '3'),
#                                                         ('@fr', '5'),
#                                                         ('@to', '8')]),
#                                            OrderedDict([('@na',
#                                                          '046 Père Soulas'),
#                                                         ('@id', '046'),
#                                                         ('@la', '43.621983'),
#                                                         ('@lg', '3.855603'),
#                                                         ('@av', '2'),
#                                                         ('@fr', '6'),
#                                                         ('@to', '8')]),
#                                            OrderedDict([('@na',
#                                                          '047 Place Viala'),
#                                                         ('@id', '047'),
#                                                         ('@la', '43.616812'),
#                                                         ('@lg', '3.855075'),
#                                                         ('@av', '4'),
#                                                         ('@fr', '4'),
#                                                         ('@to', '8')]),
#                                            OrderedDict([('@na',
#                                                          '048 Hôtel du Département'),
#                                                         ('@id', '048'),
#                                                         ('@la', '43.621682'),
#                                                         ('@lg', '3.834770'),
#                                                         ('@av', '3'),
#                                                         ('@fr', '5'),
#                                                         ('@to', '8')]),
#                                            OrderedDict([('@na',
#                                                          '049 Tonnelles'),
#                                                         ('@id', '049'),
#                                                         ('@la', '43.615155'),
#                                                         ('@lg', '3.839466'),
#                                                         ('@av', '2'),
#                                                         ('@fr', '6'),
#                                                         ('@to', '8')]),
#                                            OrderedDict([('@na',
#                                                          '050 Parvis Jules Ferry - Gare Saint-Roch'),
#                                                         ('@id', '050'),
#                                                         ('@la', '43.603889'),
#                                                         ('@lg', '3.879362'),
#                                                         ('@av', '3'),
#                                                         ('@fr', '5'),
#                                                         ('@to', '8')]),
#                                            OrderedDict([('@na',
#                                                          '051 Pont de Lattes - Gare Saint-Roch'),
#                                                         ('@id', '051'),
#                                                         ('@la', '43.606036'),
#                                                         ('@lg', '3.882393'),
#                                                         ('@av', '4'),
#                                                         ('@fr', '8'),
#                                                         ('@to', '12')]),
#                                            OrderedDict([('@na',
#                                                          '053 Deux Ponts - Gare Saint-Roch'),
#                                                         ('@id', '053'),
#                                                         ('@la', '43.604319'),
#                                                         ('@lg', '3.880916'),
#                                                         ('@av', '7'),
#                                                         ('@fr', '1'),
#                                                         ('@to', '8')]),
#                                            OrderedDict([('@na',
#                                                          '054 Providence - Ovalie'),
#                                                         ('@id', '054'),
#                                                         ('@la', '43.588239'),
#                                                         ('@lg', '3.853421'),
#                                                         ('@av', '4'),
#                                                         ('@fr', '4'),
#                                                         ('@to', '8')]),
#                                            OrderedDict([('@na',
#                                                          "055 Pérols Etang de l'Or"),
#                                                         ('@id', '055'),
#                                                         ('@la', '43.558351'),
#                                                         ('@lg', '3.963412'),
#                                                         ('@av', '3'),
#                                                         ('@fr', '65'),
#                                                         ('@to', '68')]),
#                                            OrderedDict([('@na',
#                                                          '056 Albert 1er - Cathédrale'),
#                                                         ('@id', '056'),
#                                                         ('@la', '43.614005'),
#                                                         ('@lg', '3.873218'),
#                                                         ('@av', '4'),
#                                                         ('@fr', '8'),
#                                                         ('@to', '12')]),
#                                            OrderedDict([('@na',
#                                                          '057 Saint-Guilhem - Courreau'),
#                                                         ('@id', '057'),
#                                                         ('@la', '43.608996'),
#                                                         ('@lg', '3.872752'),
#                                                         ('@av', '3'),
#                                                         ('@fr', '5'),
#                                                         ('@to', '8')]),
#                                            OrderedDict([('@na',
#                                                          '059 Sud De France'),
#                                                         ('@id', '059'),
#                                                         ('@la', '43.595620'),
#                                                         ('@lg', '3.923500'),
#                                                         ('@av', '4'),
#                                                         ('@fr', '4'),
#                                                         ('@to',
#                                                          '8')])])]))]))])

# %%
features_montpellier = list()
for element in data['vcs']['sl']['si']:
    temp= list(element.values())
    temp.pop(1)
    features_montpellier.append(temp)
for element in features_montpellier:
    element[0]=element[0][4:]
features_montpellier
# Out:
# [['Rue Jules Ferry - Gare Saint-Roch',
#   '43.605366',
#   '3.881346',
#   '3',
#   '9',
#   '12'],
#  ['Comédie', '43.608148', '3.878778', '6', '18', '24'],
#  ['Esplanade', '43.609478', '3.881293', '1', '31', '32'],
#  ['Hôtel de Ville', '43.599088', '3.894866', '4', '12', '16'],
#  ['Corum', '43.613989', '3.881600', '9', '3', '12'],
#  ['Place Albert 1er - St Charles', '43.616768', '3.873375', '19', '12', '31'],
#  ['Foch', '43.610989', '3.873345', '7', '1', '8'],
#  ['Halles Castellane', '43.609935', '3.877208', '8', '4', '12'],
#  ['Observatoire', '43.606081', '3.876931', '5', '3', '8'],
#  ['Rondelet', '43.603038', '3.875796', '7', '9', '16'],
#  ['Plan Cabanes', '43.608491', '3.868389', '3', '9', '12'],
#  ['Boutonnet', '43.622629', '3.868375', '6', '6', '12'],
#  ['Emile Combes', '43.616742', '3.87998', '3', '5', '8'],
#  ['Beaux-Arts', '43.616698', '3.884981', '4', '4', '8'],
#  ['Les Aubes', '43.618692', '3.893844', '4', '4', '8'],
#  ['Antigone centre', '43.607942', '3.890634', '13', '3', '16'],
#  ['Médiathèque Emile Zola', '43.608218', '3.893140', '4', '12', '16'],
#  ["Nombre d'Or", '43.607859', '3.886644', '6', '10', '16'],
#  ['Louis Blanc', '43.614642', '3.877648', '4', '12', '16'],
#  ['Gambetta', '43.607106', '3.870693', '5', '3', '8'],
#  ['Port Marianne', '43.600320', '3.898510', '9', '7', '16'],
#  ['Clemenceau', '43.603539', '3.872394', '5', '7', '12'],
#  ['Les Arceaux', '43.611991', '3.867157', '7', '9', '16'],
#  ['Cité Mion', '43.601143', '3.884373', '3', '5', '8'],
#  ['Nouveau Saint-Roch', '43.599817', '3.875757', '3', '5', '8'],
#  ['Renouvier', '43.603553', '3.867884', '5', '3', '8'],
#  ['Odysseum', '43.603727', '3.918979', '7', '1', '8'],
#  ['Saint-Denis', '43.605021', '3.875065', '4', '4', '8'],
#  ['Richter', '43.603424', '3.899263', '9', '7', '16'],
#  ['Charles Flahault', '43.618762', '3.865971', '2', '6', '8'],
#  ['Voltaire', '43.603767', '3.888659', '4', '4', '8'],
#  ["Prés d'Arènes", '43.590480', '3.884611', '1', '7', '8'],
#  ['Garcia Lorca', '43.590757', '3.890616', '2', '6', '8'],
#  ['Vert Bois', '43.634580', '3.868230', '0', '16', '16'],
#  ['Malbosc', '43.633679', '3.832861', '7', '1', '8'],
#  ['Occitanie', '43.634242', '3.849128', '8', '24', '32'],
#  ['FacdesSciences', '43.631018', '3.860697', '5', '19', '24'],
#  ['Fac de Lettres', '43.630665', '3.870230', '5', '11', '16'],
#  ['Aiguelongue', '43.626163', '3.882492', '3', '5', '8'],
#  ['Jeu de Mail des Abbés', '43.619701', '3.883831', '4', '4', '8'],
#  ['Euromédecine', '43.639119', '3.828199', '2', '6', '8'],
#  ['Marie Caizergues', '43.619871', '3.873812', '5', '3', '8'],
#  ['Sabines', '43.584211', '3.860031', '1', '7', '8'],
#  ['Celleneuve', '43.614670', '3.832624', '4', '4', '8'],
#  ['Jardin de la Lironde', '43.605850', '3.911576', '3', '5', '8'],
#  ['Père Soulas', '43.621983', '3.855603', '2', '6', '8'],
#  ['Place Viala', '43.616812', '3.855075', '4', '4', '8'],
#  ['Hôtel du Département', '43.621682', '3.834770', '3', '5', '8'],
#  ['Tonnelles', '43.615155', '3.839466', '2', '6', '8'],
#  ['Parvis Jules Ferry - Gare Saint-Roch',
#   '43.603889',
#   '3.879362',
#   '3',
#   '5',
#   '8'],
#  ['Pont de Lattes - Gare Saint-Roch', '43.606036', '3.882393', '4', '8', '12'],
#  ['Deux Ponts - Gare Saint-Roch', '43.604319', '3.880916', '7', '1', '8'],
#  ['Providence - Ovalie', '43.588239', '3.853421', '4', '4', '8'],
#  ["Pérols Etang de l'Or", '43.558351', '3.963412', '3', '65', '68'],
#  ['Albert 1er - Cathédrale', '43.614005', '3.873218', '4', '8', '12'],
#  ['Saint-Guilhem - Courreau', '43.608996', '3.872752', '3', '5', '8'],
#  ['Sud De France', '43.595620', '3.923500', '4', '4', '8']]

# %%
montpellier_json={
    'type': 'FeatureCollection',
    'name': 'Stations de velos Montpellier',
    "features":[]
}
for element in montpellier_json['features']:
    element['type']='Feature'

# %%
for element in features_montpellier:
    properties=dict(zip(["name","lat","long","available_bikes_stands","available_bikes","total"],element))
    temp = {
        "type":"Feature",
        "properties":properties
        
    }
    montpellier_json['features'].append(temp)

# %%
montpellier_json
# Out:
# {'type': 'FeatureCollection',
#  'name': 'Stations de velos Montpellier',
#  'features': [{'type': 'Feature',
#    'properties': {'name': 'Rue Jules Ferry - Gare Saint-Roch',
#     'lat': '43.605366',
#     'long': '3.881346',
#     'available_bikes_stands': '3',
#     'available_bikes': '9',
#     'total': '12'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Comédie',
#     'lat': '43.608148',
#     'long': '3.878778',
#     'available_bikes_stands': '6',
#     'available_bikes': '18',
#     'total': '24'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Esplanade',
#     'lat': '43.609478',
#     'long': '3.881293',
#     'available_bikes_stands': '1',
#     'available_bikes': '31',
#     'total': '32'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Hôtel de Ville',
#     'lat': '43.599088',
#     'long': '3.894866',
#     'available_bikes_stands': '4',
#     'available_bikes': '12',
#     'total': '16'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Corum',
#     'lat': '43.613989',
#     'long': '3.881600',
#     'available_bikes_stands': '9',
#     'available_bikes': '3',
#     'total': '12'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Place Albert 1er - St Charles',
#     'lat': '43.616768',
#     'long': '3.873375',
#     'available_bikes_stands': '19',
#     'available_bikes': '12',
#     'total': '31'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Foch',
#     'lat': '43.610989',
#     'long': '3.873345',
#     'available_bikes_stands': '7',
#     'available_bikes': '1',
#     'total': '8'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Halles Castellane',
#     'lat': '43.609935',
#     'long': '3.877208',
#     'available_bikes_stands': '8',
#     'available_bikes': '4',
#     'total': '12'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Observatoire',
#     'lat': '43.606081',
#     'long': '3.876931',
#     'available_bikes_stands': '5',
#     'available_bikes': '3',
#     'total': '8'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Rondelet',
#     'lat': '43.603038',
#     'long': '3.875796',
#     'available_bikes_stands': '7',
#     'available_bikes': '9',
#     'total': '16'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Plan Cabanes',
#     'lat': '43.608491',
#     'long': '3.868389',
#     'available_bikes_stands': '3',
#     'available_bikes': '9',
#     'total': '12'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Boutonnet',
#     'lat': '43.622629',
#     'long': '3.868375',
#     'available_bikes_stands': '6',
#     'available_bikes': '6',
#     'total': '12'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Emile Combes',
#     'lat': '43.616742',
#     'long': '3.87998',
#     'available_bikes_stands': '3',
#     'available_bikes': '5',
#     'total': '8'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Beaux-Arts',
#     'lat': '43.616698',
#     'long': '3.884981',
#     'available_bikes_stands': '4',
#     'available_bikes': '4',
#     'total': '8'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Les Aubes',
#     'lat': '43.618692',
#     'long': '3.893844',
#     'available_bikes_stands': '4',
#     'available_bikes': '4',
#     'total': '8'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Antigone centre',
#     'lat': '43.607942',
#     'long': '3.890634',
#     'available_bikes_stands': '13',
#     'available_bikes': '3',
#     'total': '16'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Médiathèque Emile Zola',
#     'lat': '43.608218',
#     'long': '3.893140',
#     'available_bikes_stands': '4',
#     'available_bikes': '12',
#     'total': '16'}},
#   {'type': 'Feature',
#    'properties': {'name': "Nombre d'Or",
#     'lat': '43.607859',
#     'long': '3.886644',
#     'available_bikes_stands': '6',
#     'available_bikes': '10',
#     'total': '16'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Louis Blanc',
#     'lat': '43.614642',
#     'long': '3.877648',
#     'available_bikes_stands': '4',
#     'available_bikes': '12',
#     'total': '16'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Gambetta',
#     'lat': '43.607106',
#     'long': '3.870693',
#     'available_bikes_stands': '5',
#     'available_bikes': '3',
#     'total': '8'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Port Marianne',
#     'lat': '43.600320',
#     'long': '3.898510',
#     'available_bikes_stands': '9',
#     'available_bikes': '7',
#     'total': '16'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Clemenceau',
#     'lat': '43.603539',
#     'long': '3.872394',
#     'available_bikes_stands': '5',
#     'available_bikes': '7',
#     'total': '12'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Les Arceaux',
#     'lat': '43.611991',
#     'long': '3.867157',
#     'available_bikes_stands': '7',
#     'available_bikes': '9',
#     'total': '16'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Cité Mion',
#     'lat': '43.601143',
#     'long': '3.884373',
#     'available_bikes_stands': '3',
#     'available_bikes': '5',
#     'total': '8'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Nouveau Saint-Roch',
#     'lat': '43.599817',
#     'long': '3.875757',
#     'available_bikes_stands': '3',
#     'available_bikes': '5',
#     'total': '8'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Renouvier',
#     'lat': '43.603553',
#     'long': '3.867884',
#     'available_bikes_stands': '5',
#     'available_bikes': '3',
#     'total': '8'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Odysseum',
#     'lat': '43.603727',
#     'long': '3.918979',
#     'available_bikes_stands': '7',
#     'available_bikes': '1',
#     'total': '8'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Saint-Denis',
#     'lat': '43.605021',
#     'long': '3.875065',
#     'available_bikes_stands': '4',
#     'available_bikes': '4',
#     'total': '8'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Richter',
#     'lat': '43.603424',
#     'long': '3.899263',
#     'available_bikes_stands': '9',
#     'available_bikes': '7',
#     'total': '16'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Charles Flahault',
#     'lat': '43.618762',
#     'long': '3.865971',
#     'available_bikes_stands': '2',
#     'available_bikes': '6',
#     'total': '8'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Voltaire',
#     'lat': '43.603767',
#     'long': '3.888659',
#     'available_bikes_stands': '4',
#     'available_bikes': '4',
#     'total': '8'}},
#   {'type': 'Feature',
#    'properties': {'name': "Prés d'Arènes",
#     'lat': '43.590480',
#     'long': '3.884611',
#     'available_bikes_stands': '1',
#     'available_bikes': '7',
#     'total': '8'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Garcia Lorca',
#     'lat': '43.590757',
#     'long': '3.890616',
#     'available_bikes_stands': '2',
#     'available_bikes': '6',
#     'total': '8'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Vert Bois',
#     'lat': '43.634580',
#     'long': '3.868230',
#     'available_bikes_stands': '0',
#     'available_bikes': '16',
#     'total': '16'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Malbosc',
#     'lat': '43.633679',
#     'long': '3.832861',
#     'available_bikes_stands': '7',
#     'available_bikes': '1',
#     'total': '8'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Occitanie',
#     'lat': '43.634242',
#     'long': '3.849128',
#     'available_bikes_stands': '8',
#     'available_bikes': '24',
#     'total': '32'}},
#   {'type': 'Feature',
#    'properties': {'name': 'FacdesSciences',
#     'lat': '43.631018',
#     'long': '3.860697',
#     'available_bikes_stands': '5',
#     'available_bikes': '19',
#     'total': '24'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Fac de Lettres',
#     'lat': '43.630665',
#     'long': '3.870230',
#     'available_bikes_stands': '5',
#     'available_bikes': '11',
#     'total': '16'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Aiguelongue',
#     'lat': '43.626163',
#     'long': '3.882492',
#     'available_bikes_stands': '3',
#     'available_bikes': '5',
#     'total': '8'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Jeu de Mail des Abbés',
#     'lat': '43.619701',
#     'long': '3.883831',
#     'available_bikes_stands': '4',
#     'available_bikes': '4',
#     'total': '8'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Euromédecine',
#     'lat': '43.639119',
#     'long': '3.828199',
#     'available_bikes_stands': '2',
#     'available_bikes': '6',
#     'total': '8'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Marie Caizergues',
#     'lat': '43.619871',
#     'long': '3.873812',
#     'available_bikes_stands': '5',
#     'available_bikes': '3',
#     'total': '8'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Sabines',
#     'lat': '43.584211',
#     'long': '3.860031',
#     'available_bikes_stands': '1',
#     'available_bikes': '7',
#     'total': '8'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Celleneuve',
#     'lat': '43.614670',
#     'long': '3.832624',
#     'available_bikes_stands': '4',
#     'available_bikes': '4',
#     'total': '8'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Jardin de la Lironde',
#     'lat': '43.605850',
#     'long': '3.911576',
#     'available_bikes_stands': '3',
#     'available_bikes': '5',
#     'total': '8'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Père Soulas',
#     'lat': '43.621983',
#     'long': '3.855603',
#     'available_bikes_stands': '2',
#     'available_bikes': '6',
#     'total': '8'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Place Viala',
#     'lat': '43.616812',
#     'long': '3.855075',
#     'available_bikes_stands': '4',
#     'available_bikes': '4',
#     'total': '8'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Hôtel du Département',
#     'lat': '43.621682',
#     'long': '3.834770',
#     'available_bikes_stands': '3',
#     'available_bikes': '5',
#     'total': '8'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Tonnelles',
#     'lat': '43.615155',
#     'long': '3.839466',
#     'available_bikes_stands': '2',
#     'available_bikes': '6',
#     'total': '8'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Parvis Jules Ferry - Gare Saint-Roch',
#     'lat': '43.603889',
#     'long': '3.879362',
#     'available_bikes_stands': '3',
#     'available_bikes': '5',
#     'total': '8'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Pont de Lattes - Gare Saint-Roch',
#     'lat': '43.606036',
#     'long': '3.882393',
#     'available_bikes_stands': '4',
#     'available_bikes': '8',
#     'total': '12'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Deux Ponts - Gare Saint-Roch',
#     'lat': '43.604319',
#     'long': '3.880916',
#     'available_bikes_stands': '7',
#     'available_bikes': '1',
#     'total': '8'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Providence - Ovalie',
#     'lat': '43.588239',
#     'long': '3.853421',
#     'available_bikes_stands': '4',
#     'available_bikes': '4',
#     'total': '8'}},
#   {'type': 'Feature',
#    'properties': {'name': "Pérols Etang de l'Or",
#     'lat': '43.558351',
#     'long': '3.963412',
#     'available_bikes_stands': '3',
#     'available_bikes': '65',
#     'total': '68'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Albert 1er - Cathédrale',
#     'lat': '43.614005',
#     'long': '3.873218',
#     'available_bikes_stands': '4',
#     'available_bikes': '8',
#     'total': '12'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Saint-Guilhem - Courreau',
#     'lat': '43.608996',
#     'long': '3.872752',
#     'available_bikes_stands': '3',
#     'available_bikes': '5',
#     'total': '8'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Sud De France',
#     'lat': '43.595620',
#     'long': '3.923500',
#     'available_bikes_stands': '4',
#     'available_bikes': '4',
#     'total': '8'}}]}

# %%
for element in montpellier_json['features']:
    element['properties']['@type'] = "station"
    element['properties']['ville']= 'Montpellier'

# %%
montpellier_json
# Out:
# {'type': 'FeatureCollection',
#  'name': 'Stations de velos Montpellier',
#  'features': [{'type': 'Feature',
#    'properties': {'name': 'Rue Jules Ferry - Gare Saint-Roch',
#     'lat': '43.605366',
#     'long': '3.881346',
#     'available_bikes_stands': '3',
#     'available_bikes': '9',
#     'total': '12',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Comédie',
#     'lat': '43.608148',
#     'long': '3.878778',
#     'available_bikes_stands': '6',
#     'available_bikes': '18',
#     'total': '24',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Esplanade',
#     'lat': '43.609478',
#     'long': '3.881293',
#     'available_bikes_stands': '1',
#     'available_bikes': '31',
#     'total': '32',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Hôtel de Ville',
#     'lat': '43.599088',
#     'long': '3.894866',
#     'available_bikes_stands': '4',
#     'available_bikes': '12',
#     'total': '16',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Corum',
#     'lat': '43.613989',
#     'long': '3.881600',
#     'available_bikes_stands': '9',
#     'available_bikes': '3',
#     'total': '12',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Place Albert 1er - St Charles',
#     'lat': '43.616768',
#     'long': '3.873375',
#     'available_bikes_stands': '19',
#     'available_bikes': '12',
#     'total': '31',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Foch',
#     'lat': '43.610989',
#     'long': '3.873345',
#     'available_bikes_stands': '7',
#     'available_bikes': '1',
#     'total': '8',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Halles Castellane',
#     'lat': '43.609935',
#     'long': '3.877208',
#     'available_bikes_stands': '8',
#     'available_bikes': '4',
#     'total': '12',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Observatoire',
#     'lat': '43.606081',
#     'long': '3.876931',
#     'available_bikes_stands': '5',
#     'available_bikes': '3',
#     'total': '8',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Rondelet',
#     'lat': '43.603038',
#     'long': '3.875796',
#     'available_bikes_stands': '7',
#     'available_bikes': '9',
#     'total': '16',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Plan Cabanes',
#     'lat': '43.608491',
#     'long': '3.868389',
#     'available_bikes_stands': '3',
#     'available_bikes': '9',
#     'total': '12',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Boutonnet',
#     'lat': '43.622629',
#     'long': '3.868375',
#     'available_bikes_stands': '6',
#     'available_bikes': '6',
#     'total': '12',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Emile Combes',
#     'lat': '43.616742',
#     'long': '3.87998',
#     'available_bikes_stands': '3',
#     'available_bikes': '5',
#     'total': '8',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Beaux-Arts',
#     'lat': '43.616698',
#     'long': '3.884981',
#     'available_bikes_stands': '4',
#     'available_bikes': '4',
#     'total': '8',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Les Aubes',
#     'lat': '43.618692',
#     'long': '3.893844',
#     'available_bikes_stands': '4',
#     'available_bikes': '4',
#     'total': '8',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Antigone centre',
#     'lat': '43.607942',
#     'long': '3.890634',
#     'available_bikes_stands': '13',
#     'available_bikes': '3',
#     'total': '16',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Médiathèque Emile Zola',
#     'lat': '43.608218',
#     'long': '3.893140',
#     'available_bikes_stands': '4',
#     'available_bikes': '12',
#     'total': '16',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': "Nombre d'Or",
#     'lat': '43.607859',
#     'long': '3.886644',
#     'available_bikes_stands': '6',
#     'available_bikes': '10',
#     'total': '16',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Louis Blanc',
#     'lat': '43.614642',
#     'long': '3.877648',
#     'available_bikes_stands': '4',
#     'available_bikes': '12',
#     'total': '16',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Gambetta',
#     'lat': '43.607106',
#     'long': '3.870693',
#     'available_bikes_stands': '5',
#     'available_bikes': '3',
#     'total': '8',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Port Marianne',
#     'lat': '43.600320',
#     'long': '3.898510',
#     'available_bikes_stands': '9',
#     'available_bikes': '7',
#     'total': '16',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Clemenceau',
#     'lat': '43.603539',
#     'long': '3.872394',
#     'available_bikes_stands': '5',
#     'available_bikes': '7',
#     'total': '12',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Les Arceaux',
#     'lat': '43.611991',
#     'long': '3.867157',
#     'available_bikes_stands': '7',
#     'available_bikes': '9',
#     'total': '16',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Cité Mion',
#     'lat': '43.601143',
#     'long': '3.884373',
#     'available_bikes_stands': '3',
#     'available_bikes': '5',
#     'total': '8',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Nouveau Saint-Roch',
#     'lat': '43.599817',
#     'long': '3.875757',
#     'available_bikes_stands': '3',
#     'available_bikes': '5',
#     'total': '8',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Renouvier',
#     'lat': '43.603553',
#     'long': '3.867884',
#     'available_bikes_stands': '5',
#     'available_bikes': '3',
#     'total': '8',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Odysseum',
#     'lat': '43.603727',
#     'long': '3.918979',
#     'available_bikes_stands': '7',
#     'available_bikes': '1',
#     'total': '8',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Saint-Denis',
#     'lat': '43.605021',
#     'long': '3.875065',
#     'available_bikes_stands': '4',
#     'available_bikes': '4',
#     'total': '8',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Richter',
#     'lat': '43.603424',
#     'long': '3.899263',
#     'available_bikes_stands': '9',
#     'available_bikes': '7',
#     'total': '16',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Charles Flahault',
#     'lat': '43.618762',
#     'long': '3.865971',
#     'available_bikes_stands': '2',
#     'available_bikes': '6',
#     'total': '8',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Voltaire',
#     'lat': '43.603767',
#     'long': '3.888659',
#     'available_bikes_stands': '4',
#     'available_bikes': '4',
#     'total': '8',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': "Prés d'Arènes",
#     'lat': '43.590480',
#     'long': '3.884611',
#     'available_bikes_stands': '1',
#     'available_bikes': '7',
#     'total': '8',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Garcia Lorca',
#     'lat': '43.590757',
#     'long': '3.890616',
#     'available_bikes_stands': '2',
#     'available_bikes': '6',
#     'total': '8',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Vert Bois',
#     'lat': '43.634580',
#     'long': '3.868230',
#     'available_bikes_stands': '0',
#     'available_bikes': '16',
#     'total': '16',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Malbosc',
#     'lat': '43.633679',
#     'long': '3.832861',
#     'available_bikes_stands': '7',
#     'available_bikes': '1',
#     'total': '8',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Occitanie',
#     'lat': '43.634242',
#     'long': '3.849128',
#     'available_bikes_stands': '8',
#     'available_bikes': '24',
#     'total': '32',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'FacdesSciences',
#     'lat': '43.631018',
#     'long': '3.860697',
#     'available_bikes_stands': '5',
#     'available_bikes': '19',
#     'total': '24',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Fac de Lettres',
#     'lat': '43.630665',
#     'long': '3.870230',
#     'available_bikes_stands': '5',
#     'available_bikes': '11',
#     'total': '16',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Aiguelongue',
#     'lat': '43.626163',
#     'long': '3.882492',
#     'available_bikes_stands': '3',
#     'available_bikes': '5',
#     'total': '8',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Jeu de Mail des Abbés',
#     'lat': '43.619701',
#     'long': '3.883831',
#     'available_bikes_stands': '4',
#     'available_bikes': '4',
#     'total': '8',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Euromédecine',
#     'lat': '43.639119',
#     'long': '3.828199',
#     'available_bikes_stands': '2',
#     'available_bikes': '6',
#     'total': '8',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Marie Caizergues',
#     'lat': '43.619871',
#     'long': '3.873812',
#     'available_bikes_stands': '5',
#     'available_bikes': '3',
#     'total': '8',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Sabines',
#     'lat': '43.584211',
#     'long': '3.860031',
#     'available_bikes_stands': '1',
#     'available_bikes': '7',
#     'total': '8',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Celleneuve',
#     'lat': '43.614670',
#     'long': '3.832624',
#     'available_bikes_stands': '4',
#     'available_bikes': '4',
#     'total': '8',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Jardin de la Lironde',
#     'lat': '43.605850',
#     'long': '3.911576',
#     'available_bikes_stands': '3',
#     'available_bikes': '5',
#     'total': '8',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Père Soulas',
#     'lat': '43.621983',
#     'long': '3.855603',
#     'available_bikes_stands': '2',
#     'available_bikes': '6',
#     'total': '8',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Place Viala',
#     'lat': '43.616812',
#     'long': '3.855075',
#     'available_bikes_stands': '4',
#     'available_bikes': '4',
#     'total': '8',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Hôtel du Département',
#     'lat': '43.621682',
#     'long': '3.834770',
#     'available_bikes_stands': '3',
#     'available_bikes': '5',
#     'total': '8',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Tonnelles',
#     'lat': '43.615155',
#     'long': '3.839466',
#     'available_bikes_stands': '2',
#     'available_bikes': '6',
#     'total': '8',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Parvis Jules Ferry - Gare Saint-Roch',
#     'lat': '43.603889',
#     'long': '3.879362',
#     'available_bikes_stands': '3',
#     'available_bikes': '5',
#     'total': '8',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Pont de Lattes - Gare Saint-Roch',
#     'lat': '43.606036',
#     'long': '3.882393',
#     'available_bikes_stands': '4',
#     'available_bikes': '8',
#     'total': '12',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Deux Ponts - Gare Saint-Roch',
#     'lat': '43.604319',
#     'long': '3.880916',
#     'available_bikes_stands': '7',
#     'available_bikes': '1',
#     'total': '8',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Providence - Ovalie',
#     'lat': '43.588239',
#     'long': '3.853421',
#     'available_bikes_stands': '4',
#     'available_bikes': '4',
#     'total': '8',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': "Pérols Etang de l'Or",
#     'lat': '43.558351',
#     'long': '3.963412',
#     'available_bikes_stands': '3',
#     'available_bikes': '65',
#     'total': '68',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Albert 1er - Cathédrale',
#     'lat': '43.614005',
#     'long': '3.873218',
#     'available_bikes_stands': '4',
#     'available_bikes': '8',
#     'total': '12',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Saint-Guilhem - Courreau',
#     'lat': '43.608996',
#     'long': '3.872752',
#     'available_bikes_stands': '3',
#     'available_bikes': '5',
#     'total': '8',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Sud De France',
#     'lat': '43.595620',
#     'long': '3.923500',
#     'available_bikes_stands': '4',
#     'available_bikes': '4',
#     'total': '8',
#     '@type': 'station',
#     'ville': 'Montpellier'}}]}

# %%
montpellier_json={
    "@context":{
        "@vocab": "http://schema.org/", 
		"@base": "http://data.org/", 
		"name": "name",
        "available_bikes_stands":"available_bikes_stands",
        "available_bikes":"available_bikes",
		"lat": "lat", 
		"long": "long",
        "ville":"ville",
    },
    "features":[
        montpellier_json
    ]
}

# %%
import json 
with open('montpellier_bikes_records.json', 'w') as fp:
   json.dump(montpellier_json, fp)

# %%
montpellier_json['features'][0]
# Out:
# {'type': 'FeatureCollection',
#  'name': 'Stations de velos Montpellier',
#  'features': [{'type': 'Feature',
#    'properties': {'name': 'Rue Jules Ferry - Gare Saint-Roch',
#     'lat': '43.605366',
#     'long': '3.881346',
#     'available_bikes_stands': '3',
#     'available_bikes': '9',
#     'total': '12',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Comédie',
#     'lat': '43.608148',
#     'long': '3.878778',
#     'available_bikes_stands': '6',
#     'available_bikes': '18',
#     'total': '24',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Esplanade',
#     'lat': '43.609478',
#     'long': '3.881293',
#     'available_bikes_stands': '1',
#     'available_bikes': '31',
#     'total': '32',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Hôtel de Ville',
#     'lat': '43.599088',
#     'long': '3.894866',
#     'available_bikes_stands': '4',
#     'available_bikes': '12',
#     'total': '16',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Corum',
#     'lat': '43.613989',
#     'long': '3.881600',
#     'available_bikes_stands': '9',
#     'available_bikes': '3',
#     'total': '12',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Place Albert 1er - St Charles',
#     'lat': '43.616768',
#     'long': '3.873375',
#     'available_bikes_stands': '19',
#     'available_bikes': '12',
#     'total': '31',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Foch',
#     'lat': '43.610989',
#     'long': '3.873345',
#     'available_bikes_stands': '7',
#     'available_bikes': '1',
#     'total': '8',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Halles Castellane',
#     'lat': '43.609935',
#     'long': '3.877208',
#     'available_bikes_stands': '8',
#     'available_bikes': '4',
#     'total': '12',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Observatoire',
#     'lat': '43.606081',
#     'long': '3.876931',
#     'available_bikes_stands': '5',
#     'available_bikes': '3',
#     'total': '8',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Rondelet',
#     'lat': '43.603038',
#     'long': '3.875796',
#     'available_bikes_stands': '7',
#     'available_bikes': '9',
#     'total': '16',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Plan Cabanes',
#     'lat': '43.608491',
#     'long': '3.868389',
#     'available_bikes_stands': '3',
#     'available_bikes': '9',
#     'total': '12',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Boutonnet',
#     'lat': '43.622629',
#     'long': '3.868375',
#     'available_bikes_stands': '6',
#     'available_bikes': '6',
#     'total': '12',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Emile Combes',
#     'lat': '43.616742',
#     'long': '3.87998',
#     'available_bikes_stands': '3',
#     'available_bikes': '5',
#     'total': '8',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Beaux-Arts',
#     'lat': '43.616698',
#     'long': '3.884981',
#     'available_bikes_stands': '4',
#     'available_bikes': '4',
#     'total': '8',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Les Aubes',
#     'lat': '43.618692',
#     'long': '3.893844',
#     'available_bikes_stands': '4',
#     'available_bikes': '4',
#     'total': '8',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Antigone centre',
#     'lat': '43.607942',
#     'long': '3.890634',
#     'available_bikes_stands': '13',
#     'available_bikes': '3',
#     'total': '16',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Médiathèque Emile Zola',
#     'lat': '43.608218',
#     'long': '3.893140',
#     'available_bikes_stands': '4',
#     'available_bikes': '12',
#     'total': '16',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': "Nombre d'Or",
#     'lat': '43.607859',
#     'long': '3.886644',
#     'available_bikes_stands': '6',
#     'available_bikes': '10',
#     'total': '16',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Louis Blanc',
#     'lat': '43.614642',
#     'long': '3.877648',
#     'available_bikes_stands': '4',
#     'available_bikes': '12',
#     'total': '16',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Gambetta',
#     'lat': '43.607106',
#     'long': '3.870693',
#     'available_bikes_stands': '5',
#     'available_bikes': '3',
#     'total': '8',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Port Marianne',
#     'lat': '43.600320',
#     'long': '3.898510',
#     'available_bikes_stands': '9',
#     'available_bikes': '7',
#     'total': '16',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Clemenceau',
#     'lat': '43.603539',
#     'long': '3.872394',
#     'available_bikes_stands': '5',
#     'available_bikes': '7',
#     'total': '12',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Les Arceaux',
#     'lat': '43.611991',
#     'long': '3.867157',
#     'available_bikes_stands': '7',
#     'available_bikes': '9',
#     'total': '16',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Cité Mion',
#     'lat': '43.601143',
#     'long': '3.884373',
#     'available_bikes_stands': '3',
#     'available_bikes': '5',
#     'total': '8',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Nouveau Saint-Roch',
#     'lat': '43.599817',
#     'long': '3.875757',
#     'available_bikes_stands': '3',
#     'available_bikes': '5',
#     'total': '8',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Renouvier',
#     'lat': '43.603553',
#     'long': '3.867884',
#     'available_bikes_stands': '5',
#     'available_bikes': '3',
#     'total': '8',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Odysseum',
#     'lat': '43.603727',
#     'long': '3.918979',
#     'available_bikes_stands': '7',
#     'available_bikes': '1',
#     'total': '8',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Saint-Denis',
#     'lat': '43.605021',
#     'long': '3.875065',
#     'available_bikes_stands': '4',
#     'available_bikes': '4',
#     'total': '8',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Richter',
#     'lat': '43.603424',
#     'long': '3.899263',
#     'available_bikes_stands': '9',
#     'available_bikes': '7',
#     'total': '16',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Charles Flahault',
#     'lat': '43.618762',
#     'long': '3.865971',
#     'available_bikes_stands': '2',
#     'available_bikes': '6',
#     'total': '8',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Voltaire',
#     'lat': '43.603767',
#     'long': '3.888659',
#     'available_bikes_stands': '4',
#     'available_bikes': '4',
#     'total': '8',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': "Prés d'Arènes",
#     'lat': '43.590480',
#     'long': '3.884611',
#     'available_bikes_stands': '1',
#     'available_bikes': '7',
#     'total': '8',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Garcia Lorca',
#     'lat': '43.590757',
#     'long': '3.890616',
#     'available_bikes_stands': '2',
#     'available_bikes': '6',
#     'total': '8',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Vert Bois',
#     'lat': '43.634580',
#     'long': '3.868230',
#     'available_bikes_stands': '0',
#     'available_bikes': '16',
#     'total': '16',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Malbosc',
#     'lat': '43.633679',
#     'long': '3.832861',
#     'available_bikes_stands': '7',
#     'available_bikes': '1',
#     'total': '8',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Occitanie',
#     'lat': '43.634242',
#     'long': '3.849128',
#     'available_bikes_stands': '8',
#     'available_bikes': '24',
#     'total': '32',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'FacdesSciences',
#     'lat': '43.631018',
#     'long': '3.860697',
#     'available_bikes_stands': '5',
#     'available_bikes': '19',
#     'total': '24',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Fac de Lettres',
#     'lat': '43.630665',
#     'long': '3.870230',
#     'available_bikes_stands': '5',
#     'available_bikes': '11',
#     'total': '16',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Aiguelongue',
#     'lat': '43.626163',
#     'long': '3.882492',
#     'available_bikes_stands': '3',
#     'available_bikes': '5',
#     'total': '8',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Jeu de Mail des Abbés',
#     'lat': '43.619701',
#     'long': '3.883831',
#     'available_bikes_stands': '4',
#     'available_bikes': '4',
#     'total': '8',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Euromédecine',
#     'lat': '43.639119',
#     'long': '3.828199',
#     'available_bikes_stands': '2',
#     'available_bikes': '6',
#     'total': '8',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Marie Caizergues',
#     'lat': '43.619871',
#     'long': '3.873812',
#     'available_bikes_stands': '5',
#     'available_bikes': '3',
#     'total': '8',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Sabines',
#     'lat': '43.584211',
#     'long': '3.860031',
#     'available_bikes_stands': '1',
#     'available_bikes': '7',
#     'total': '8',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Celleneuve',
#     'lat': '43.614670',
#     'long': '3.832624',
#     'available_bikes_stands': '4',
#     'available_bikes': '4',
#     'total': '8',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Jardin de la Lironde',
#     'lat': '43.605850',
#     'long': '3.911576',
#     'available_bikes_stands': '3',
#     'available_bikes': '5',
#     'total': '8',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Père Soulas',
#     'lat': '43.621983',
#     'long': '3.855603',
#     'available_bikes_stands': '2',
#     'available_bikes': '6',
#     'total': '8',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Place Viala',
#     'lat': '43.616812',
#     'long': '3.855075',
#     'available_bikes_stands': '4',
#     'available_bikes': '4',
#     'total': '8',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Hôtel du Département',
#     'lat': '43.621682',
#     'long': '3.834770',
#     'available_bikes_stands': '3',
#     'available_bikes': '5',
#     'total': '8',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Tonnelles',
#     'lat': '43.615155',
#     'long': '3.839466',
#     'available_bikes_stands': '2',
#     'available_bikes': '6',
#     'total': '8',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Parvis Jules Ferry - Gare Saint-Roch',
#     'lat': '43.603889',
#     'long': '3.879362',
#     'available_bikes_stands': '3',
#     'available_bikes': '5',
#     'total': '8',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Pont de Lattes - Gare Saint-Roch',
#     'lat': '43.606036',
#     'long': '3.882393',
#     'available_bikes_stands': '4',
#     'available_bikes': '8',
#     'total': '12',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Deux Ponts - Gare Saint-Roch',
#     'lat': '43.604319',
#     'long': '3.880916',
#     'available_bikes_stands': '7',
#     'available_bikes': '1',
#     'total': '8',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Providence - Ovalie',
#     'lat': '43.588239',
#     'long': '3.853421',
#     'available_bikes_stands': '4',
#     'available_bikes': '4',
#     'total': '8',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': "Pérols Etang de l'Or",
#     'lat': '43.558351',
#     'long': '3.963412',
#     'available_bikes_stands': '3',
#     'available_bikes': '65',
#     'total': '68',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Albert 1er - Cathédrale',
#     'lat': '43.614005',
#     'long': '3.873218',
#     'available_bikes_stands': '4',
#     'available_bikes': '8',
#     'total': '12',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Saint-Guilhem - Courreau',
#     'lat': '43.608996',
#     'long': '3.872752',
#     'available_bikes_stands': '3',
#     'available_bikes': '5',
#     'total': '8',
#     '@type': 'station',
#     'ville': 'Montpellier'}},
#   {'type': 'Feature',
#    'properties': {'name': 'Sud De France',
#     'lat': '43.595620',
#     'long': '3.923500',
#     'available_bikes_stands': '4',
#     'available_bikes': '4',
#     'total': '8',
#     '@type': 'station',
#     'ville': 'Montpellier'}}]}

# %%
url_lille= 'https://opendata.lillemetropole.fr//explore/dataset/localisation-hopitaux/download?format=json&timezone=Europe/Berlin&use_labels_for_header=false'
data_lille = requests.get(url_lille).json()

data_lille
# Out:
# [{'datasetid': 'localisation-hopitaux',
#   'recordid': 'a8591a3333181faca7c35e0f9f61d70c342f5474',
#   'fields': {'commune': 'LILLE',
#    'code_postal': '59000',
#    'objectid': '979',
#    'url': 'http://hopital-prive-la-louviere-lille.ramsaygds.fr/',
#    'libelle': 'POLYCLINIQUE LA LOUVIERE',
#    'geo_point_2d': [50.6465113784, 3.08395241534],
#    'geometry': {'type': 'Point',
#     'coordinates': [3.0839524153393, 50.64651137837]}},
#   'geometry': {'type': 'Point', 'coordinates': [3.08395241534, 50.6465113784]},
#   'record_timestamp': '2021-03-24T00:00:54.972+01:00'},
#  {'datasetid': 'localisation-hopitaux',
#   'recordid': '163c463e8e5c7b98d2c36697b6a3ca3a72204aea',
#   'fields': {'commune': 'ROUBAIX',
#    'code_postal': '59100',
#    'objectid': '1428',
#    'url': 'http://www.ch-roubaix.fr',
#    'libelle': 'HOPITAL DE LA FRATERNITE',
#    'geo_point_2d': [50.6826161374, 3.19776884998],
#    'geometry': {'type': 'Point',
#     'coordinates': [3.197768849979, 50.682616137418]}},
#   'geometry': {'type': 'Point', 'coordinates': [3.19776884998, 50.6826161374]},
#   'record_timestamp': '2021-03-24T00:00:54.972+01:00'},
#  {'datasetid': 'localisation-hopitaux',
#   'recordid': 'b19ef5400c9edeff86cb0af8021f22692a75a2dd',
#   'fields': {'commune': 'RONCQ',
#    'code_postal': '59223',
#    'objectid': '1395',
#    'url': 'http://www.clinique-saintroch.fr/',
#    'libelle': 'CLINIQUE SAINT ROCH',
#    'geo_point_2d': [50.7327642037, 3.115016521],
#    'geometry': {'type': 'Point',
#     'coordinates': [3.115016521002, 50.732764203664]}},
#   'geometry': {'type': 'Point', 'coordinates': [3.115016521, 50.7327642037]},
#   'record_timestamp': '2021-03-24T00:00:54.972+01:00'},
#  {'datasetid': 'localisation-hopitaux',
#   'recordid': 'ef7af72bc5c0f854b8b59588da4ea1badbb52ffd',
#   'fields': {'commune': 'ARMENTIERES',
#    'code_postal': '59280',
#    'objectid': '184',
#    'url': 'http://www.ch-armentieres.fr',
#    'libelle': 'CHR CENTRE HOSPITALIER',
#    'geo_point_2d': [50.6846779019, 2.86783660669],
#    'geometry': {'type': 'Point',
#     'coordinates': [2.867836606694, 50.684677901903]}},
#   'geometry': {'type': 'Point', 'coordinates': [2.86783660669, 50.6846779019]},
#   'record_timestamp': '2021-03-24T00:00:54.972+01:00'},
#  {'datasetid': 'localisation-hopitaux',
#   'recordid': '952dcc58254e2095dda3677d8c69d1a7848fd915',
#   'fields': {'commune': 'TOURCOING',
#    'code_postal': '59200',
#    'objectid': '1734',
#    'url': 'http://www.groupehpm.com/cliniques/index/87',
#    'libelle': 'POLYCLINIQUE DU VAL DE LYS',
#    'geo_point_2d': [50.7246508856, 3.14800433887],
#    'geometry': {'type': 'Point',
#     'coordinates': [3.1480043388737, 50.724650885578]}},
#   'geometry': {'type': 'Point', 'coordinates': [3.14800433887, 50.7246508856]},
#   'record_timestamp': '2021-03-24T00:00:54.972+01:00'},
#  {'datasetid': 'localisation-hopitaux',
#   'recordid': 'a6c96bb9ea3b36b40ebd08c52e21773e62e6a07f',
#   'fields': {'commune': 'LILLE',
#    'code_postal': '59000',
#    'objectid': '4238',
#    'url': 'http://www.saintvincentdepaul-lille.fr/',
#    'libelle': 'HOPITAL SAINT VINCENT DE PAUL GROUPE INSTITUT CATHOLIQUE',
#    'geo_point_2d': [50.6202380916, 3.07717927762],
#    'geometry': {'type': 'Point',
#     'coordinates': [3.0771792776184, 50.620238091599]}},
#   'geometry': {'type': 'Point', 'coordinates': [3.07717927762, 50.6202380916]},
#   'record_timestamp': '2021-03-24T00:00:54.972+01:00'},
#  {'datasetid': 'localisation-hopitaux',
#   'recordid': 'ae565d48eba9ec1e1927cebf490fa93465fa9e47',
#   'fields': {'commune': 'TOURCOING',
#    'code_postal': '59200',
#    'objectid': '1668',
#    'url': 'http://www.ch-tourcoing.fr',
#    'libelle': 'CENTRE HOSPITALIER GUSTAVE DRON',
#    'geo_point_2d': [50.7446443074, 3.18029017856],
#    'geometry': {'type': 'Point',
#     'coordinates': [3.1802901785553, 50.744644307373]}},
#   'geometry': {'type': 'Point', 'coordinates': [3.18029017856, 50.7446443074]},
#   'record_timestamp': '2021-03-24T00:00:54.972+01:00'},
#  {'datasetid': 'localisation-hopitaux',
#   'recordid': '5fb58f2a91d8a987273235389d241891ee1f89ca',
#   'fields': {'commune': 'LILLE',
#    'code_postal': '59000',
#    'objectid': '3350',
#    'url': 'http://www.polyclinique-bois.com',
#    'libelle': 'HOPITAL PRIVE LE BOIS',
#    'geo_point_2d': [50.6339108151, 3.03153623994],
#    'geometry': {'type': 'Point',
#     'coordinates': [3.0315362399364, 50.633910815113]}},
#   'geometry': {'type': 'Point', 'coordinates': [3.03153623994, 50.6339108151]},
#   'record_timestamp': '2021-03-24T00:00:54.972+01:00'},
#  {'datasetid': 'localisation-hopitaux',
#   'recordid': '3284f0b918627ca40f09d8ae5d38a505533bf8e3',
#   'fields': {'commune': 'LOOS',
#    'code_postal': '59120',
#    'objectid': '1095',
#    'url': 'http://www.ghlh.fr',
#    'libelle': 'CHR CENTRE HOSPITALIER LOOS HAUBOURDIN',
#    'geo_point_2d': [50.6105672954, 3.00789073236],
#    'geometry': {'type': 'Point',
#     'coordinates': [3.007890732357, 50.610567295391]}},
#   'geometry': {'type': 'Point', 'coordinates': [3.00789073236, 50.6105672954]},
#   'record_timestamp': '2021-03-24T00:00:54.972+01:00'},
#  {'datasetid': 'localisation-hopitaux',
#   'recordid': '03ff1c29c80d86f3e54b8564089d323a2eb9ab2b',
#   'fields': {'commune': 'WATTRELOS',
#    'code_postal': '59150',
#    'objectid': '1877',
#    'url': 'http://www.ch-wattrelos.com',
#    'libelle': 'CENTRE HOSPITALIER',
#    'geo_point_2d': [50.7007490358, 3.22201522281],
#    'geometry': {'type': 'Point',
#     'coordinates': [3.2220152228126, 50.700749035758]}},
#   'geometry': {'type': 'Point', 'coordinates': [3.22201522281, 50.7007490358]},
#   'record_timestamp': '2021-03-24T00:00:54.972+01:00'},
#  {'datasetid': 'localisation-hopitaux',
#   'recordid': '1f32397037ace426a75e8804339f9742ba12dae2',
#   'fields': {'commune': 'TOURCOING',
#    'code_postal': '59200',
#    'objectid': '5619',
#    'url': 'http://www.groupehpm.com/clinique-victoire-tourcoing',
#    'libelle': 'CLINIQUE DE LA VICTOIRE HPM',
#    'geo_point_2d': [50.7164587684, 3.15662245507],
#    'geometry': {'type': 'Point',
#     'coordinates': [3.1566224550655, 50.716458768421]}},
#   'geometry': {'type': 'Point', 'coordinates': [3.15662245507, 50.7164587684]},
#   'record_timestamp': '2021-03-24T00:00:54.972+01:00'},
#  {'datasetid': 'localisation-hopitaux',
#   'recordid': 'cfaf8af5c53f36cb29a47aeffc96cdcd2b777a44',
#   'fields': {'commune': "VILLENEUVE D'ASCQ",
#    'code_postal': '59650',
#    'objectid': '2109',
#    'url': 'http://www.generale-de-sante.fr/hopital-prive-de-villeneuve-d-ascq',
#    'libelle': "HOPITAL PRIVE DE VILLENEUVE D'ASCQ",
#    'geo_point_2d': [50.6530104252, 3.15218579198],
#    'geometry': {'type': 'Point',
#     'coordinates': [3.1521857919809, 50.653010425216]}},
#   'geometry': {'type': 'Point', 'coordinates': [3.15218579198, 50.6530104252]},
#   'record_timestamp': '2021-03-24T00:00:54.972+01:00'},
#  {'datasetid': 'localisation-hopitaux',
#   'recordid': '9a24e25a3c3f8df7dd42794948446bf24d30b429',
#   'fields': {'commune': '(LOMME) LILLE',
#    'code_postal': '59160',
#    'objectid': '1036',
#    'url': 'http://www.saintphilibert-lomme.fr/',
#    'libelle': 'HOPITAL SAINT PHILIBERT GROUPE INSTITUT CATHOLIQUE',
#    'geo_point_2d': [50.6513947118, 2.9731517883],
#    'geometry': {'type': 'Point',
#     'coordinates': [2.9731517882953, 50.651394711752]}},
#   'geometry': {'type': 'Point', 'coordinates': [2.9731517883, 50.6513947118]},
#   'record_timestamp': '2021-03-24T00:00:54.972+01:00'},
#  {'datasetid': 'localisation-hopitaux',
#   'recordid': '899c266b3b4560b4ed1b85ea2958916495302b24',
#   'fields': {'commune': 'ROUBAIX',
#    'code_postal': '59100',
#    'objectid': '1410',
#    'url': 'http://www.ch-roubaix.fr',
#    'libelle': 'CENTRE HOSPITALIER DE ROUBAIX VICTOR PROVO',
#    'geo_point_2d': [50.679169334, 3.17382832463],
#    'geometry': {'type': 'Point',
#     'coordinates': [3.1738283246326, 50.679169333955]}},
#   'geometry': {'type': 'Point', 'coordinates': [3.17382832463, 50.679169334]},
#   'record_timestamp': '2021-03-24T00:00:54.972+01:00'},
#  {'datasetid': 'localisation-hopitaux',
#   'recordid': '276d8989c2538ebf474327a87432bfa66c9ba3ea',
#   'fields': {'commune': 'HAUBOURDIN',
#    'code_postal': '59320',
#    'objectid': '6229',
#    'url': 'http://www.ghlh.fr',
#    'libelle': 'CENTRE HOSPITALIER JEAN LUXEMBOURG',
#    'geo_point_2d': [50.6130128507, 2.98673462341],
#    'geometry': {'type': 'Point',
#     'coordinates': [2.9867346234108, 50.61301285066]}},
#   'geometry': {'type': 'Point', 'coordinates': [2.98673462341, 50.6130128507]},
#   'record_timestamp': '2021-03-24T00:00:54.972+01:00'},
#  {'datasetid': 'localisation-hopitaux',
#   'recordid': 'e66497959d88f737396eb6d7f89d8b74da17d1d6',
#   'fields': {'commune': 'ROUBAIX',
#    'code_postal': '59100',
#    'objectid': '1416',
#    'geometry': {'type': 'Point',
#     'coordinates': [3.178288786343, 50.685912854851]},
#    'libelle': 'CLINIQUE SAINT JEAN',
#    'geo_point_2d': [50.6859128549, 3.17828878634]},
#   'geometry': {'type': 'Point', 'coordinates': [3.17828878634, 50.6859128549]},
#   'record_timestamp': '2021-03-24T00:00:54.972+01:00'},
#  {'datasetid': 'localisation-hopitaux',
#   'recordid': '90799c39903b5d6cd3faea06c899ed024ef806aa',
#   'fields': {'commune': '(LOMME) LILLE',
#    'code_postal': '59160',
#    'objectid': '3857',
#    'url': 'http://www.clinique-mitterie.com',
#    'libelle': 'CLINIQUE DE LA MITTERIE',
#    'geo_point_2d': [50.653891345, 2.9923404297],
#    'geometry': {'type': 'Point',
#     'coordinates': [2.9923404297026, 50.65389134502]}},
#   'geometry': {'type': 'Point', 'coordinates': [2.9923404297, 50.653891345]},
#   'record_timestamp': '2021-03-24T00:00:54.972+01:00'},
#  {'datasetid': 'localisation-hopitaux',
#   'recordid': '91616b8677973f91df8af60d66d0516a70eae2fd',
#   'fields': {'commune': 'LILLE',
#    'code_postal': '59000',
#    'objectid': '4259',
#    'url': 'http://www.groupehpm.com/clinique-ambroisepare-lille',
#    'libelle': 'CLINIQUE AMBROISE PARE HPM',
#    'geo_point_2d': [50.6491473003, 3.08549912212],
#    'geometry': {'type': 'Point',
#     'coordinates': [3.0854991221233, 50.649147300325]}},
#   'geometry': {'type': 'Point', 'coordinates': [3.08549912212, 50.6491473003]},
#   'record_timestamp': '2021-03-24T00:00:54.972+01:00'},
#  {'datasetid': 'localisation-hopitaux',
#   'recordid': 'c027137713817880283b9a5e93755289d48b348e',
#   'fields': {'commune': 'LILLE',
#    'code_postal': '59000',
#    'objectid': '5538',
#    'url': 'http://www.chru-lille.fr',
#    'libelle': 'CENTRE HOSPITALIER REGIONAL ET UNIVERSITAIRE',
#    'geo_point_2d': [50.6086696715, 3.03596840781],
#    'geometry': {'type': 'Point',
#     'coordinates': [3.0359684078101, 50.60866967145]}},
#   'geometry': {'type': 'Point', 'coordinates': [3.03596840781, 50.6086696715]},
#   'record_timestamp': '2021-03-24T00:00:54.972+01:00'},
#  {'datasetid': 'localisation-hopitaux',
#   'recordid': 'fc53695ccb11ac4b8c89b3d16871597cbcb70e16',
#   'fields': {'commune': 'SECLIN',
#    'code_postal': '59113',
#    'objectid': '1571',
#    'url': 'http://www.ch-seclin.fr/index/1/1',
#    'libelle': 'CHR CENTRE HOSPITALIER DE SECLIN',
#    'geo_point_2d': [50.5466414558, 3.01781005107],
#    'geometry': {'type': 'Point',
#     'coordinates': [3.0178100510722, 50.54664145579]}},
#   'geometry': {'type': 'Point', 'coordinates': [3.01781005107, 50.5466414558]},
#   'record_timestamp': '2021-03-24T00:00:54.972+01:00'},
#  {'datasetid': 'localisation-hopitaux',
#   'recordid': 'db244d576e3a44e4b3c7591cda36a2e7d6195d7b',
#   'fields': {'commune': 'LESQUIN',
#    'code_postal': '59810',
#    'objectid': '830',
#    'url': 'http://www.groupehpm.com/clinique-lille-sud',
#    'libelle': 'CLINIQUE LILLE SUD SOS MAINS HPM',
#    'geo_point_2d': [50.5888971553, 3.08948682714],
#    'geometry': {'type': 'Point',
#     'coordinates': [3.0894868271423, 50.588897155281]}},
#   'geometry': {'type': 'Point', 'coordinates': [3.08948682714, 50.5888971553]},
#   'record_timestamp': '2021-03-24T00:00:54.972+01:00'},
#  {'datasetid': 'localisation-hopitaux',
#   'recordid': 'e008f8d7e269e8e1a7027a1f4558c1cb041eff31',
#   'fields': {'commune': 'MARCQ-EN-BAROEUL',
#    'code_postal': '59700',
#    'objectid': '1168',
#    'url': 'http://www.clinique-sport-lille.fr/',
#    'libelle': 'CLINIQUE DU SPORT ET DE CHIRURGIE ORTHOPEDIQUE HPM',
#    'geo_point_2d': [50.666496025, 3.10155008906],
#    'geometry': {'type': 'Point',
#     'coordinates': [3.1015500890599, 50.666496024961]}},
#   'geometry': {'type': 'Point', 'coordinates': [3.10155008906, 50.666496025]},
#   'record_timestamp': '2021-03-24T00:00:54.972+01:00'}]

# %%
for element in data_lille:
    del element['datasetid']
    del element['recordid']
    del element['fields']['objectid']
    if 'url' in element['fields']:
        del element['fields']['url']
    del element['fields']['libelle']
    del element['fields']['geometry']
    del element['geometry']
    del element['record_timestamp']
    element['fields']

# %%
data_lille
# Out:
# [{'fields': {'commune': 'LILLE',
#    'code_postal': '59000',
#    'geo_point_2d': [50.6465113784, 3.08395241534]}},
#  {'fields': {'commune': 'ROUBAIX',
#    'code_postal': '59100',
#    'geo_point_2d': [50.6826161374, 3.19776884998]}},
#  {'fields': {'commune': 'RONCQ',
#    'code_postal': '59223',
#    'geo_point_2d': [50.7327642037, 3.115016521]}},
#  {'fields': {'commune': 'ARMENTIERES',
#    'code_postal': '59280',
#    'geo_point_2d': [50.6846779019, 2.86783660669]}},
#  {'fields': {'commune': 'TOURCOING',
#    'code_postal': '59200',
#    'geo_point_2d': [50.7246508856, 3.14800433887]}},
#  {'fields': {'commune': 'LILLE',
#    'code_postal': '59000',
#    'geo_point_2d': [50.6202380916, 3.07717927762]}},
#  {'fields': {'commune': 'TOURCOING',
#    'code_postal': '59200',
#    'geo_point_2d': [50.7446443074, 3.18029017856]}},
#  {'fields': {'commune': 'LILLE',
#    'code_postal': '59000',
#    'geo_point_2d': [50.6339108151, 3.03153623994]}},
#  {'fields': {'commune': 'LOOS',
#    'code_postal': '59120',
#    'geo_point_2d': [50.6105672954, 3.00789073236]}},
#  {'fields': {'commune': 'WATTRELOS',
#    'code_postal': '59150',
#    'geo_point_2d': [50.7007490358, 3.22201522281]}},
#  {'fields': {'commune': 'TOURCOING',
#    'code_postal': '59200',
#    'geo_point_2d': [50.7164587684, 3.15662245507]}},
#  {'fields': {'commune': "VILLENEUVE D'ASCQ",
#    'code_postal': '59650',
#    'geo_point_2d': [50.6530104252, 3.15218579198]}},
#  {'fields': {'commune': '(LOMME) LILLE',
#    'code_postal': '59160',
#    'geo_point_2d': [50.6513947118, 2.9731517883]}},
#  {'fields': {'commune': 'ROUBAIX',
#    'code_postal': '59100',
#    'geo_point_2d': [50.679169334, 3.17382832463]}},
#  {'fields': {'commune': 'HAUBOURDIN',
#    'code_postal': '59320',
#    'geo_point_2d': [50.6130128507, 2.98673462341]}},
#  {'fields': {'commune': 'ROUBAIX',
#    'code_postal': '59100',
#    'geo_point_2d': [50.6859128549, 3.17828878634]}},
#  {'fields': {'commune': '(LOMME) LILLE',
#    'code_postal': '59160',
#    'geo_point_2d': [50.653891345, 2.9923404297]}},
#  {'fields': {'commune': 'LILLE',
#    'code_postal': '59000',
#    'geo_point_2d': [50.6491473003, 3.08549912212]}},
#  {'fields': {'commune': 'LILLE',
#    'code_postal': '59000',
#    'geo_point_2d': [50.6086696715, 3.03596840781]}},
#  {'fields': {'commune': 'SECLIN',
#    'code_postal': '59113',
#    'geo_point_2d': [50.5466414558, 3.01781005107]}},
#  {'fields': {'commune': 'LESQUIN',
#    'code_postal': '59810',
#    'geo_point_2d': [50.5888971553, 3.08948682714]}},
#  {'fields': {'commune': 'MARCQ-EN-BAROEUL',
#    'code_postal': '59700',
#    'geo_point_2d': [50.666496025, 3.10155008906]}}]

# %%
for element in data_lille:
    element['type']='Feature'
    element['fields']['@type'] = "hopital"
    element['fields']['ville'] = 'Lille'
    element['fields']['lat']= element['fields']['geo_point_2d'][0]
    element['fields']['long'] = element['fields']['geo_point_2d'][1]

# %%
data_lille
# Out:
# [{'fields': {'commune': 'LILLE',
#    'code_postal': '59000',
#    'geo_point_2d': [50.6465113784, 3.08395241534],
#    '@type': 'hopital',
#    'ville': 'Lille',
#    'lat': 50.6465113784,
#    'long': 3.08395241534},
#   'type': 'Feature'},
#  {'fields': {'commune': 'ROUBAIX',
#    'code_postal': '59100',
#    'geo_point_2d': [50.6826161374, 3.19776884998],
#    '@type': 'hopital',
#    'ville': 'Lille',
#    'lat': 50.6826161374,
#    'long': 3.19776884998},
#   'type': 'Feature'},
#  {'fields': {'commune': 'RONCQ',
#    'code_postal': '59223',
#    'geo_point_2d': [50.7327642037, 3.115016521],
#    '@type': 'hopital',
#    'ville': 'Lille',
#    'lat': 50.7327642037,
#    'long': 3.115016521},
#   'type': 'Feature'},
#  {'fields': {'commune': 'ARMENTIERES',
#    'code_postal': '59280',
#    'geo_point_2d': [50.6846779019, 2.86783660669],
#    '@type': 'hopital',
#    'ville': 'Lille',
#    'lat': 50.6846779019,
#    'long': 2.86783660669},
#   'type': 'Feature'},
#  {'fields': {'commune': 'TOURCOING',
#    'code_postal': '59200',
#    'geo_point_2d': [50.7246508856, 3.14800433887],
#    '@type': 'hopital',
#    'ville': 'Lille',
#    'lat': 50.7246508856,
#    'long': 3.14800433887},
#   'type': 'Feature'},
#  {'fields': {'commune': 'LILLE',
#    'code_postal': '59000',
#    'geo_point_2d': [50.6202380916, 3.07717927762],
#    '@type': 'hopital',
#    'ville': 'Lille',
#    'lat': 50.6202380916,
#    'long': 3.07717927762},
#   'type': 'Feature'},
#  {'fields': {'commune': 'TOURCOING',
#    'code_postal': '59200',
#    'geo_point_2d': [50.7446443074, 3.18029017856],
#    '@type': 'hopital',
#    'ville': 'Lille',
#    'lat': 50.7446443074,
#    'long': 3.18029017856},
#   'type': 'Feature'},
#  {'fields': {'commune': 'LILLE',
#    'code_postal': '59000',
#    'geo_point_2d': [50.6339108151, 3.03153623994],
#    '@type': 'hopital',
#    'ville': 'Lille',
#    'lat': 50.6339108151,
#    'long': 3.03153623994},
#   'type': 'Feature'},
#  {'fields': {'commune': 'LOOS',
#    'code_postal': '59120',
#    'geo_point_2d': [50.6105672954, 3.00789073236],
#    '@type': 'hopital',
#    'ville': 'Lille',
#    'lat': 50.6105672954,
#    'long': 3.00789073236},
#   'type': 'Feature'},
#  {'fields': {'commune': 'WATTRELOS',
#    'code_postal': '59150',
#    'geo_point_2d': [50.7007490358, 3.22201522281],
#    '@type': 'hopital',
#    'ville': 'Lille',
#    'lat': 50.7007490358,
#    'long': 3.22201522281},
#   'type': 'Feature'},
#  {'fields': {'commune': 'TOURCOING',
#    'code_postal': '59200',
#    'geo_point_2d': [50.7164587684, 3.15662245507],
#    '@type': 'hopital',
#    'ville': 'Lille',
#    'lat': 50.7164587684,
#    'long': 3.15662245507},
#   'type': 'Feature'},
#  {'fields': {'commune': "VILLENEUVE D'ASCQ",
#    'code_postal': '59650',
#    'geo_point_2d': [50.6530104252, 3.15218579198],
#    '@type': 'hopital',
#    'ville': 'Lille',
#    'lat': 50.6530104252,
#    'long': 3.15218579198},
#   'type': 'Feature'},
#  {'fields': {'commune': '(LOMME) LILLE',
#    'code_postal': '59160',
#    'geo_point_2d': [50.6513947118, 2.9731517883],
#    '@type': 'hopital',
#    'ville': 'Lille',
#    'lat': 50.6513947118,
#    'long': 2.9731517883},
#   'type': 'Feature'},
#  {'fields': {'commune': 'ROUBAIX',
#    'code_postal': '59100',
#    'geo_point_2d': [50.679169334, 3.17382832463],
#    '@type': 'hopital',
#    'ville': 'Lille',
#    'lat': 50.679169334,
#    'long': 3.17382832463},
#   'type': 'Feature'},
#  {'fields': {'commune': 'HAUBOURDIN',
#    'code_postal': '59320',
#    'geo_point_2d': [50.6130128507, 2.98673462341],
#    '@type': 'hopital',
#    'ville': 'Lille',
#    'lat': 50.6130128507,
#    'long': 2.98673462341},
#   'type': 'Feature'},
#  {'fields': {'commune': 'ROUBAIX',
#    'code_postal': '59100',
#    'geo_point_2d': [50.6859128549, 3.17828878634],
#    '@type': 'hopital',
#    'ville': 'Lille',
#    'lat': 50.6859128549,
#    'long': 3.17828878634},
#   'type': 'Feature'},
#  {'fields': {'commune': '(LOMME) LILLE',
#    'code_postal': '59160',
#    'geo_point_2d': [50.653891345, 2.9923404297],
#    '@type': 'hopital',
#    'ville': 'Lille',
#    'lat': 50.653891345,
#    'long': 2.9923404297},
#   'type': 'Feature'},
#  {'fields': {'commune': 'LILLE',
#    'code_postal': '59000',
#    'geo_point_2d': [50.6491473003, 3.08549912212],
#    '@type': 'hopital',
#    'ville': 'Lille',
#    'lat': 50.6491473003,
#    'long': 3.08549912212},
#   'type': 'Feature'},
#  {'fields': {'commune': 'LILLE',
#    'code_postal': '59000',
#    'geo_point_2d': [50.6086696715, 3.03596840781],
#    '@type': 'hopital',
#    'ville': 'Lille',
#    'lat': 50.6086696715,
#    'long': 3.03596840781},
#   'type': 'Feature'},
#  {'fields': {'commune': 'SECLIN',
#    'code_postal': '59113',
#    'geo_point_2d': [50.5466414558, 3.01781005107],
#    '@type': 'hopital',
#    'ville': 'Lille',
#    'lat': 50.5466414558,
#    'long': 3.01781005107},
#   'type': 'Feature'},
#  {'fields': {'commune': 'LESQUIN',
#    'code_postal': '59810',
#    'geo_point_2d': [50.5888971553, 3.08948682714],
#    '@type': 'hopital',
#    'ville': 'Lille',
#    'lat': 50.5888971553,
#    'long': 3.08948682714},
#   'type': 'Feature'},
#  {'fields': {'commune': 'MARCQ-EN-BAROEUL',
#    'code_postal': '59700',
#    'geo_point_2d': [50.666496025, 3.10155008906],
#    '@type': 'hopital',
#    'ville': 'Lille',
#    'lat': 50.666496025,
#    'long': 3.10155008906},
#   'type': 'Feature'}]

# %%
data_lille={
    "@context":{
        "@vocab": "http://schema.org/", 
		"@base": "http://data.org/", 
		"name": "name", 
		"lat": "lat", 
		"long": "long",
        "ville":"ville",
    },
    "features":[
        data_lille
    ]
}

# %%
import json 
with open('lille_hospital_records.json', 'w') as fp:
   json.dump(data_lille, fp,ensure_ascii=False)

# %%
url_hospital= 'https://www.data.gouv.fr/fr/datasets/r/1818b1fa-93cf-4d3d-acf1-b3a4c99c4ee5'
data_hospital = requests.get(url_hospital).json()


for element in data_hospital['features']:
    del element['id']
    del element['geometry']['type']
    del element['geometry_name']
    del element['properties']['amenity']
    del element['properties']['short_name']
    del element['properties']['official_name']
    del element['properties']['alt_name']
    del element['properties']['old_name']
    del element['properties']['operator']
    del element['properties']['operator-type']
    del element['properties']['emergency']
    del element['properties']['capacity']
    del element['properties']['wheelchair']
    del element['properties']['ref-FR-FINESS']
    del element['properties']['type-FR-FINESS']
    del element['properties']['ref-FR-NAF']
    del element['properties']['ref-FR-SIRET']
    del element['properties']['contact-website']
    del element['properties']['url']
    del element['properties']['phone']
    del element['properties']['contact-phone']
    del element['properties']['email']
    del element['properties']['contact-email']
    del element['properties']['addr-housename']
    del element['properties']['addr-housenumber']
    del element['properties']['addr-street']
    del element['properties']['addr-city']
    del element['properties']['addr-postcode']
    del element['properties']['wikidata']
    del element['properties']['description']
    del element['properties']['opening_hours']
    del element['properties']['source']
    del element['properties']['note']
    del element['properties']['osm_type']
    del element['properties']['osm_version']
    del element['properties']['osm_timestamp']
    del element['properties']['healthcare-speciality']
    del element['properties']['osm_original_geom']
    del element['properties']['bbox']
    del element['properties']['osm_id']
    del element['properties']['fax']
    del element['properties']['contact-fax']
    del element['properties']['wikipedia']
    del element['type']
    element['@type']='hospital'
    element['geometry']['lat']= element['geometry']['coordinates'][0]
    element['geometry']['long'] = element['geometry']['coordinates'][1]
    del element['geometry']['coordinates']
del data_hospital['totalFeatures']
del data_hospital['numberMatched']
del data_hospital['numberReturned']
del data_hospital['timeStamp']
del data_hospital['crs']
del data_hospital['bbox']
    
data_hospital
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'geometry': {'lat': 638784.243, 'long': 5682727.2935},
#    'properties': {'name': 'Centre Hospitalier de Saint-Laurent-du-Pont'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': -369440.8142, 'long': 6060261.7588},
#    'properties': {'name': 'Port Louis-Riantec'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 300280.3168, 'long': 6175530.1887},
#    'properties': {'name': 'Centre hospitalier de Fontainebleau'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 343167.889, 'long': 6243448.1485},
#    'properties': {'name': 'Centre hospitalier de Coulommiers'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 331607.7213, 'long': 5538202.8283},
#    'properties': {'name': "Hôpital de St Geniez d'Olt"},
#    '@type': 'hospital'},
#   {'geometry': {'lat': -471416.6105, 'long': 6181684.0261},
#    'properties': {'name': 'Centre Hospitalier Ferdinand Grall'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 551678.7091, 'long': 6212905.4125},
#    'properties': {'name': 'Centre Hospitalier Georges Heuyer'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 214857.0192, 'long': 5227732.0775},
#    'properties': {'name': 'Hospital de Cerdanya'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': -310384.1334, 'long': 6198532.2846},
#    'properties': {'name': "Hôpital Privé des Côtes d'Armor"},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 242241.2042, 'long': 6223707.5372},
#    'properties': {'name': 'Bâtiment 101 - Centre de protonthérapie'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 12578.4735, 'long': 6360056.5918},
#    'properties': {'name': 'Hôpital Flaubert'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 296299.2337, 'long': 5826212.6403},
#    'properties': {'name': 'Centre Hospitalier de Néris-Les-Bains'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 665668.1474, 'long': 5977302.9385},
#    'properties': {'name': 'Polyclinique de Franche-Comté'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 8682.7865, 'long': 6179289.1579},
#    'properties': {'name': "Centre Psychothérapique de l'Orne"},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 528457.084, 'long': 5681704.3575},
#    'properties': {'name': 'Hôpital Local de Saint-Pierre-de-Bœuf'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 601534.3542, 'long': 5356166.0255},
#    'properties': {'name': 'Hôpital de la Timone'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 450690.4347, 'long': 6319994.1675},
#    'properties': {'name': 'CHU Reims - Hôpital Sébastopol'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': -332492.7732, 'long': 6139851.0551},
#    'properties': {'name': 'Pharmacie de Guerledan'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 509803.5657, 'long': 5619759.4465},
#    'properties': {'name': 'Hôpital Elisée Charra Lamastre'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 563632.4228, 'long': 5548205.9063},
#    'properties': {'name': 'Dieulefit Santé'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 807296.7593, 'long': 6044536.2076},
#    'properties': {'name': "Centre hospitalier d'Altkirch"},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 596724.0237, 'long': 5370149.778},
#    'properties': {'name': 'Centre Hospitalier Spécialisé Édouard Toulouse'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 360058.5569, 'long': 6381579.8969},
#    'properties': {'name': 'Centre Hospitalier de Chauny'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 185788.4547, 'long': 6310368.9435},
#    'properties': {'name': "Maison de santé de l'Epte"},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 130628.2576, 'long': 6325538.1525},
#    'properties': {'name': 'Clinique La Mare'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': -64120.0556, 'long': 5591341.7994},
#    'properties': {'name': 'Maison de santé protestante de Bagatelle'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 840594.9233, 'long': 6037668.4447},
#    'properties': {'name': 'Polyclinique des 3 Frontières'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 213807.1166, 'long': 6079679.0947},
#    'properties': {'name': "Centre Hospitalier Régional d'Orléans"},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 810481.7403, 'long': 5422928.5041},
#    'properties': {'name': 'Centre Antoine Lacassagne'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 604219.9894, 'long': 5349882.0622},
#    'properties': {'name': 'Hôpital privé Clairval'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 253496.9056, 'long': 6423277.2186},
#    'properties': {'name': 'Centre de Post-Cure'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 602581.0163, 'long': 5352216.5647},
#    'properties': {'name': 'Hôpital Salvator'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 157449.5508, 'long': 5402837.2635},
#    'properties': {'name': None},
#    '@type': 'hospital'},
#   {'geometry': {'lat': -82415.2171, 'long': 5884465.4088},
#    'properties': {'name': 'Hôpital des Collines Vendéennes'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 488833.1978, 'long': 5686424.6256},
#    'properties': {'name': 'Hôpital Bellevue'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 265607.6869, 'long': 6253425.5443},
#    'properties': {'name': 'Centre post-cure de la Métairie'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 42158.102, 'long': 5458638.7751},
#    'properties': {'name': 'Centre Hospitalier de Condom'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 546412.0656, 'long': 5870543.4594},
#    'properties': {'name': None},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 212639.357, 'long': 6083075.2635},
#    'properties': {'name': 'Centre de soins "Les Buissonnets"'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 531247.7239, 'long': 5738869.1636},
#    'properties': {'name': 'La Maisonnée'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 88208.084, 'long': 5703577.3535},
#    'properties': {'name': 'Larret à venir'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 515805.505, 'long': 5412569.7747},
#    'properties': {'name': "Centre hospitalier d'Arles"},
#    '@type': 'hospital'},
#   {'geometry': {'lat': -102629.9506, 'long': 6156124.9523},
#    'properties': {'name': 'Hôpital Ernée'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 208111.7328, 'long': 5806682.4128},
#    'properties': {'name': 'Centre hospitalier de Guéret'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 346041.5682, 'long': 5748748.0827},
#    'properties': {'name': 'Clinique de la Plaine'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 66071.5826, 'long': 5410537.8718},
#    'properties': {'name': 'Centre hospitalier spécialisé'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 282594.8244, 'long': 6268111.3885},
#    'properties': {'name': "Clinique de l'Alliance"},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 248832.8543, 'long': 6249263.5146},
#    'properties': {'name': 'Hôpital Ambroise Paré'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 379914.0931, 'long': 6283897.3275},
#    'properties': {'name': 'Centre hospitalier de Château-Thierry'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 723950.1081, 'long': 6205426.8065},
#    'properties': {'name': "Clinique Jeanne d'arc"},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 602880.2285, 'long': 5353181.8516},
#    'properties': {'name': 'Hôpital Privé Résidence du Parc'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 55919.6242, 'long': 5598455.3174},
#    'properties': {'name': "Pôle d'Hospitalisation Psychiatrique"},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 319830.8254, 'long': 5638968.8132},
#    'properties': {'name': 'Centre Hospitalier de Murat'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 79868.5101, 'long': 5650108.1881},
#    'properties': {'name': 'Clinique Francheville'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 971668.6546, 'long': 5148147.43},
#    'properties': {'name': 'Clinique du Golfe'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 280171.5691, 'long': 6242913.8613},
#    'properties': {'name': "Hôpital privé Paul d'Égine"},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 146023.8632, 'long': 5413106.8896},
#    'properties': {'name': 'Clinique des Cèdres'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 810185.8821, 'long': 5425459.6408},
#    'properties': {'name': 'Les Sources - Hôpital Gériatrique'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 810417.0249, 'long': 5422741.9734},
#    'properties': {'name': 'Villa Romaine'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 599181.4039, 'long': 5350074.553},
#    'properties': {'name': 'Clinique Mutualiste Bonneveine'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 253739.6546, 'long': 6256488.4062},
#    'properties': {'name': 'Institut hospitalier franco-britannique - Site Kléber'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 337596.4912, 'long': 6552153.9016},
#    'properties': {'name': 'Hôpital Roger Salengro'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 254757.4136, 'long': 6247610.5053},
#    'properties': {'name': 'Maternité Sainte-Félicité'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 319250.4153, 'long': 6565693.5932},
#    'properties': {'name': "Centre hospitalier d'Armentières"},
#    '@type': 'hospital'},
#   {'geometry': {'lat': -72780.0625, 'long': 5739828.4244},
#    'properties': {'name': 'Centre hospitalier de Saintonge'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': -64437.8399, 'long': 5600068.7254},
#    'properties': {'name': 'Polyclinique Bordeaux Nord Aquitaine'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 61808.2707, 'long': 5914649.0288},
#    'properties': {'name': 'Centre hospitalier de Chatellerault'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 325860.985, 'long': 6008280.7271},
#    'properties': {'name': 'Pôle de santé'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 578197.0472, 'long': 5765358.5703},
#    'properties': {'name': 'Hôpital C.J. Ruivet'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 346502.8027, 'long': 5762533.4702},
#    'properties': {'name': 'Centre Hospitalier Guy Thomas'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 278703.8297, 'long': 6240730.7378},
#    'properties': {'name': 'Centre de Santé Jean Moulin'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 255560.1804, 'long': 6247697.1374},
#    'properties': {'name': 'Clinique Blomet'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 673205.7338, 'long': 5340781.3065},
#    'properties': {'name': 'Alain Laporte'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 291085.537, 'long': 6228010.4964},
#    'properties': {'name': 'Hôpital Forcilles'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 811326.6577, 'long': 6098677.4998},
#    'properties': {'name': 'Centre Hospitalier de Rouffach'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 635441.4172, 'long': 5914765.4407},
#    'properties': {'name': 'Centre Hospitalier de Poligny'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 826531.0867, 'long': 5424937.5257},
#    'properties': {'name': 'Centre Cardio Thoracique de Monaco'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 321522.511, 'long': 6314670.2344},
#    'properties': {'name': 'Hôpital local de Crépy-en-Valois'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 192688.9174, 'long': 6001034.8243},
#    'properties': {'name': 'Centre hospitalier de Romorantin-Lanthenay'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 248926.309, 'long': 6262135.3923},
#    'properties': {'name': 'Hôpital Louis Mourier'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 270156.6404, 'long': 5607230.8716},
#    'properties': {'name': 'Centre Médico Chirurgical'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 546067.3406, 'long': 5607910.7937},
#    'properties': {'name': 'Centre hospitalier de Valence'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 264995.6909, 'long': 6253554.7322},
#    'properties': {'name': 'Hôpital Maison-Blanche'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 282164.8974, 'long': 5520116.3482},
#    'properties': {'name': 'Centre Hospitalier Sainte Marie'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 476506.0745, 'long': 5849888.5273},
#    'properties': {'name': 'Centre hospitalier de Charolles'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 435080.4483, 'long': 5407463.6523},
#    'properties': {'name': 'Centre Orthopédique Maguelone'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 267109.3148, 'long': 6627772.1998},
#    'properties': {'name': 'Centre de Planification Familliale'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 388589.0678, 'long': 5546649.9148},
#    'properties': {'name': 'Hôpital Lozère'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 318001.7045, 'long': 6464110.0887},
#    'properties': {'name': 'Centre Hospitalier de Bapaume'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 41069.3945, 'long': 5871105.0135},
#    'properties': {'name': 'Clinique Saint-Charles'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 233352.9469, 'long': 6285680.4289},
#    'properties': {'name': 'Centre hospitalier René Dubos'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 638040.3277, 'long': 5644936.2692},
#    'properties': {'name': 'Hôpital Sud'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 564300.9696, 'long': 5994392.1783},
#    'properties': {'name': 'Centre Georges-François Leclerc'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 515554.2737, 'long': 5412554.5399},
#    'properties': {'name': 'Centre de Dialyse - Diaverum'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 434456.2059, 'long': 6417286.7038},
#    'properties': {'name': 'Centre Hospitalier de Vervins'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 123476.7618, 'long': 6349877.9075},
#    'properties': {'name': 'Hôpital Charles Nicolle'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 216882.1151, 'long': 6245365.795},
#    'properties': {'name': 'Centre médico-psychologique La Pommeraie'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 277987.3998, 'long': 5897386.5976},
#    'properties': {'name': 'Clinique des Grainetières'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 337273.7672, 'long': 5265834.0462},
#    'properties': {'name': 'Centre Medico Psychologique La Canetoise'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 231100.9797, 'long': 6287442.1133},
#    'properties': {'name': 'Clinique Sainte-Marie'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 431984.5726, 'long': 5585988.6826},
#    'properties': {'name': 'Foyer Saint-Nicolas'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': -66724.4172, 'long': 5590947.8872},
#    'properties': {'name': 'Clinique Bethanie'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 367908.6684, 'long': 5424110.3927},
#    'properties': {'name': 'Clinique du Souffle - La Vallonie'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': -227605.9897, 'long': 6309406.1105},
#    'properties': {'name': 'Clinique Pinel'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': -39261.9143, 'long': 5361991.786},
#    'properties': {'name': 'Clinique Les Jeunes Chênes'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 635434.8948, 'long': 6168449.8936},
#    'properties': {'name': 'Centre hospitalier de l’Ouest Vosgien - Site de Neufchâteau'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 609360.0122, 'long': 5358566.3482},
#    'properties': {'name': 'Polyclinique La Phocéanne'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 337697.8851, 'long': 6552265.2691},
#    'properties': {'name': 'Centre Hospitalier Régional Universitaire de Lille'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 167739.2144, 'long': 6177099.8244},
#    'properties': {'name': 'SMUR CHARTRES'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': -38816.5503, 'long': 5361383.612},
#    'properties': {'name': 'Clinique Princess'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 230448.1621, 'long': 6351386.6789},
#    'properties': {'name': 'Centre hospitalier Simone Veil de Beauvais'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 268490.6262, 'long': 6339358.4686},
#    'properties': {'name': "Centre hospitalier de Clermont de l'Oise"},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 267690.4703, 'long': 6274802.6594},
#    'properties': {'name': 'Hôpital Adélaïde Hautval'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 534864.8114, 'long': 5598927.396},
#    'properties': {'name': 'Centre Ssr le Château'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 271160.9641, 'long': 5609956.4227},
#    'properties': {'name': 'Centre Hospitalier Henri Mondor'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 429357.9068, 'long': 5459073.9359},
#    'properties': {'name': None},
#    '@type': 'hospital'},
#   {'geometry': {'lat': -184056.9905, 'long': 5371960.8872},
#    'properties': {'name': 'Hôpital de Saint-Jean-de-Luz'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': -172954.8177, 'long': 5976479.342},
#    'properties': {'name': 'Hôtel Dieu'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 240840.7086, 'long': 5452262.0914},
#    'properties': {'name': 'Hôpital de Jour Agricole Bellevue'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': -34589.1858, 'long': 5564237.4091},
#    'properties': {'name': 'Centre Hospitalier de Cadillac - Unité pour Malades Difficiles'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': -202509.6759, 'long': 6018380.16},
#    'properties': {'name': 'Centre Hospitalier Spécialisé de Blain'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 300731.6928, 'long': 6175737.8711},
#    'properties': {'name': 'Polyclinique de la Forêt'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': -23027.5818, 'long': 6069345.4859},
#    'properties': {'name': 'Pôle Santé Sarthe et Loir'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 654777.9415, 'long': 5323559.4222},
#    'properties': {'name': 'Institut Médicalisé de Mar-Vivo'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 440692.6079, 'long': 6494833.233},
#    'properties': {'name': 'CHSA - Centre de Psychothérapie'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 695000.6758, 'long': 6295907.6466},
#    'properties': {'name': 'Hôpital Robert-Schuman'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 340434.2074, 'long': 6508629.4066},
#    'properties': {'name': 'Clinique Saint-Amé'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 550374.0806, 'long': 5850335.3827},
#    'properties': {'name': 'Centre Hospitalier de Pont-de-Vaux'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 267618.8073, 'long': 5352216.5119},
#    'properties': {'name': 'Château de la Vernede - Centre de soin de suite et de réadaptation'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 308632.0272, 'long': 6106355.1001},
#    'properties': {'name': "Centre hospitalier de l'agglomération montargoise"},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 24830.6696, 'long': 6100908.5701},
#    'properties': {'name': 'Clinique du Tertre Rouge'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': -174781.3889, 'long': 6245810.6522},
#    'properties': {'name': 'Centre Hospitalier Avranches - Granville'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 415143.404, 'long': 6227915.7373},
#    'properties': {'name': 'Centre Hospitalier de Sézanne'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 5048.6319, 'long': 5370579.8659},
#    'properties': {'name': 'Hôpital Gériatrique des Acacias'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 271665.5103, 'long': 6340408.1376},
#    'properties': {'name': 'Centre Hospitalier Psychiatrique Interdépartemental Site de Fitz James'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 692901.1528, 'long': 5810330.662},
#    'properties': {'name': 'Hôpital Privé Pays de Savoie'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 195867.1673, 'long': 5814853.8909},
#    'properties': {'name': 'Hôpital de la Valette'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 807285.7915, 'long': 5419610.0144},
#    'properties': {'name': 'Clinique du Parc Impérial'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 264377.7359, 'long': 6263907.6292},
#    'properties': {'name': 'Hôpital Delafontaine'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 381275.078, 'long': 6524210.015},
#    'properties': {'name': 'Clinique psychiatrique'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 707939.3682, 'long': 5925896.9977},
#    'properties': {'name': 'Centre hospitalier de Pontarlier'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 861095.2899, 'long': 6204229.1174},
#    'properties': {'name': 'Clinique Sainte-Barbe'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 427908.9293, 'long': 5403077.1599},
#    'properties': {'name': 'service MPEA'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 254909.9882, 'long': 6248838.2324},
#    'properties': {'name': 'Maison médicale Jeanne Garnier'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 543531.0182, 'long': 5739378.8927},
#    'properties': {'name': 'Hôpital Édouard Herriot'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': -92124.9509, 'long': 5855276.5738},
#    'properties': {'name': 'Centre Hospitalier de Fontenay-le-Comte'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 347629.2394, 'long': 6554647.187},
#    'properties': {'name': "Centre de l'Espoir"},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 582570.7927, 'long': 5812618.7383},
#    'properties': {'name': 'Hôtel-Dieu'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 156177.919, 'long': 5405060.7175},
#    'properties': {'name': 'Hôpital Paule de Viguier'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 292773.6186, 'long': 6540290.0777},
#    'properties': {'name': "Clinique Anne d'Artois"},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 612527.3669, 'long': 5357959.3},
#    'properties': {'name': 'Clinique des Quatre Saisons'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': -27411.6014, 'long': 5613094.4652},
#    'properties': {'name': 'Colisée Clinique Avicenne'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 252574.9754, 'long': 6248842.5731},
#    'properties': {'name': 'Hôpital Sainte-Périne - Rossini - Chardon-Lagache'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': -265536.8435, 'long': 6075766.9288},
#    'properties': {'name': 'Clinique des Augustines'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 256506.4895, 'long': 6254527.46},
#    'properties': {'name': 'Clinique Internationale du Parc Monceau'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 333971.2648, 'long': 5339575.6863},
#    'properties': {'name': 'Centre Hospitalier de Narbonne'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 209108.6096, 'long': 6090180.7282},
#    'properties': {'name': 'Centre de jour Marcel Proust'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 826220.3643, 'long': 6282664.7709},
#    'properties': {'name': 'Hôpital Saint-Joseph'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 325869.1227, 'long': 6010171.4437},
#    'properties': {'name': 'Centre Hospitalier de Cosne sur Loire'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 268614.0709, 'long': 6220078.3761},
#    'properties': {'name': 'Hôpital Dupuytren'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 249833.1977, 'long': 6246954.8219},
#    'properties': {'name': "Centre de Pneumologie de l'Enfant"},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 683268.107, 'long': 6297001.0698},
#    'properties': {'name': 'Hôpital Félix Maréchal'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 316021.462, 'long': 5996632.7567},
#    'properties': {'name': 'Hôpital local de Sancerre'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 542083.3669, 'long': 5738478.3008},
#    'properties': {'name': 'Clinique Saint-Jean'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 507545.072, 'long': 6084043.725},
#    'properties': {'name': 'Centre hospitalier de Châtillon-sur-Seine'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 273870.3819, 'long': 6260151.142},
#    'properties': {'name': "Clinique du Bois d'Amour"},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 346242.6842, 'long': 5746109.8945},
#    'properties': {'name': 'Hôpital Estaing'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 635585.2936, 'long': 5650158.5798},
#    'properties': {'name': 'Groupe hospitalier mutualiste de Grenoble'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 405182.91, 'long': 6429368.2619},
#    'properties': {'name': 'Centre hospitalier de Guise'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 830751.5799, 'long': 6189531.2718},
#    'properties': {'name': 'Hôpital Saint-Jacques'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 347605.3657, 'long': 5938733.7776},
#    'properties': {'name': 'Hôpital Pierre Bérégovoy'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': -61873.0803, 'long': 6021364.6403},
#    'properties': {'name': "(ICO) Institut de Cancérologie de l'Ouest - Centre Paul Papin"},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 446929.2596, 'long': 6451210.424},
#    'properties': {'name': 'Polyclinique de la Thiérache'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 427250.5366, 'long': 5410546.3409},
#    'properties': {'name': 'Institut régional du Cancer de Montpellier'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': -67048.5063, 'long': 5593927.7364},
#    'properties': {'name': 'Hôpital Charles Perrens'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 78613.566, 'long': 6423296.7989},
#    'properties': {'name': 'Centre hospitalier du Grand Large'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 185432.9102, 'long': 5385022.6167},
#    'properties': {'name': 'Maison de Santé Mailhol'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 538636.8444, 'long': 5746196.0836},
#    'properties': {'name': 'Hôpital gériatrique Frédéric Dugoujon'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 427533.2126, 'long': 5578380.2356},
#    'properties': {'name': 'Centre hospitalier de Langogne'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 656200.7276, 'long': 6327428.3641},
#    'properties': {'name': 'Dollard-Westrich Florence'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 624448.0429, 'long': 5339380.3917},
#    'properties': {'name': 'Centre hospitalier de la Ciotat'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': -70289.3864, 'long': 5340566.5842},
#    'properties': {'name': 'Centre Hospitalier - Site de Saint-Pée'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 718362.99, 'long': 5393348.457},
#    'properties': {'name': 'Clinique Notre-Dame'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': -22770.6934, 'long': 6256313.6798},
#    'properties': {'name': 'Centre Hospitalier de Falaise'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 293978.0316, 'long': 6200000.561},
#    'properties': {'name': "Clinique Saint-Jean l'Ermitage"},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 250495.5601, 'long': 6247934.1478},
#    'properties': {'name': 'Clinique Montevideo'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 537764.3126, 'long': 5745441.9339},
#    'properties': {'name': 'Hôpital de la Croix-Rousse'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 238237.6379, 'long': 6239946.3469},
#    'properties': {'name': 'Clinique des Franciscaines'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 975775.8282, 'long': 5243463.4163},
#    'properties': {'name': 'Centre hospitalier de Calvi-Balagne'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 733942.4733, 'long': 6109079.6629},
#    'properties': {'name': 'Centre Hospitalier Sainte-Béatrix de Lorraine'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': -107276.2945, 'long': 5775072.1137},
#    'properties': {'name': 'Centre hospitalier de Rochefort'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 697947.2394, 'long': 6288041.8337},
#    'properties': {'name': 'Complexe Hospitalier Spécialisé de Jury'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 540341.0632, 'long': 5630203.683},
#    'properties': {'name': 'Hôpital de Tournon'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 580420.4817, 'long': 5374451.5509},
#    'properties': {'name': 'Clinique Générale de Marignane'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 266947.5342, 'long': 6248037.6506},
#    'properties': {'name': 'Unité de Soins de Suite de la Fondation Rothschild'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 675610.6255, 'long': 5553787.3731},
#    'properties': {'name': 'Centre Rhône-Azur'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 122770.3368, 'long': 6342273.6862},
#    'properties': {'name': 'Hôpital de jour Adosphère'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 681618.8385, 'long': 5330365.5212},
#    'properties': {'name': 'Clinique Villa Magali'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 198646.2371, 'long': 6301221.8011},
#    'properties': {'name': 'Groupement Hospitalier Intercommunal du Vexin - Site de Magny'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 241594.5201, 'long': 6273528.6529},
#    'properties': {'name': 'Clinique du Château'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 318807.76, 'long': 5265727.6292},
#    'properties': {'name': "Centre Catalan d'Imagerie"},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 65629.952, 'long': 6290153.5815},
#    'properties': {'name': 'Centre hospitalier de Bernay'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 280867.7221, 'long': 6261039.2453},
#    'properties': {'name': 'Clinique Vauban'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 622780.1064, 'long': 5895755.7401},
#    'properties': {'name': 'Parking'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 724347.3494, 'long': 6245277.4667},
#    'properties': {'name': 'Hôpital de Château Salins'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 481856.6909, 'long': 6266827.3003},
#    'properties': {'name': 'Centre Rééducation Moteur Cérébral'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': -426594.7801, 'long': 6202230.6101},
#    'properties': {'name': 'Centre hospitalier des Pays de Morlaix'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 40841.6471, 'long': 5871237.6694},
#    'properties': {'name': 'Polyclinique de Poitiers'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 361098.6314, 'long': 6478753.9795},
#    'properties': {'name': 'Clinique Saint-Roch'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 430848.7689, 'long': 5409758.1005},
#    'properties': {'name': 'Clinique Lavalette'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 681707.48, 'long': 5988246.5253},
#    'properties': {'name': 'Centre Hospitalier de Novillars'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 723808.4074, 'long': 6054132.2207},
#    'properties': {'name': 'Centre hospitalier de Lure'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 683176.4845, 'long': 5317420.3585},
#    'properties': {'name': 'Hôpital Renée Sabran'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': -367294.7361, 'long': 6212205.4788},
#    'properties': {'name': "Clinique d'Addictologie"},
#    '@type': 'hospital'},
#   {'geometry': {'lat': -130844.1503, 'long': 5804963.998},
#    'properties': {'name': 'Centre de réadaptation fonctionnelle Richelieu'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 267997.2015, 'long': 6216479.9757},
#    'properties': {'name': 'Groupe Hospitalier Les cheminots'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 571118.9134, 'long': 6239274.1744},
#    'properties': {'name': 'Centre hospitalier spécialisé de Fains-Véel'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': -67344.8036, 'long': 6157757.1108},
#    'properties': {'name': 'Centre Hospitalier du Nord-Mayenne'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 204852.5871, 'long': 5269386.1366},
#    'properties': {'name': 'Hôpital local Saint-Louis'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 713172.1397, 'long': 5793461.7108},
#    'properties': {'name': 'Centre Martel de Janville'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 257229.3237, 'long': 6245975.5304},
#    'properties': {'name': 'Aura'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': -50658.3091, 'long': 5830599.4771},
#    'properties': {'name': 'Centre hospitalier de Niort - Site de Goise'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 447213.2908, 'long': 6316377.0453},
#    'properties': {'name': 'Polyclinique Courlancy'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': -68687.5506, 'long': 5341886.1631},
#    'properties': {'name': "Centre hospitalier d'Oloron"},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 718491.9782, 'long': 6136636.8119},
#    'properties': {'name': 'Centre Hospitalier Émile Durkheim'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 544023.9022, 'long': 5751734.3225},
#    'properties': {'name': 'Polyclinique Lyon-Nord Rillieux'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 487933.8094, 'long': 5443085.6425},
#    'properties': {'name': 'Clinique Les Sophoras'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 442974.3553, 'long': 6082949.291},
#    'properties': {'name': 'Centre hospitalier du Tonnerrois'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 538329.7069, 'long': 5740319.7089},
#    'properties': {'name': 'Centre Hospitalier Saint-Joseph Saint-Luc'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 243455.2641, 'long': 6253864.8781},
#    'properties': {'name': 'Hôpital Stell'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 32526.9433, 'long': 5972873.5166},
#    'properties': {'name': "Clinique Jeanne d'Arc"},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 269598.6078, 'long': 6218180.2213},
#    'properties': {'name': 'Hôpital des Cheminots'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 748265.3518, 'long': 6243325.8734},
#    'properties': {'name': 'Hôpital Saint-Jacques'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': -235160.3519, 'long': 6306774.1979},
#    'properties': {'name': 'Jersey General Hospital'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': -73426.0871, 'long': 5587900.3131},
#    'properties': {'name': 'Hôpital Haut-Lévêque'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 255034.5065, 'long': 6253042.3744},
#    'properties': {'name': 'Clinique Chirurgicale Victor Hugo'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 252038.2644, 'long': 6271611.9465},
#    'properties': {'name': 'Clinique Claude Bernard'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 656007.9886, 'long': 5334332.9563},
#    'properties': {'name': "HIA Sainte-Anne - Site L'Oratoire"},
#    '@type': 'hospital'},
#   {'geometry': {'lat': -231535.5128, 'long': 6049534.79},
#    'properties': {'name': 'Centre hospitalier intercommunal Redon-Carentoir'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': -230013.7799, 'long': 6212666.301},
#    'properties': {'name': 'Hôpital Arthur Gardiner'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 266003.811, 'long': 6238577.0018},
#    'properties': {'name': 'Hôpital privé de Vitry - Site Pasteur'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 251772.6616, 'long': 6239383.2182},
#    'properties': {'name': 'Clinique du Plateau'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 209514.6872, 'long': 6096673.5761},
#    'properties': {'name': 'La Cigogne'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': -179572.4021, 'long': 6383690.6786},
#    'properties': {'name': 'Hôpital Pasteur'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 532330.9581, 'long': 5908847.7064},
#    'properties': {'name': 'Dracy santé : Centre Orthopédique Médico Chirurgical de Dracy-Le Fort'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 320106.0011, 'long': 5458993.0469},
#    'properties': {'name': 'Centre hospitalier de Saint-Affrique'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 435670.4878, 'long': 5404034.038},
#    'properties': {'name': 'Clinique du Millénaire'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 483976.709, 'long': 5439414.7321},
#    'properties': {'name': 'Clinique Kennedy'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 262888.8217, 'long': 6240444.4075},
#    'properties': {'name': 'Hôpital Paul Brousse'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 151096.3342, 'long': 6119246.5633},
#    'properties': {'name': 'Centre hospitalier de Châteaudun'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 102350.3592, 'long': 6038526.9111},
#    'properties': {'name': 'Centre hospitalier de Château-Renault'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 305462.8389, 'long': 6576502.3899},
#    'properties': {'name': 'Établissement Public de Santé Mentale des Flandres'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': -130207.8939, 'long': 5805494.9903},
#    'properties': {'name': 'Clinique du Mail'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 481024.0939, 'long': 5683292.762},
#    'properties': {'name': 'Centre hospitalier Georges Claudinon'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 513243.0319, 'long': 5489457.2116},
#    'properties': {'name': 'Clinique Ambulatoire de la Cèze'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': -164593.3992, 'long': 6183108.3555},
#    'properties': {'name': "Centre Hospitalier d'Antrain"},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 263284.1754, 'long': 6247338.807},
#    'properties': {'name': 'Hôpital Pitié-Salpêtrière'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 478862.2791, 'long': 5934254.6617},
#    'properties': {'name': "Centre hospitalier d'Autin - Site Latouche"},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 170023.7254, 'long': 5405505.4456},
#    'properties': {'name': "Clinique Château d'Aufrery"},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 209126.4677, 'long': 6096778.2454},
#    'properties': {'name': 'Pôle Santé Oréliance'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 330303.8895, 'long': 5336232.9452},
#    'properties': {'name': "Pech d'Alcy USLD de l'Hôpital de Narbonne"},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 195813.5393, 'long': 6322698.5275},
#    'properties': {'name': 'Centre Hospitalier de Gisors - Pôle Sanitaire du Vexin'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 676063.2382, 'long': 5552081.0273},
#    'properties': {'name': 'Centre Hospitalier Intercommunal des Alpes du Sud'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 138015.4349, 'long': 5750539.375},
#    'properties': {'name': 'Hôpital de la Mère et de l’Enfant'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': -117001.389, 'long': 5420100.5336},
#    'properties': {'name': 'Hôpital Thermal'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 611013.4902, 'long': 5669295.2002},
#    'properties': {'name': 'Centre Hospitalier Michel Perret'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 253145.9358, 'long': 6247559.1798},
#    'properties': {'name': 'Hôpital Européen Georges Pompidou'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': -126473.2739, 'long': 5808376.2321},
#    'properties': {'name': 'Hôpital Psychiatrique Marius Lacroix'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': -27293.0037, 'long': 5550122.3449},
#    'properties': {'name': 'Centre hospitalier de Langon'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': -167135.6026, 'long': 5973410.7875},
#    'properties': {'name': 'Centre de Convalescence Mutualiste'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 179394.0199, 'long': 5939216.9362},
#    'properties': {'name': None},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 294228.918, 'long': 6200146.6835},
#    'properties': {'name': 'Centre hospitalier de Melun'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': -227350.5902, 'long': 5927893.6875},
#    'properties': {'name': 'Hôpital Local Les Mathurins'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': -47325.7535, 'long': 6199608.7016},
#    'properties': {'name': 'Centre de Médecine Physique et de Réadaptation de Bagnoles de l’Orne'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 256968.7138, 'long': 6217860.3332},
#    'properties': {'name': "Maison d'accueil spécialisée Les Jours Heureux"},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 484818.4885, 'long': 5437032.821},
#    'properties': {'name': 'Polyclinique du Grand Sud'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 219946.8533, 'long': 6299908.5361},
#    'properties': {'name': 'Hôpital Jean-Baptiste Cartry'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 252826.3111, 'long': 6249074.0118},
#    'properties': {'name': 'Clinique Rémusat'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 782238.6865, 'long': 6274551.4286},
#    'properties': {'name': 'Hôpital Saint-Joseph'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 71845.1541, 'long': 6013842.4759},
#    'properties': {'name': 'Centre de Rééducation Fonctionnelle Neurologique Bel-Air'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 1049451.9011, 'long': 5263631.2348},
#    'properties': {'name': 'Centre hospitalier de Bastia'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 90694.5143, 'long': 6334290.2699},
#    'properties': {'name': 'Hôpital Pierre Hurabielle'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 257748.3075, 'long': 6248625.4854},
#    'properties': {'name': 'Hôpital Necker Enfants Malades'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 341960.9681, 'long': 5744819.8838},
#    'properties': {'name': 'Centre de Rééducation Fonctionnelle Notre-Dame'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 212788.8136, 'long': 6275326.5892},
#    'properties': {'name': 'Centre hospitalier de Meulan-en-Yvelines'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 70029.1323, 'long': 5494258.4937},
#    'properties': {'name': 'Clinique Esquirol Saint-Hilaire'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 168589.3392, 'long': 5415900.7002},
#    'properties': {'name': 'Clinique de Castelviel'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': -136551.1755, 'long': 6127333.9818},
#    'properties': {'name': 'Centre hospitalier Simone Veil'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 283083.2955, 'long': 6251843.1455},
#    'properties': {'name': 'La Roseraie'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 263641.5321, 'long': 6267235.6927},
#    'properties': {'name': "Clinique de l'Estrée"},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 563359.568, 'long': 5675341.1573},
#    'properties': {'name': 'Centre Hospitalier de Luzy-Dufeillant'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': -99807.1965, 'long': 5948900.7552},
#    'properties': {'name': 'Centre hospitalier de Cholet'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 270118.362, 'long': 6248419.278},
#    'properties': {'name': "Hôpital d'Instruction des Armées Bégin"},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 277807.1896, 'long': 6226195.028},
#    'properties': {'name': "Hôpital privé du Val d'Yerres"},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 578551.3273, 'long': 5740941.3668},
#    'properties': {'name': "Cabinet d'ophtalmologie"},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 428560.7448, 'long': 5405206.9332},
#    'properties': {'name': 'Clinique Beau Soleil'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 761581.7991, 'long': 6043027.1045},
#    'properties': {'name': None},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 830383.5488, 'long': 6049117.7649},
#    'properties': {'name': 'Centre hospitalier de Sierentz'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 408554.8261, 'long': 5374171.9984},
#    'properties': {'name': 'Centre hospitalier du Bassin de Thau'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 138075.4087, 'long': 5750559.5925},
#    'properties': {'name': "Hôpital de la mère et de l'enfant"},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 412338.2542, 'long': 5374316.142},
#    'properties': {'name': 'Polyclinique Sainte-Thérèse'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': -26999.5547, 'long': 5421151.707},
#    'properties': {'name': "Polyclinique de l'Adour"},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 255691.8646, 'long': 6252418.1406},
#    'properties': {'name': 'Clinique Bizet'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 340720.2908, 'long': 5744289.5442},
#    'properties': {'name': 'Clinique des 6 Lacs'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 263902.2382, 'long': 5387673.1721},
#    'properties': {'name': 'Centre Hospitalier InterCommunal'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 670965.8854, 'long': 5985209.1079},
#    'properties': {'name': None},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 524340.9095, 'long': 6444495.3965},
#    'properties': {'name': 'Centre hospitalier de Fumay'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 318947.0263, 'long': 5265791.1144},
#    'properties': {'name': 'Clinique Saint-Pierre'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': -155854.4577, 'long': 5365355.5232},
#    'properties': {'name': 'Marienea'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 661999.6077, 'long': 5330811.9734},
#    'properties': {'name': 'Hôpital Privé Saint-Jean'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 403775.2709, 'long': 6490001.5659},
#    'properties': {'name': 'Hôpital Léon Schwartzenberg'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 43054.3715, 'long': 6402153.0263},
#    'properties': {'name': 'HAD Estuaire'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 752963.5506, 'long': 5719085.5114},
#    'properties': {'name': 'Centre Hospitalier de Bourg-Saint-Maurice'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 155950.9863, 'long': 5405304.377},
#    'properties': {'name': 'Hôpital Purpan'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 103239.5437, 'long': 5608421.7783},
#    'properties': {'name': 'Groupe Médical Jean Rey'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 257300.3803, 'long': 6258269.7544},
#    'properties': {'name': 'Hôpital Goüin'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 540356.7306, 'long': 5740195.6212},
#    'properties': {'name': "Clinique dentaire et d'orthodontie mutualiste"},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 807397.4117, 'long': 5419515.7678},
#    'properties': {'name': 'Clinique Atlantis'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 864419.4064, 'long': 6199468.851},
#    'properties': {'name': 'Hôpitaux Universitaires de Strasbourg Lyautey'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': -304189.2727, 'long': 6186396.5242},
#    'properties': {'name': 'Clinique de la Cerisaie'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': -191952.6359, 'long': 6175326.7937},
#    'properties': {'name': 'Centre local hospitalier Saint-Joseph'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 639907.907, 'long': 5654040.8737},
#    'properties': {'name': 'Clinique du Grésivaudan'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': -138440.6836, 'long': 6097609.156},
#    'properties': {'name': 'Centre Hospitalier'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 1020073.5612, 'long': 5071425.2102},
#    'properties': {'name': 'Centre hospitalier de Bonifacio'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': -168925.6607, 'long': 6198986.9885},
#    'properties': {'name': "Centre hospitalier de l'Estran"},
#    '@type': 'hospital'},
#   {'geometry': {'lat': -207764.104, 'long': 6221281.8203},
#    'properties': {'name': 'Hôpital des Prés Bosgers'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 321335.1476, 'long': 6269329.0329},
#    'properties': {'name': 'Centre hospitalier de Meaux'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 259440.1014, 'long': 6256217.3116},
#    'properties': {'name': 'Hôpital Bretonneau'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 266722.5003, 'long': 6241947.7666},
#    'properties': {'name': 'Hôpital Charles Foix'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 267029.2145, 'long': 5345359.2358},
#    'properties': {'name': 'Clinique Verdeau-Pailles'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': -65441.7007, 'long': 6021633.8454},
#    'properties': {'name': 'Clinique Saint-Didier'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 236613.1176, 'long': 6246354.6856},
#    'properties': {'name': 'Hôpital André Mignot - Maternité'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': -42481.8109, 'long': 6324291.1351},
#    'properties': {'name': 'Kinésithérapeute'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 636037.4248, 'long': 5650704.7777},
#    'properties': {'name': 'Centre médico-psychologique Diatkine - Infanto juvénile'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 689266.389, 'long': 6221530.3572},
#    'properties': {'name': 'Hôpital Central'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 336005.2816, 'long': 6541854.411},
#    'properties': {'name': "USLD Au Fil de l'Eau"},
#    '@type': 'hospital'},
# ...
#   {'geometry': {'lat': 290779.5789, 'long': 6241581.5752},
#    'properties': {'name': None},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 512169.6108, 'long': 6226751.3526},
#    'properties': {'name': 'Centre Hospitalier de Vitry-le-François'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 211076.4359, 'long': 6610943.6694},
#    'properties': {'name': 'Clinique des Oyats'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 384408.0711, 'long': 5913108.7643},
#    'properties': {'name': 'Centre hospitalier de Decize'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 239593.176, 'long': 6266436.28},
#    'properties': {'name': 'Polyclinique de Maisons-Laffitte'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 273513.7268, 'long': 6210644.4212},
#    'properties': {'name': 'Centre Hospitalier Sud Francilien'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': -67367.617, 'long': 5595751.6457},
#    'properties': {'name': 'Clinique Saint-Augustin'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 61449.1696, 'long': 6194379.2765},
#    'properties': {'name': 'Centre Hospitalier Marguerite de Lorraine'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 54546.9264, 'long': 5598215.423},
#    'properties': {'name': 'Clinique Pasteur'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 169848.9191, 'long': 5441158.4979},
#    'properties': {'name': 'Clinique du Château de Vernhes'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': -80736.1841, 'long': 5976118.2024},
#    'properties': {'name': 'Hôpital Local'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 399312.4038, 'long': 6084191.9122},
#    'properties': {'name': 'Clinique du Petit Pien'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 560779.2561, 'long': 5376258.3565},
#    'properties': {'name': 'Les Vallons'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 486476.2905, 'long': 6270074.5601},
#    'properties': {'name': 'Centre hospitalier de Châlons-en-Champagne'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 15180.8398, 'long': 6358018.8951},
#    'properties': {'name': 'Clinique des Ormeaux'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 802828.9682, 'long': 5417011.3027},
#    'properties': {'name': 'Centre Antoine Lacassagne'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 558823.0402, 'long': 5628142.2726},
#    'properties': {'name': 'Hôpitaux Drôme-Nord'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 168029.9492, 'long': 5401105.9187},
#    'properties': {'name': None},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 268792.254, 'long': 6254273.4716},
#    'properties': {'name': 'Maternité des Lilas'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 459385.2216, 'long': 5644252.7847},
#    'properties': {'name': 'Centre Hospitalier Jacques Barrot'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 430136.4141, 'long': 5406821.3386},
#    'properties': {'name': 'Clinique Rech'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 353419.0469, 'long': 6514271.3175},
#    'properties': {'name': 'Maison de Santé et de Cure Médicale La Plaine de la Scarpe'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 316917.7059, 'long': 5269977.431},
#    'properties': {'name': 'Clinique de la Pinède'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 225907.9177, 'long': 5525043.3979},
#    'properties': {'name': 'Centre hospitalier de Villefranche-de-Rouergue - Site de Ruhle'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 545547.9714, 'long': 5739749.7443},
#    'properties': {'name': 'Hôpital Femme-Mère-Enfant'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 274409.7055, 'long': 6262607.6056},
#    'properties': {'name': 'Clinique Gallieni'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 245340.7101, 'long': 6263616.2259},
#    'properties': {'name': 'Polyclinique du Plateau'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 313704.6601, 'long': 6522675.349},
#    'properties': {'name': 'Centre hospitalier de Lens'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 62041.9063, 'long': 5914459.9419},
#    'properties': {'name': 'Centre hospitalier Henri laborit'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 20558.9734, 'long': 5626708.2341},
#    'properties': {'name': 'C.H.S de Vauclaire'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 239284.0571, 'long': 6177258.5376},
#    'properties': {'name': "Centre hospitalier d'Étampes"},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 519799.3023, 'long': 5662694.0221},
#    'properties': {'name': 'Clinique des Cévennes'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 559764.6584, 'long': 5472773.5326},
#    'properties': {'name': 'Pôle Santé CHS Montfavet'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 146075.6544, 'long': 5379623.1505},
#    'properties': {'name': 'Hôpital local de Muret'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 14398.4695, 'long': 6340024.0238},
#    'properties': {'name': 'Centre Hospitalier de la Côte Fleurie'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 270624.6911, 'long': 6254234.5848},
#    'properties': {'name': 'Centre médico-chirurgical Floréal'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 9671.8995, 'long': 6363525.0525},
#    'properties': {'name': 'Centre de Rééducation Fonctionnelle de la Hève'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 869592.5558, 'long': 6201839.0989},
#    'properties': {'name': 'Ortenau Klinikum Offenburg-Kehl'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 600603.4536, 'long': 5356312.3158},
#    'properties': {'name': 'Hôpital de la Conception'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': -122030.9621, 'long': 6202011.8516},
#    'properties': {'name': 'Centre Hospitalier de Saint-Hilaire-du-Harcouet'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': -173449.9154, 'long': 5976431.7504},
#    'properties': {'name': 'Centre du Voyage International'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 485889.3336, 'long': 6268223.5739},
#    'properties': {'name': 'Hôpital de Jour Lewis Carroll'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': -39006.39, 'long': 5361468.9315},
#    'properties': {'name': 'Polyclinique de Navarre'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 519620.5499, 'long': 5434453.9468},
#    'properties': {'name': 'Hôpitaux des Portes de Camargue'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 181423.2991, 'long': 6572371.4866},
#    'properties': {'name': 'Centre hospitalier de Boulogne-sur-Mer'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 575073.0838, 'long': 6238595.3825},
#    'properties': {'name': 'Centre Hospitalier de Bar-le-Duc'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 279211.3901, 'long': 6249903.3862},
#    'properties': {'name': 'Clinique Joncs Marins'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 73401.9168, 'long': 5443412.5226},
#    'properties': {'name': 'Etablissement Public de Santé de Lomagne'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 267873.7726, 'long': 6248257.8171},
#    'properties': {'name': 'Hôpital Pierre Rouquès - Les Bluets'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 255386.4373, 'long': 6424119.6948},
#    'properties': {'name': 'Clinique Victor Pauchet'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 124205.6964, 'long': 6354045.7677},
#    'properties': {'name': 'Clinique de Soins de Suite de Bois-Guillaume'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 259964.0798, 'long': 6236130.4527},
#    'properties': {'name': 'Hôpital de Chevilly-Larue'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 673753.6688, 'long': 6258992.283},
#    'properties': {'name': 'Centre hospitalier de Pont-à-Mousson'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 669170.915, 'long': 6313187.5321},
#    'properties': {'name': 'Hôpital de Joeuf'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 203191.2217, 'long': 6215930.6941},
#    'properties': {'name': 'Centre Hospitalier de Rambouillet'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 607730.6426, 'long': 5953486.7279},
#    'properties': {'name': 'Centre Hospitalier Spécialisé du Jura'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 118336.1253, 'long': 6342674.875},
#    'properties': {'name': 'Centre médico-psychologique Charles Perrault pour enfants et adolescents'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 210546.2531, 'long': 6610824.1151},
#    'properties': {'name': 'Centre hospitalier de Calais'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': -67600.4737, 'long': 5594431.3331},
#    'properties': {'name': 'Groupe hospitalier Pellegrin'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 359321.494, 'long': 5366070.3139},
#    'properties': {'name': "Centre d'imagerie le Rabelais"},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 659083.4959, 'long': 5331650.3195},
#    'properties': {'name': 'Hôpital Saint-Roch'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': -157434.1089, 'long': 5886416.3919},
#    'properties': {'name': 'Clinique Saint-Charles'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 284030.693, 'long': 5521343.5309},
#    'properties': {'name': 'Centre hospitalier de Rodez'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': -186297.4425, 'long': 5868297.3623},
#    'properties': {'name': 'Maison de la Santé'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 243722.4056, 'long': 6256552.5736},
#    'properties': {'name': 'Hôpital du Jour - Centre Médico-Psychologique'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 91173.4459, 'long': 5525724.1216},
#    'properties': {'name': "Centre Hospitalier de Penne d'Agenais"},
#    '@type': 'hospital'},
#   {'geometry': {'lat': -152104.3634, 'long': 5812572.5822},
#    'properties': {'name': 'Hopital Saint-Honoré'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 25155.7105, 'long': 6101139.5448},
#    'properties': {'name': 'Centre Médico Chirurgical du Mans'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 216764.4055, 'long': 6245017.596},
#    'properties': {'name': 'Centre hospitalier de Plaisir-Site Marc Laurent'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': -223697.1248, 'long': 6211622.7821},
#    'properties': {'name': 'HDJ Donald Winnicott'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 159407.2232, 'long': 5403812.0118},
#    'properties': {'name': 'Hôpital de la Grave'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 689435.4834, 'long': 6221917.5633},
#    'properties': {'name': 'Hôpital Saint-Julien'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 784606.1491, 'long': 6300885.0556},
#    'properties': {'name': 'SHG-Klinik für Kinder- und Jugendpsychiatrie und -psychotherapie'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 269156.3308, 'long': 6338802.0268},
#    'properties': {'name': 'Centre Hospitalier Psychiatrique Interdépartemental Site de Clermont'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 266898.1887, 'long': 6244881.9637},
#    'properties': {'name': 'Clinique de Bercy'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 350523.8256, 'long': 5941340.2907},
#    'properties': {'name': 'Polyclinique du Val de Loire'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 342932.1337, 'long': 5402635.3777},
#    'properties': {'name': 'Hôpital Paul Coste-Floret'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 120795.7658, 'long': 6334620.2297},
#    'properties': {'name': 'Hôpital de Oissel'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 342293.7325, 'long': 5745019.6611},
#    'properties': {'name': 'Hôpital de Jour Henri Ey'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 862157.2194, 'long': 6203176.8941},
#    'properties': {'name': 'Hôpital Civil'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 680441.9814, 'long': 5330102.2038},
#    'properties': {'name': 'Centre hospitalier de Hyères'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': -70477.1042, 'long': 6277949.8388},
#    'properties': {'name': 'Centre Hospitalier Aunay-Bayeux'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 538130.1799, 'long': 5758214.4454},
#    'properties': {'name': "Centre Hospitalier Gériatrique des Monts d'Or"},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 282634.8416, 'long': 6573404.7103},
#    'properties': {'name': "Centre Hospitalier d'Hazebrouck"},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 538287.2889, 'long': 5746215.9102},
#    'properties': {'name': 'Infirmerie Protestante'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 341385.7015, 'long': 5626321.5656},
#    'properties': {'name': 'Centre Hospitalier La Combe de Volzac'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 865816.5246, 'long': 6240546.0589},
#    'properties': {'name': 'Centre hospitalier de Haguenau'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 255242.9565, 'long': 6247354.9678},
#    'properties': {'name': 'Hôpital Cognacq-Jay'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 482939.0278, 'long': 6301902.52},
#    'properties': {'name': 'WCA'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 660472.6004, 'long': 6318738.6418},
#    'properties': {'name': 'Hôpital Maillot'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 260048.1814, 'long': 6513714.6912},
#    'properties': {'name': 'Polyclinique du Ternois'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 669852.1896, 'long': 5866105.6265},
#    'properties': {'name': 'Hôpital Léon Bérard'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 545326.8574, 'long': 5740215.776},
#    'properties': {'name': 'Hôpital neurologique Pierre Wertheimer'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': -132911.2653, 'long': 6166848.3864},
#    'properties': {'name': 'Centre hospitalier de Fougères'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 540326.4186, 'long': 5909172.8202},
#    'properties': {'name': 'Centre Médical Nicolas de Pontoux'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 630579.7037, 'long': 5706746.3447},
#    'properties': {'name': 'Centre Hospitalier Yves Touraine'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 343544.4328, 'long': 5626848.7028},
#    'properties': {'name': 'Centre Hospitalier de Saint-Flour'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 52382.366, 'long': 6371877.4346},
#    'properties': {'name': 'Hôpital psychiatrique'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 345842.5739, 'long': 5238367.6272},
#    'properties': {'name': 'Centre Medico Psychologique De Port-Vendres'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 541474.8865, 'long': 5743884.1354},
#    'properties': {'name': 'Hôpital des Charpennes'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': -109286.4871, 'long': 5975113.1743},
#    'properties': {'name': 'Hôpital Saint-Martin'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': -187843.2599, 'long': 6130954.5758},
#    'properties': {'name': 'Centre hospitalier privé Saint-Grégoire'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 660559.9671, 'long': 5332328.375},
#    'properties': {'name': 'Hôpital Sainte-Anne'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 179417.7087, 'long': 6571957.5418},
#    'properties': {'name': 'C.A.T.T.P.'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 675317.8908, 'long': 5373606.9462},
#    'properties': {'name': 'Centre hospitalier de Brignoles'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 395890.2859, 'long': 6074369.6581},
#    'properties': {'name': 'Centre hospitalier d’Auxerre'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 669610.6784, 'long': 5332181.8505},
#    'properties': {'name': 'Hôpital Clémenceau'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 344153.751, 'long': 5741572.8201},
#    'properties': {'name': 'Hôpital Gabriel Montpied'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': -173456.216, 'long': 5976425.6708},
#    'properties': {'name': 'Le Tourville'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 616687.2894, 'long': 6256159.4796},
#    'properties': {'name': 'Hôpital Sainte-Anne'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 327987.3325, 'long': 5255834.3051},
#    'properties': {'name': 'Clinique du Pré'},
#    '@type': 'hospital'},
#   {'geometry': {'lat': 336759.0789, 'long': 5339878.3464},
#    'properties': {'name': 'Polyclinique Le Languedoc'},
#    '@type': 'hospital'},
#   ...]}

# %%
data_hospital={
    "@context":{
        "@vocab": "http://schema.org/", 
		"@base": "http://data.org/", 
		"name": "name", 
		"lat": "lat", 
		"long": "long"
    },
    "features":[
        data_hospital
    ]
}

# %%
import json 
with open('france_hospital_records.json', 'w') as fp:
   json.dump(data_hospital, fp,ensure_ascii=False)
